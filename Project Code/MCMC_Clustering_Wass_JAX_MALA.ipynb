# %%
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pandas as pd
import time
import scipy

#Separate import for numpy and jax.numpy to have major felxibility
import jax.numpy as jnp
import numpy as np
from jax import jit,lax,random,grad,vmap
from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions
from tensorflow_probability.substrates import jax as jtfp
jtfd = jtfp.distributions

np.random.seed(0)

# %%
#sampled_perturbed = np.load('Data/sampled_2D_two_clusters.npy')
sampled_perturbed = np.load('test4.npy')
data = sampled_perturbed[0 : 1000]
#DEFINING NUMBER OF CLUSTERS AND DIMENSION OF DATA
k = 15
d = 2
#Key to store for random generation
rng_key = random.PRNGKey(0)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
@jit
def g(x):
    """
    Diggle Graton Modulation Function
    """
    #Shape parameters
    r = 5
    gamma = 0.5
    asymptote = 5
    logic0 = jnp.logical_and(0 < x,x <= 1e-5)  
    logic1 = jnp.logical_and( 1e-5 < x,x <= r)          
    logic2 = r < x       
    logic3 = x <= 0
    return (logic0 * x + logic1*(1e-5 +  jnp.power((x-1e-5)/r,1/gamma)) + logic2)*asymptote + logic3*1e-10

@jit
def sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,key = sample_from_MALA(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,data,cluster_allocs,h,mus,covs,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key

  
@jit
def sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs,h,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein when the cluster
    is empty
    """
    
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,subk1 = sample_from_MALA_empty(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,mus,covs,h,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
   
@jit
def spd_matrix_sqrt(X):
    eigvals, eigvecs = jnp.linalg.eigh(X)
    return eigvecs @ jnp.diag(jnp.sqrt(eigvals)) @ eigvecs.T

spd_matrix_sqrt_vec = vmap(spd_matrix_sqrt)
trace_vec = vmap(jnp.trace)

@jit
def wasserstein_to_normals(mu, cov, other_mus, other_covs):
    mean_dist = jnp.sum((other_mus - mu) ** 2, axis=1)
    cov_sqrt = spd_matrix_sqrt(cov)
    weird_term = trace_vec(spd_matrix_sqrt_vec(
        jnp.matmul(cov_sqrt, jnp.matmul(other_covs, cov_sqrt))))
    return g(jnp.nan_to_num(mean_dist + (trace_vec(other_covs) + jnp.trace(cov) - 2 * weird_term)))

@jit
def sum_dist_to_others(mu, cov, mask, other_mus, other_covs):   
    all_dists = jnp.log(wasserstein_to_normals(mu, cov, other_mus, other_covs))
    return jnp.sum(all_dists * mask)


@jit
def TargetFullCondEmptyCluster(mu,cov,mask,mus,covs,bijector):   
    """
    The full conditional from which we sample using Metropolis Hastings, written in a JAX-differentiable way,in
    the case where the cluster is empty
    """
    
    cov = jnp.matmul(bijector.forward(cov),jnp.transpose(bijector.forward(cov)))
    covs = jnp.matmul(bijector.forward(covs),jnp.transpose(bijector.forward(covs),axes = [0,2,1]))
 
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    #Normal Wishart Term
    normal_wishart = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    
    #Wasserstein Term
    wass_dist = sum_dist_to_others(mu, cov, mask, mus, covs)
    return normal_wishart + wass_dist

@jit
def TargetFullCond(mu,cov,mask,h,cluster_allocs,data,mus,covs,bijector):   
    """
    The full conditional from which we sample using Metropolis Hastings, written in a JAX-differentiable way
    """
    
    cov = jnp.matmul(bijector.forward(cov),jnp.transpose(bijector.forward(cov)))
    covs = jnp.matmul(bijector.forward(covs),jnp.transpose(bijector.forward(covs),axes = [0,2,1]))
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    #Normal Wishart Term
    normal_wishart = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)

    #Data Term
    normal_data = jnp.sum(jnp.where(cluster_allocs == h,jtfd.MultivariateNormalFullCovariance(mu, cov).log_prob(data),0))
    
    #Wasserstein Term
    wass_dist = sum_dist_to_others(mu, cov, mask, mus, covs)
    
    return normal_data + wass_dist + normal_wishart


@jit
def sample_from_MALA(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,data,cluster_allocs,h,mus,covs,bijector,key):
    """
    Sample new mean and covariance matrix through the bijection using MALA proposal
    """
    key , subk1 , subk2 = random.split(key,3)
    
    #Compute gradients of log wrt mu and cov
    mask = jnp.ones(mus.shape[0])
    mask.at[h].set(0.0)
    mask = jnp.array(mask)
    
    cov_old_vec = bijector.inverse(jnp.linalg.cholesky(cov_old))
    covs_vec = bijector.inverse(jnp.linalg.cholesky(covs))
     
    grad_log_mu,grad_log_cov = grad(TargetFullCond,argnums=[0,1])(mu_old,cov_old_vec,mask,h,cluster_allocs,data,mus,covs_vec,bijector)
    grad_out.append(grad_log_cov)

    #Compute mu proposal
    mu_mean = mu_old + tau*grad_log_mu
    mu = jtfd.MultivariateNormalFullCovariance(mu_mean, cov_prop_mu).sample(seed = subk1)
    
    #Compute cov proposal
    cov_mean_vec = cov_old_vec + tau*grad_log_cov
    
    vec_sampl = jtfd.MultivariateNormalFullCovariance(cov_mean_vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    


    return mu,cov,log_jac,key



@jit
def sample_from_MALA_empty(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,mus,covs,h,bijector,key):
    """
    Sample new mean and covariance matrix through the bijection using MALA proposal, in the case where cluster 
    is empty
    """
    key , subk1 , subk2 = random.split(key,3)
    
    #Compute gradients of log wrt mu and cov
    mask = jnp.ones(mus.shape[0])
    mask.at[h].set(0.0)
    mask = jnp.array(mask)
    
    cov_old_vec = bijector.inverse(jnp.linalg.cholesky(cov_old))
    covs_vec = bijector.inverse(jnp.linalg.cholesky(covs))
 
    
    grad_log_mu,grad_log_cov = grad(TargetFullCondEmptyCluster,argnums=[0,1])(mu_old,cov_old_vec,mask,mus,covs_vec,bijector)

    #Compute mu proposal
    mu_mean = mu_old + tau*grad_log_mu
    mu = jtfd.MultivariateNormalFullCovariance(mu_mean, cov_prop_mu).sample(seed = subk1)
    
    #Compute cov proposal
    cov_mean_vec = cov_old_vec + tau*grad_log_cov
    
    vec_sampl = jtfd.MultivariateNormalFullCovariance(cov_mean_vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    


    
    return mu,cov,log_jac,key



@jit
def compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    cluster_allocs_expanded = jnp.expand_dims(cluster_allocs,axis = 1)
    nan_vec = jnp.repeat(jnp.array([[jnp.nan,jnp.nan]]),len(cluster_allocs),axis=0)
    clusdata = jnp.where(jnp.concatenate((cluster_allocs_expanded,cluster_allocs_expanded),axis = 1) == h,data,nan_vec)
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    # NW distribution terms
    num_0 = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu, cov).log_prob(clusdata))
    den_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu_old, cov_old).log_prob(clusdata))
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term



@jit
def compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    # NW distribution terms
    num = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))
    
    return num  - den + sum_ + jac_term


@jit
def evaluate_NW_log(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = jnp.linalg.inv(phi_n)
    chol = jnp.linalg.cholesky(W) 
    inv_cov = jnp.linalg.inv(x_cov)

    f1 = jtfd.WishartTriL(df=nu_n.astype(float), scale_tril=chol).log_prob(inv_cov)
    #f1 = jtfd.WishartTriL(df=float(nu_n), scale_tril=chol).log_prob(inv_cov)
    f2 = jtfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

@jit
def compute_Wasserstein(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = jnp.linalg.norm(mu_1 - mu_2, ord = 2)
    
    #Compute square root of cov_2
    s = jnp.sqrt(jnp.linalg.det(cov_2))
    t = jnp.sqrt(jnp.trace(cov_2) + 2*s)
    sqrt_C2 = 1/t * (cov_2 + s*jnp.eye(2))
    
    C1_sqrt_C2 = jnp.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = jnp.matmul(sqrt_C2,C1_sqrt_C2)
    
    #Compute square root of sqrt_C2_C1_sqrt_C2
    s = jnp.sqrt(jnp.linalg.det(sqrt_C2_C1_sqrt_C2))
    t = jnp.sqrt(jnp.trace(sqrt_C2_C1_sqrt_C2) + 2*s)
    mat_sqrt = 1/t * (sqrt_C2_C1_sqrt_C2 + s*jnp.eye(2))
    
    trace = jnp.trace(cov_1 + cov_2 - 2 * mat_sqrt)

    # Function g
    return g(norm+trace) 

@jit
def update_weights(cluster_allocs, weights, k, alpha,key):

    key, subk = random.split(key)
    n_clus = len(weights)
    n_by_clus = jnp.array([jnp.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = jnp.ones(n_clus) * alpha + n_by_clus
    return jtfd.Dirichlet(post_params.astype(float)).sample(seed = subk),key
    #return jtfd.Dirichlet(post_params).sample(seed = subk),key

@jit
def update_cluster_allocs(data, weights, mus, covs,key):
    #print(weights)
    key, subk = random.split(key)
    logprobs = jtfd.MultivariateNormalFullCovariance(mus, covs).log_prob(data[:, jnp.newaxis])
    logprobs += jnp.log(weights)
    probs =  jnp.exp(logprobs)/(jnp.sum(jnp.exp(logprobs), axis=1))[:,None]
    return jtfd.Categorical(probs=probs, validate_args=True).sample(seed = subk),key

# %%
def run_one_gibbs(data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Run one gibbs sampler iteration
    Takes in input values of the previous iteration and sample the new values from sample_uniq_vals_fullcond, update_weights and update_cluster_allocs
    Returns:   
    
    -cluster_allocs: for every data point, the cluster assigned
    -uniq_vals: array of parameters of the distributions. Matrix has d rows of the type:[mu[0], var[0,0], var[0,1]]
    -weights: array with the weights of the clusters 
     """
    key, subk = random.split(key)
    n_clus = len(weights)
    for h in range(n_clus):

        #Extract data assigned to cluster h and sample 
        clusdata = data[cluster_allocs == h]
        if(len(clusdata) != 0):
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,tau,key)
        else:
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,tau,key)


    weights,key = update_weights(cluster_allocs ,weights, k, alpha,key)

    cluster_allocs,key = update_cluster_allocs(data, weights, mus,covs,key)

    return cluster_allocs, mus,covs, weights, acc_rate,key

def run_mcmc(data, k, key , niter=1000, nburn=300, thin=5 ): 
    """
    Runs entire MCMC
    Takes in input data, number of clusters, number of iterations, burn-in and thin
    Returns the parameters recorded after burn-in phase
    """

    b = time.time() # only to measure time
    
    #Bijector setup
    jtfb = jtfp.bijectors
    bij = jtfb.Chain([
            jtfb.TransformDiagonal(jtfb.Softplus()),
            jtfb.FillTriangular()])

    #Starting Values
    cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
    weights = jnp.ones(k)/k
    alpha = 0.1
    lam = 0.1
    mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.eye(2) ).sample(k,seed = key))
    covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(2)) ).sample(k,seed = key))
    
    #Proposal Covariances
    tau = 0.0001
    cov_prop_cov = jnp.sqrt(2*tau)*jnp.eye(3) #covariance matrix for the covariance sampling
    cov_prop_mu =  jnp.sqrt(2*tau)*jnp.eye(2)   #covariance matrix for the mean sampling
#     cov_prop_cov = np.power(tau,1/4)*jnp.eye(3) #covariance matrix for the covariance sampling
#     cov_prop_mu =  np.power(tau,1/4)*jnp.eye(2)   #covariance matrix for the mean sampling
   
    
    #Output values
    allocs_out = []
    mus_out = []
    covs_out = []
    weights_out = []
    acc_rates = []
    
    #Useful value
    data_mean = np.mean(data, axis = 0)
    
    #Iterations
    for i in range(niter):
        cluster_allocs, mus,covs, weights, acc_rate,key = run_one_gibbs(
            data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,tau,key)
        acc_rates.append(acc_rate)
        
        if i > nburn and i % thin == 0:
            allocs_out.append(cluster_allocs)
            mus_out.append(mus.copy())
            covs_out.append(covs.copy())
            weights_out.append(weights)
            
        if i % 10 == 0 and i > 11:
            a = time.time()
            print("\rIter {0} / {1}".format(i+1, niter) + " Remaining minutes: " + str(round((a-b)*(niter-i)/(60*10) ,1)) , flush=False, end=" ")
            b = time.time()
            print("Acceptance rate: " + str(np.mean(acc_rates[-10:])))
            
    return allocs_out, mus_out,covs_out, weights_out,acc_rates

# %%
#RUNNING THE MCMC
grad_out = []
covs_out_ = []
mus_out_ = []
h_out = []
start = time.time()
allocs_out, mus_out,covs_out, weights_out,accept_rate_out = run_mcmc(data, k,rng_key , niter = 6000,nburn = 4000,thin = 5)
end = time.time()
print("Total time: " + str(end-start))
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:3556: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# Iter 21 / 6000 Remaining minutes: 16.0 Acceptance rate: 0.33849263
# Iter 31 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.42632622
# Iter 41 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.13239904
# Iter 51 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.35410145
# Iter 61 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.20741232
# Iter 71 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.18874213
# Iter 81 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.057536114
# Iter 91 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.48696774
# Iter 101 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.51632655
# Iter 111 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.33328658
# Iter 121 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.4037633
# Iter 131 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.3007706
# Iter 141 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.13479584
# Iter 151 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.26730162
# Iter 161 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.3322958
# Iter 171 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.20042534
# Iter 181 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.470726
# Iter 191 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.062099956
# Iter 201 / 6000 Remaining minutes: 1.2 Acceptance rate: 0.035397805
# Iter 211 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.14848763
# Iter 221 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.12313981
# Iter 231 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.21421905
# Iter 241 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.11420707
# Iter 251 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.19144423
# Iter 261 / 6000 Remaining minutes: 1.2 Acceptance rate: 0.048648275
# Iter 271 / 6000 Remaining minutes: 2.3 Acceptance rate: 0.06824599
# Iter 281 / 6000 Remaining minutes: 2.2 Acceptance rate: 0.025893372
# Iter 291 / 6000 Remaining minutes: 2.0 Acceptance rate: 0.1498281
# Iter 301 / 6000 Remaining minutes: 1.7 Acceptance rate: 0.12949042
# Iter 311 / 6000 Remaining minutes: 1.8 Acceptance rate: 0.109423205
# Iter 321 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.0026751326
# Iter 331 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.20047334
# Iter 341 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.031655177
# Iter 351 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.15114133
# Iter 361 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.10671099
# Iter 371 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.04056392
# Iter 381 / 6000 Remaining minutes: 1.9 Acceptance rate: 0.0629459
# Iter 391 / 6000 Remaining minutes: 1.4 Acceptance rate: 0.13662599
# Iter 401 / 6000 Remaining minutes: 1.6 Acceptance rate: 0.04539115
# Iter 411 / 6000 Remaining minutes: 1.6 Acceptance rate: 0.06302992
# Iter 421 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.16545314
# Iter 431 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.09828426
# Iter 441 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.10130572
# Iter 451 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.028669303
# Iter 461 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.1053652
# Iter 471 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.13236067
# Iter 481 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.0024674535
# Iter 491 / 6000 Remaining minutes: 1.7 Acceptance rate: 0.10471523
# Iter 501 / 6000 Remaining minutes: 1.7 Acceptance rate: 0.20639046
# Iter 511 / 6000 Remaining minutes: 1.9 Acceptance rate: 0.08616428
# Iter 521 / 6000 Remaining minutes: 1.7 Acceptance rate: 0.16713816
# Iter 531 / 6000 Remaining minutes: 1.9 Acceptance rate: 0.16376899
# Iter 541 / 6000 Remaining minutes: 1.8 Acceptance rate: 0.028918412
# Iter 551 / 6000 Remaining minutes: 1.4 Acceptance rate: 0.022610396
# Iter 561 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.016939979
# Iter 571 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.04329575
# Iter 581 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.080216005
# Iter 591 / 6000 Remaining minutes: 0.8 Acceptance rate: 9.508933e-05
# Iter 601 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.22662398
# Iter 611 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.004882817
# Iter 621 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.0017067054
# Iter 631 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.032174252
# Iter 641 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.101329505
# Iter 651 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.023196764
# Iter 661 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.1459581
# Iter 671 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.13619265
# Iter 681 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.0625516
# Iter 691 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.020144222
# Iter 701 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.03442129
# Iter 711 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.008511351
# Iter 721 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.20354751
# Iter 731 / 6000 Remaining minutes: 2.1 Acceptance rate: 0.04956204
# Iter 741 / 6000 Remaining minutes: 1.8 Acceptance rate: 0.22252965
# Iter 751 / 6000 Remaining minutes: 1.2 Acceptance rate: 0.100252226
# Iter 761 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.027844647
# Iter 771 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.0349077
# Iter 781 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.014775634
# Iter 791 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.013660967
# Iter 801 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.051431824
# Iter 811 / 6000 Remaining minutes: 1.3 Acceptance rate: 0.024836456
# Iter 821 / 6000 Remaining minutes: 1.8 Acceptance rate: 0.019297719
# Iter 831 / 6000 Remaining minutes: 1.5 Acceptance rate: 0.113224946
# Iter 841 / 6000 Remaining minutes: 1.8 Acceptance rate: 0.03664608
# Iter 851 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.10109881
# Iter 861 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.105556525
# Iter 871 / 6000 Remaining minutes: 1.5 Acceptance rate: 0.002402385
# Iter 881 / 6000 Remaining minutes: 2.0 Acceptance rate: 0.004009663
# Iter 891 / 6000 Remaining minutes: 1.2 Acceptance rate: 0.015297988
# Iter 901 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.007672409
# Iter 911 / 6000 Remaining minutes: 1.5 Acceptance rate: 0.001966986
# Iter 921 / 6000 Remaining minutes: 2.2 Acceptance rate: 0.14738347
# Iter 931 / 6000 Remaining minutes: 1.6 Acceptance rate: 0.0030799555
# Iter 941 / 6000 Remaining minutes: 1.7 Acceptance rate: 0.042100552
# Iter 951 / 6000 Remaining minutes: 1.5 Acceptance rate: 0.017223552
# Iter 961 / 6000 Remaining minutes: 1.8 Acceptance rate: 0.069751814
# Iter 971 / 6000 Remaining minutes: 1.9 Acceptance rate: 0.016102564
# Iter 981 / 6000 Remaining minutes: 1.9 Acceptance rate: 0.11674559
# Iter 991 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.04775437
# Iter 1001 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.05534614
# Iter 1011 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.08773719
# Iter 1021 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.10437479
# Iter 1031 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.03419948
# Iter 1041 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.005056541
# Iter 1051 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.07197669
# Iter 1061 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.103047945
# Iter 1071 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.22057076
# Iter 1081 / 6000 Remaining minutes: 1.2 Acceptance rate: 0.0009033891
# Iter 1091 / 6000 Remaining minutes: 1.2 Acceptance rate: 0.012588846
# Iter 1101 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.0071329637
# Iter 1111 / 6000 Remaining minutes: 1.4 Acceptance rate: 0.0015481417
# Iter 1121 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.10342188
# Iter 1131 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.10507623
# Iter 1141 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.005511441
# Iter 1151 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.00845138
# Iter 1161 / 6000 Remaining minutes: 1.5 Acceptance rate: 0.015290287
# Iter 1171 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.16184615
# Iter 1181 / 6000 Remaining minutes: 0.8 Acceptance rate: 7.404048e-06
# Iter 1191 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.102514386
# Iter 1201 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.03157069
# Iter 1211 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.014285919
# Iter 1221 / 6000 Remaining minutes: 1.4 Acceptance rate: 0.10824509
# Iter 1231 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.021558102
# Iter 1241 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.19203576
# Iter 1251 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.15359965
# Iter 1261 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.12631509
# Iter 1271 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.071431234
# Iter 1281 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.104252085
# Iter 1291 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.011404549
# Iter 1301 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.020379793
# Iter 1311 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.010778424
# Iter 1321 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.10781431
# Iter 1331 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.11377007
# Iter 1341 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.0624318
# Iter 1351 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.16310073
# Iter 1361 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.28041083
# Iter 1371 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.22301297
# Iter 1381 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.27112085
# Iter 1391 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.06805658
# Iter 1401 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.17439009
# Iter 1411 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.045756154
# Iter 1421 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.11910083
# Iter 1431 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.012738317
# Iter 1441 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.09605321
# Iter 1451 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.30041298
# Iter 1461 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.100513995
# Iter 1471 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.030262638
# Iter 1481 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.051505517
# Iter 1491 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.0149260145
# Iter 1501 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.06100782
# Iter 1511 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.069954276
# Iter 1521 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.12729621
# Iter 1531 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.011976315
# Iter 1541 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.14843088
# Iter 1551 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.038919725
# Iter 1561 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.15000977
# Iter 1571 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.18402559
# Iter 1581 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.19034675
# Iter 1591 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.14310154
# Iter 1601 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.15250042
# Iter 1611 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.17427379
# Iter 1621 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.034633644
# Iter 1631 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.112610355
# Iter 1641 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.14609157
# Iter 1651 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.07434513
# Iter 1661 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.20563821
# Iter 1671 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.006886893
# Iter 1681 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.12128432
# Iter 1691 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.0016351346
# Iter 1701 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.0205713
# Iter 1711 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.080665685
# Iter 1721 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.05223163
# Iter 1731 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.013700398
# Iter 1741 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.18147047
# Iter 1751 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.15497664
# Iter 1761 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.04156646
# Iter 1771 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.028562367
# Iter 1781 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.056588627
# Iter 1791 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.12730595
# Iter 1801 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.1587277
# Iter 1811 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.0040635755
# Iter 1821 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.08160317
# Iter 1831 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.08288246
# Iter 1841 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.030186052
# Iter 1851 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.12350915
# Iter 1861 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.12067716
# Iter 1871 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.016977943
# Iter 1881 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.10242047
# Iter 1891 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.056206994
# Iter 1901 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.020194568
# Iter 1911 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.11671735
# Iter 1921 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.045478024
# Iter 1931 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.18738942
# Iter 1941 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.3751515
# Iter 1951 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.22378889
# Iter 1961 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.11745747
# Iter 1971 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.1829554
# Iter 1981 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.15509792
# Iter 1991 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.1752588
# Iter 2001 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.111490324
# Iter 2011 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.12100315
# Iter 2021 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.0343102
# Iter 2031 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.39342636
# Iter 2041 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.02543379
# Iter 2051 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.19651005
# Iter 2061 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.041163884
# Iter 2071 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.10799084
# Iter 2081 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.14473052
# Iter 2091 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.012853911
# Iter 2101 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.00077147817
# Iter 2111 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.015576939
# Iter 2121 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.1484887
# Iter 2131 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.3505763
# Iter 2141 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.02580599
# Iter 2151 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.10923654
# Iter 2161 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.17542589
# Iter 2171 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.12057874
# Iter 2181 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.12351544
# Iter 2191 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.0093340175
# Iter 2201 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.090960234
# Iter 2211 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.0028375469
# Iter 2221 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.10851149
# Iter 2231 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.013647589
# Iter 2241 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.115361236
# Iter 2251 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.19932097
# Iter 2261 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.14493655
# Iter 2271 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.0042704307
# Iter 2281 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.03436763
# Iter 2291 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.05041162
# Iter 2301 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.10329045
# Iter 2311 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.23441324
# Iter 2321 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.063849844
# Iter 2331 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.011621699
# Iter 2341 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.113056935
# Iter 2351 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.0045894203
# Iter 2361 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.20618737
# Iter 2371 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.027760427
# Iter 2381 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.100448385
# Iter 2391 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.10492711
# Iter 2401 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.11560347
# Iter 2411 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.0048004547
# Iter 2421 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.0017439288
# Iter 2431 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.10617381
# Iter 2441 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.15488362
# Iter 2451 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.03745416
# Iter 2461 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.14809448
# Iter 2471 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.13544722
# Iter 2481 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.2084268
# Iter 2491 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.012889278
# Iter 2501 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.021386394
# Iter 2511 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.0036899191
# Iter 2521 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.06478226
# Iter 2531 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.013560154
# Iter 2541 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.036783617
# Iter 2551 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.12777421
# Iter 2561 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.096588336
# Iter 2571 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.100825
# Iter 2581 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.20814066
# Iter 2591 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.033179495
# Iter 2601 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.124441065
# Iter 2611 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.011051454
# Iter 2621 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.10130469
# Iter 2631 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.016752427
# Iter 2641 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.24935023
# Iter 2651 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.20034444
# Iter 2661 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.0007010822
# Iter 2671 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.20241638
# Iter 2681 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.09444844
# Iter 2691 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.018836755
# Iter 2701 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.21409604
# Iter 2711 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.11647685
# Iter 2721 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.13443956
# Iter 2731 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.15506303
# Iter 2741 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.038861334
# Iter 2751 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.101086035
# Iter 2761 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.10313249
# Iter 2771 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.09444474
# Iter 2781 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.14465506
# Iter 2791 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.006370439
# Iter 2801 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.12837127
# Iter 2811 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.008583713
# Iter 2821 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.0143151805
# Iter 2831 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.03810423
# Iter 2841 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.111067235
# Iter 2851 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.101256624
# Iter 2861 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.14008202
# Iter 2871 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.13347933
# Iter 2881 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.17562297
# Iter 2891 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.170561
# Iter 2901 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.0014543828
# Iter 2911 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.015322569
# Iter 2921 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.27642825
# Iter 2931 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.009239127
# Iter 2941 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.028741661
# Iter 2951 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.13701817
# Iter 2961 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.10537501
# Iter 2971 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.013417738
# Iter 2981 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.05309602
# Iter 2991 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.1789768
# Iter 3001 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.07296471
# Iter 3011 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.018499559
# Iter 3021 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.19013739
# Iter 3031 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.12479415
# Iter 3041 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.040887993
# Iter 3051 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.0031193837
# Iter 3061 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.040424712
# Iter 3071 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.053046424
# Iter 3081 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.08143236
# Iter 3091 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.001103122
# Iter 3101 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.13749371
# Iter 3111 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.10811909
# Iter 3121 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.11569321
# Iter 3131 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.16978574
# Iter 3141 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.18422528
# Iter 3151 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.09061525
# Iter 3161 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.10975386
# Iter 3171 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.22564724
# Iter 3181 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.08751323
# Iter 3191 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.07393058
# Iter 3201 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.08791556
# Iter 3211 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.07289876
# Iter 3221 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.013588896
# Iter 3231 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.032054327
# Iter 3241 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.104870856
# Iter 3251 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.11954646
# Iter 3261 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.18742284
# Iter 3271 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.10507647
# Iter 3281 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.08525057
# Iter 3291 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.30759314
# Iter 3301 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.010007498
# Iter 3311 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.1452072
# Iter 3321 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.13342886
# Iter 3331 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.22579429
# Iter 3341 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.20049623
# Iter 3351 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.16104911
# Iter 3361 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.21352205
# Iter 3371 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.10277666
# Iter 3381 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.0056682145
# Iter 3391 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.017815225
# Iter 3401 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.017328043
# Iter 3411 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.06935604
# Iter 3421 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.013495749
# Iter 3431 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.079822585
# Iter 3441 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.02919292
# Iter 3451 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.00021487827
# Iter 3461 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.109984815
# Iter 3471 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.014954358
# Iter 3481 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.0012474607
# Iter 3491 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.042325653
# Iter 3501 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.10391267
# Iter 3511 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.1004644
# Iter 3521 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.0009981878
# Iter 3531 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.005461532
# Iter 3541 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.021977976
# Iter 3551 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.00075871317
# Iter 3561 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.027887335
# Iter 3571 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.13836351
# Iter 3581 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.003864685
# Iter 3591 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.03503948
# Iter 3601 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.1399238
# Iter 3611 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.13198106
# Iter 3621 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.07018502
# Iter 3631 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.121638335
# Iter 3641 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.034950595
# Iter 3651 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.10293625
# Iter 3661 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.008210425
# Iter 3671 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.012829201
# Iter 3681 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.0022279597
# Iter 3691 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.106453314
# Iter 3701 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.008427778
# Iter 3711 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.0015832253
# Iter 3721 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.029691283
# Iter 3731 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.0495197
# Iter 3741 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.07772909
# Iter 3751 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.14310053
# Iter 3761 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.09073839
# Iter 3771 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.03438553
# Iter 3781 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.03150554
# Iter 3791 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.0003930429
# Iter 3801 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.1510621
# Iter 3811 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.10531513
# Iter 3821 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.10858376
# Iter 3831 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.008356925
# Iter 3841 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.14711449
# Iter 3851 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.0044056685
# Iter 3861 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.022867847
# Iter 3871 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.10579054
# Iter 3881 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.02661084
# Iter 3891 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.066560164
# Iter 3901 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.015069601
# Iter 3911 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.04389786
# Iter 3921 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.007713534
# Iter 3931 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.15633984
# Iter 3941 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.22203302
# Iter 3951 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.24345417
# Iter 3961 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.10366131
# Iter 3971 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.029509332
# Iter 3981 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.014453622
# Iter 3991 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.02361973
# Iter 4001 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.088887334
# Iter 4011 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.010371758
# Iter 4021 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.003188727
# Iter 4031 / 6000 Remaining minutes: 0.3 Acceptance rate: 9.962167e-05
# Iter 4041 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.113897264
# Iter 4051 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.0587702
# Iter 4061 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.076105855
# Iter 4071 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.100749925
# Iter 4081 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.004326075
# Iter 4091 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0008157202
# Iter 4101 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0004337568
# Iter 4111 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.005423882
# Iter 4121 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.036113497
# Iter 4131 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.01527703
# Iter 4141 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.017273013
# Iter 4151 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.13473976
# Iter 4161 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.020185921
# Iter 4171 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.030023124
# Iter 4181 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.031911038
# Iter 4191 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.071358755
# Iter 4201 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.00873453
# Iter 4211 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.17032823
# Iter 4221 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.081220165
# Iter 4231 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.028791618
# Iter 4241 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.14281921
# Iter 4251 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.15133956
# Iter 4261 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0043096105
# Iter 4271 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.18053865
# Iter 4281 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.00013838793
# Iter 4291 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.01888474
# Iter 4301 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.043258883
# Iter 4311 / 6000 Remaining minutes: 0.2 Acceptance rate: 1.4652929e-05
# Iter 4321 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.10008879
# Iter 4331 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.17226097
# Iter 4341 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.00035920143
# Iter 4351 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.06650587
# Iter 4361 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.048060693
# Iter 4371 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.022553356
# Iter 4381 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0016147944
# Iter 4391 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.010882253
# Iter 4401 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.001295289
# Iter 4411 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.011747606
# Iter 4421 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.0062140874
# Iter 4431 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.008963185
# Iter 4441 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.10004246
# Iter 4451 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.0022922177
# Iter 4461 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.30058765
# Iter 4471 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.04515914
# Iter 4481 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.010636117
# Iter 4491 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.00488795
# Iter 4501 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.23106542
# Iter 4511 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.027847001
# Iter 4521 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.15310271
# Iter 4531 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0058718584
# Iter 4541 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.053476445
# Iter 4551 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.011397077
# Iter 4561 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.041618053
# Iter 4571 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.11400942
# Iter 4581 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0576796
# Iter 4591 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.014659722
# Iter 4601 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.00037366105
# Iter 4611 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.054019064
# Iter 4621 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.030796895
# Iter 4631 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.056652833
# Iter 4641 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.11768571
# Iter 4651 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.00351652
# Iter 4661 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.00062520907
# Iter 4671 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.1394285
# Iter 4681 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.022573624
# Iter 4691 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.039886568
# Iter 4701 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.024907783
# Iter 4711 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.0048491294
# Iter 4721 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.010169686
# Iter 4731 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.016990531
# Iter 4741 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.0032033199
# Iter 4751 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0008276265
# Iter 4761 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0637987
# Iter 4771 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0041889898
# Iter 4781 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.037166614
# Iter 4791 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0005370261
# Iter 4801 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.0064189695
# Iter 4811 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.053133577
# Iter 4821 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.00137301
# Iter 4831 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.39904597
# Iter 4841 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.06694958
# Iter 4851 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0013502635
# Iter 4861 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.013452068
# Iter 4871 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.11907303
# Iter 4881 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.0014170754
# Iter 4891 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.10454582
# Iter 4901 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.122554705
# Iter 4911 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.22622696
# Iter 4921 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.2868838
# Iter 4931 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.20877632
# Iter 4941 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.022173543
# Iter 4951 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0883558
# Iter 4961 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0036918907
# Iter 4971 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.07289959
# Iter 4981 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.0038433298
# Iter 4991 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.084667325
# Iter 5001 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.14132659
# Iter 5011 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.01652804
# Iter 5021 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.026963428
# Iter 5031 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.00483066
# Iter 5041 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.00921728
# Iter 5051 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.12394732
# Iter 5061 / 6000 Remaining minutes: 0.1 Acceptance rate: 2.8254173e-05
# Iter 5071 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.070768215
# Iter 5081 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.07899423
# Iter 5091 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.011289147
# Iter 5101 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.0003294446
# Iter 5111 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.03010934
# Iter 5121 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.018918667
# Iter 5131 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.100011334
# Iter 5141 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.07363189
# Iter 5151 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.011175885
# Iter 5161 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.061711036
# Iter 5171 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.10307785
# Iter 5181 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.00042215208
# Iter 5191 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.2396112
# Iter 5201 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.12774919
# Iter 5211 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.021756696
# Iter 5221 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.009267761
# Iter 5231 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.0039244015
# Iter 5241 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.13578317
# Iter 5251 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.093430385
# Iter 5261 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.14964202
# Iter 5271 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.16394863
# Iter 5281 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.10030933
# Iter 5291 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.0032177232
# Iter 5301 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.03973635
# Iter 5311 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.045884363
# Iter 5321 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.0014880876
# Iter 5331 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.032272346
# Iter 5341 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.03334416
# Iter 5351 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.008462861
# Iter 5361 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.25174192
# Iter 5371 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.18649352
# Iter 5381 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.0017649228
# Iter 5391 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.042231698
# Iter 5401 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.106608845
# Iter 5411 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.09450922
# Iter 5421 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.007088027
# Iter 5431 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.1671016
# Iter 5441 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.0066500963
# Iter 5451 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.15523127
# Iter 5461 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.10259086
# Iter 5471 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.15717153
# Iter 5481 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.0004860544
# Iter 5491 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.012448402
# Iter 5501 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.106849656
# Iter 5511 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.001808982
# Iter 5521 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.013071455
# Iter 5531 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.0038265432
# Iter 5541 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.033823542
# Iter 5551 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.16967049
# Iter 5561 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.00029544375
# Iter 5571 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.006197322
# Iter 5581 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.010678893
# Iter 5591 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.0032076635
# Iter 5601 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.17261243
# Iter 5611 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.10132804
# Iter 5621 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.20005345
# Iter 5631 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.20010439
# Iter 5641 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.0055759326
# Iter 5651 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.02171337
# Iter 5661 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.08255879
# Iter 5671 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.07365158
# Iter 5681 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.3074078
# Iter 5691 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.13513413
# Iter 5701 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.10421101
# Iter 5711 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.11791136
# Iter 5721 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.15052062
# Iter 5731 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.05993225
# Iter 5741 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.018214118
# Iter 5751 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.06456591
# Iter 5761 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.12884727
# Iter 5771 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.011546444
# Iter 5781 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.006413105
# Iter 5791 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.0032597154
# Iter 5801 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.024037715
# Iter 5811 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.28218395
# Iter 5821 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.10896454
# Iter 5831 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.034846596
# Iter 5841 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.16799238
# Iter 5851 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.13148448
# Iter 5861 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.032031335
# Iter 5871 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.17923898
# Iter 5881 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.11342641
# Iter 5891 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.008215792
# Iter 5901 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.028727707
# Iter 5911 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.03678996
# Iter 5921 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.01969364
# Iter 5931 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.11909443
# Iter 5941 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.008023566
# Iter 5951 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.0066674454
# Iter 5961 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.015798597
# Iter 5971 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.09479102
# Iter 5981 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.0013147615
# Iter 5991 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.013836903
# Total time: 60.65362095832825

# %%
yy = []
for i in range(len(allocs_out)):
    yy.append(len(np.unique(allocs_out[i])))

xx,cc = np.unique(yy,return_counts=True)
print(xx,cc)
plt.bar(xx,cc)
# Out:
# [5 6 7 8 9] [130 192  65  11   1]
# <BarContainer object of 5 artists>

# %%
for h in range(k):
    currd = data[allocs_out[-1] == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [mu[i][0] for mu in mus_out]
    second_comp = [mu[i][1] for mu in mus_out]

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__mu_x", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_mu_y", fontsize=16)

    plt.show()

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [covs[i][0,0] for covs in covs_out]
    second_comp = [covs[i][0,1] for covs in covs_out]
    third_comp = [covs[i][1,1] for covs in covs_out]

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__cov_xx", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_cov_xy", fontsize=16)
    
    axes[2].plot(np.arange(len(third_comp)), third_comp,)
    axes[2].set_title(str(i) + "_cov_yy", fontsize=16)

    plt.show()

# %%
def get_psm(clus_alloc_chain):
    """
    Returns the posterior similarity matrix, i.e.
        out[i, j] = P(c_i == c_j | all the rest)
    for each pair of observations
    """
    #Fare confronto tra colonna i e j della matrice e poi calcolare da li
    c_chain = np.vstack(clus_alloc_chain)
    out = np.zeros((c_chain.shape[1], c_chain.shape[1]))
    for i in range(c_chain.shape[1]):
        for j in range(c_chain.shape[1]):
            out[i,j] = np.sum(c_chain[:,i] == c_chain[:,j]) / c_chain.shape[0]
            
    return out


def minbinder_sample(clus_alloc_chain, psm):
    """
    Finds the iteration for which the Binder loss is minimized
    and returns the associated clustering
    """
    losses = np.zeros(len(clus_alloc_chain))
    c_chain = np.vstack(clus_alloc_chain)
    
    # You can either cycle through the iterations, or 
    # cycle through the entries in the PSM [i, j]
    # and vectorize the same operation for each iteration!
    
    mat = np.zeros( ( c_chain.shape[0], c_chain.shape[1]**2 ) )
    k = 0
    for i in range(c_chain.shape[1]):
        for j in range(c_chain.shape[1]):
            mat[:,k] = ( (c_chain[:,i] == c_chain[:,j]).astype(int) - psm[i,j] * np.ones(c_chain.shape[0]) ) **2
            k = k+1
    
    losses = np.sum(mat, axis = 1)
    
    best_iter = np.argmin(losses)
    return clus_alloc_chain[best_iter]



def unique_vals_given_clus(unique_vals_chain, clus_alloc_chain, best_clus,n_clus):
    #Finds the unique values associated to the best clusters obtained during MCMC
    
    c_allocs = np.stack(clus_alloc_chain)
    uniq_vals = np.stack(unique_vals_chain)
    means = uniq_vals[:, :, : , 0]
    variances = uniq_vals[:, :, : , 1:3]
    out1 = []
    out2 = []
    for h in range(n_clus):
        data_idx = np.where(best_clus == h)[0]
        uniq_vals_idx = c_allocs[:, data_idx] # -> Matrix [n_iter x n_data_in_clus]
        means_by_iter = np.empty((c_allocs.shape[0], len(data_idx),2))
        vars_by_iter = np.empty((c_allocs.shape[0], len(data_idx),2,2))
        for i in range(c_allocs.shape[0]):
            means_by_iter[i, :] = means[i,uniq_vals_idx[i,:],:]
            vars_by_iter[i, :] = variances[i,uniq_vals_idx[i,:]]

        avg_mean_by_iter = np.mean(means_by_iter , axis = 1)
        avg_var_by_iter = np.mean(vars_by_iter , axis = 1)
        
        muhat = np.mean(avg_mean_by_iter,axis=0)
        sigsqhat = np.mean(avg_var_by_iter,axis=0)
        out1.append(np.array(muhat))
        out2.append(np.array(sigsqhat))
    
    #If there are no points in certain clusters, the output would be full of NANs for the cluster. This gives problems
    #I replace the NANs with some 0
    for i in range(len(out1)):
        if(np.any(np.isnan(out1[i]))):
            out1[i] = np.zeros(shape = out1[i].shape)
        if(np.any(np.isnan(out2[i]))):
            out2[i] = np.eye(N = out2[i].shape[0])
    
        
    return out1,out2


psm = get_psm(allocs_out)
best_clus = minbinder_sample(allocs_out,psm)

uniq_vals_out = []
for n in range(len(mus_out)):
    mus = mus_out[n]
    covs = covs_out[n]
    arr = np.zeros(shape=(k,2,3))
    for i in range(k):
        mu = mus[i]
        cov = covs[i]
        arr[i,:,:] = np.array( [ [mu[0],cov[0,0],cov[0,1]] , [mu[1],cov[1,0],cov[1,1]] ])
    uniq_vals_out.append(arr)
    
mu_lis,var_lis = unique_vals_given_clus(uniq_vals_out, allocs_out, best_clus,k)
weights = np.sum(best_clus == np.arange(k)[:, np.newaxis], axis=1) / len(data)

# %%
for h in range(k):
    currd = data[best_clus == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])
