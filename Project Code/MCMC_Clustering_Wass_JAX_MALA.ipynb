# %%
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pandas as pd
import time
import scipy

#Separate import for numpy and jax.numpy to have major felxibility
import jax.numpy as jnp
import numpy as np
from jax import jit,lax,random,grad,vmap
from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions
from tensorflow_probability.substrates import jax as jtfp
jtfd = jtfp.distributions

np.random.seed(0)

# %%
#sampled_perturbed = np.load('Data/test4.npy')
sampled_perturbed = np.genfromtxt('Data/faithful.csv', delimiter=',')
data = sampled_perturbed[0 : 1000]
#DEFINING NUMBER OF CLUSTERS AND DIMENSION OF DATA
k = 15
d = 2
#Key to store for random generation
rng_key = random.PRNGKey(0)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
@jit
def g(x):
    """
    Diggle Graton Modulation Function
    """
    #Shape parameters
    r = 5
    gamma = 0.5
    asymptote = 5
    logic0 = jnp.logical_and(0 < x,x <= 1e-5)  
    logic1 = jnp.logical_and( 1e-5 < x,x <= r)          
    logic2 = r < x       
    logic3 = x <= 0
    return (logic0 * x + logic1*(1e-5 +  jnp.power((x-1e-5)/r,1/gamma)) + logic2)*asymptote + logic3*1e-10

@jit
def sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,key = sample_from_MALA(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,data,cluster_allocs,h,mus,covs,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key

  
@jit
def sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs,h,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein when the cluster
    is empty
    """
    
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,subk1 = sample_from_MALA_empty(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,mus,covs,h,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
   
@jit
def spd_matrix_sqrt(X):
    eigvals, eigvecs = jnp.linalg.eigh(X)
    return eigvecs @ jnp.diag(jnp.sqrt(eigvals)) @ eigvecs.T

spd_matrix_sqrt_vec = vmap(spd_matrix_sqrt)
trace_vec = vmap(jnp.trace)

@jit
def wasserstein_to_normals(mu, cov, other_mus, other_covs):
    mean_dist = jnp.sum((other_mus - mu) ** 2, axis=1)
    cov_sqrt = spd_matrix_sqrt(cov)
    weird_term = trace_vec(spd_matrix_sqrt_vec(
        jnp.matmul(cov_sqrt, jnp.matmul(other_covs, cov_sqrt))))
    return g(jnp.nan_to_num(mean_dist + (trace_vec(other_covs) + jnp.trace(cov) - 2 * weird_term)))

@jit
def sum_dist_to_others(mu, cov, mask, other_mus, other_covs):   
    all_dists = jnp.log(wasserstein_to_normals(mu, cov, other_mus, other_covs))
    return jnp.sum(all_dists * mask)


@jit
def TargetFullCondEmptyCluster(mu,cov,mask,mus,covs,bijector):   
    """
    The full conditional from which we sample using Metropolis Hastings, written in a JAX-differentiable way,in
    the case where the cluster is empty
    """
    
    cov = jnp.matmul(bijector.forward(cov),jnp.transpose(bijector.forward(cov)))
    covs = jnp.matmul(bijector.forward(covs),jnp.transpose(bijector.forward(covs),axes = [0,2,1]))
 
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    #Normal Wishart Term
    normal_wishart = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    
    #Wasserstein Term
    wass_dist = sum_dist_to_others(mu, cov, mask, mus, covs)
    return normal_wishart + wass_dist

@jit
def TargetFullCond(mu,cov,mask,h,cluster_allocs,data,mus,covs,bijector):   
    """
    The full conditional from which we sample using Metropolis Hastings, written in a JAX-differentiable way
    """
    
    cov = jnp.matmul(bijector.forward(cov),jnp.transpose(bijector.forward(cov)))
    covs = jnp.matmul(bijector.forward(covs),jnp.transpose(bijector.forward(covs),axes = [0,2,1]))
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    #Normal Wishart Term
    normal_wishart = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)

    #Data Term
    normal_data = jnp.sum(jnp.where(cluster_allocs == h,jtfd.MultivariateNormalFullCovariance(mu, cov).log_prob(data),0))
    
    #Wasserstein Term
    wass_dist = sum_dist_to_others(mu, cov, mask, mus, covs)
    
    return normal_data + wass_dist + normal_wishart


@jit
def sample_from_MALA(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,data,cluster_allocs,h,mus,covs,bijector,key):
    """
    Sample new mean and covariance matrix through the bijection using MALA proposal
    """
    key , subk1 , subk2 = random.split(key,3)
    
    #Compute gradients of log wrt mu and cov
    mask = jnp.ones(mus.shape[0])
    mask.at[h].set(0.0)
    mask = jnp.array(mask)
    
    cov_old_vec = bijector.inverse(jnp.linalg.cholesky(cov_old))
    covs_vec = bijector.inverse(jnp.linalg.cholesky(covs))
     
    grad_log_mu,grad_log_cov = grad(TargetFullCond,argnums=[0,1])(mu_old,cov_old_vec,mask,h,cluster_allocs,data,mus,covs_vec,bijector)
    grad_out.append(grad_log_cov)

    #Compute mu proposal
    mu_mean = mu_old + tau*grad_log_mu
    mu = jtfd.MultivariateNormalFullCovariance(mu_mean, cov_prop_mu).sample(seed = subk1)
    
    #Compute cov proposal
    cov_mean_vec = cov_old_vec + tau*grad_log_cov
    
    vec_sampl = jtfd.MultivariateNormalFullCovariance(cov_mean_vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    


    return mu,cov,log_jac,key



@jit
def sample_from_MALA_empty(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,mus,covs,h,bijector,key):
    """
    Sample new mean and covariance matrix through the bijection using MALA proposal, in the case where cluster 
    is empty
    """
    key , subk1 , subk2 = random.split(key,3)
    
    #Compute gradients of log wrt mu and cov
    mask = jnp.ones(mus.shape[0])
    mask.at[h].set(0.0)
    mask = jnp.array(mask)
    
    cov_old_vec = bijector.inverse(jnp.linalg.cholesky(cov_old))
    covs_vec = bijector.inverse(jnp.linalg.cholesky(covs))
 
    
    grad_log_mu,grad_log_cov = grad(TargetFullCondEmptyCluster,argnums=[0,1])(mu_old,cov_old_vec,mask,mus,covs_vec,bijector)

    #Compute mu proposal
    mu_mean = mu_old + tau*grad_log_mu
    mu = jtfd.MultivariateNormalFullCovariance(mu_mean, cov_prop_mu).sample(seed = subk1)
    
    #Compute cov proposal
    cov_mean_vec = cov_old_vec + tau*grad_log_cov
    
    vec_sampl = jtfd.MultivariateNormalFullCovariance(cov_mean_vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    


    
    return mu,cov,log_jac,key



@jit
def compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    cluster_allocs_expanded = jnp.expand_dims(cluster_allocs,axis = 1)
    nan_vec = jnp.repeat(jnp.array([[jnp.nan,jnp.nan]]),len(cluster_allocs),axis=0)
    clusdata = jnp.where(jnp.concatenate((cluster_allocs_expanded,cluster_allocs_expanded),axis = 1) == h,data,nan_vec)
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    # NW distribution terms
    num_0 = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu, cov).log_prob(clusdata))
    den_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu_old, cov_old).log_prob(clusdata))
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term



@jit
def compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    # NW distribution terms
    num = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))
    
    return num  - den + sum_ + jac_term


@jit
def evaluate_NW_log(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = jnp.linalg.inv(phi_n)
    chol = jnp.linalg.cholesky(W) 
    inv_cov = jnp.linalg.inv(x_cov)

    f1 = jtfd.WishartTriL(df=nu_n.astype(float), scale_tril=chol).log_prob(inv_cov)
    #f1 = jtfd.WishartTriL(df=float(nu_n), scale_tril=chol).log_prob(inv_cov)
    f2 = jtfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

@jit
def compute_Wasserstein(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = jnp.linalg.norm(mu_1 - mu_2, ord = 2)
    
    #Compute square root of cov_2
    s = jnp.sqrt(jnp.linalg.det(cov_2))
    t = jnp.sqrt(jnp.trace(cov_2) + 2*s)
    sqrt_C2 = 1/t * (cov_2 + s*jnp.eye(2))
    
    C1_sqrt_C2 = jnp.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = jnp.matmul(sqrt_C2,C1_sqrt_C2)
    
    #Compute square root of sqrt_C2_C1_sqrt_C2
    s = jnp.sqrt(jnp.linalg.det(sqrt_C2_C1_sqrt_C2))
    t = jnp.sqrt(jnp.trace(sqrt_C2_C1_sqrt_C2) + 2*s)
    mat_sqrt = 1/t * (sqrt_C2_C1_sqrt_C2 + s*jnp.eye(2))
    
    trace = jnp.trace(cov_1 + cov_2 - 2 * mat_sqrt)

    # Function g
    return g(norm+trace) 

@jit
def update_weights(cluster_allocs, weights, k, alpha,key):

    key, subk = random.split(key)
    n_clus = len(weights)
    n_by_clus = jnp.array([jnp.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = jnp.ones(n_clus) * alpha + n_by_clus
    return jtfd.Dirichlet(post_params.astype(float)).sample(seed = subk),key
    #return jtfd.Dirichlet(post_params).sample(seed = subk),key

@jit
def update_cluster_allocs(data, weights, mus, covs,key):
    #print(weights)
    key, subk = random.split(key)
    logprobs = jtfd.MultivariateNormalFullCovariance(mus, covs).log_prob(data[:, jnp.newaxis])
    logprobs += jnp.log(weights)
    probs =  jnp.exp(logprobs)/(jnp.sum(jnp.exp(logprobs), axis=1))[:,None]
    return jtfd.Categorical(probs=probs, validate_args=True).sample(seed = subk),key

# %%
def run_one_gibbs(data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Run one gibbs sampler iteration
    Takes in input values of the previous iteration and sample the new values from sample_uniq_vals_fullcond, update_weights and update_cluster_allocs
    Returns:   
    
    -cluster_allocs: for every data point, the cluster assigned
    -uniq_vals: array of parameters of the distributions. Matrix has d rows of the type:[mu[0], var[0,0], var[0,1]]
    -weights: array with the weights of the clusters 
     """
    key, subk = random.split(key)
    n_clus = len(weights)
    for h in range(n_clus):

        #Extract data assigned to cluster h and sample 
        clusdata = data[cluster_allocs == h]
        if(len(clusdata) != 0):
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,tau,key)
        else:
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,tau,key)


    weights,key = update_weights(cluster_allocs ,weights, k, alpha,key)

    cluster_allocs,key = update_cluster_allocs(data, weights, mus,covs,key)

    return cluster_allocs, mus,covs, weights, acc_rate,key

def run_mcmc(data, k, key , niter=1000, nburn=300, thin=5 ): 
    """
    Runs entire MCMC
    Takes in input data, number of clusters, number of iterations, burn-in and thin
    Returns the parameters recorded after burn-in phase
    """

    b = time.time() # only to measure time
    
    #Bijector setup
    jtfb = jtfp.bijectors
    bij = jtfb.Chain([
            jtfb.TransformDiagonal(jtfb.Softplus()),
            jtfb.FillTriangular()])

    #Starting Values
    cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
    weights = jnp.ones(k)/k
    alpha = 0.1
    lam = 0.1
    mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.eye(2) ).sample(k,seed = key))
    covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(2)) ).sample(k,seed = key))
    
    #Proposal Covariances
    tau = 0.0001
    cov_prop_cov = jnp.sqrt(2*tau)*jnp.eye(3) #covariance matrix for the covariance sampling
    cov_prop_mu =  jnp.sqrt(2*tau)*jnp.eye(2)   #covariance matrix for the mean sampling
#     cov_prop_cov = np.power(tau,1/4)*jnp.eye(3) #covariance matrix for the covariance sampling
#     cov_prop_mu =  np.power(tau,1/4)*jnp.eye(2)   #covariance matrix for the mean sampling
   
    
    #Output values
    allocs_out = []
    mus_out = []
    covs_out = []
    weights_out = []
    acc_rates = []
    
    #Useful value
    data_mean = np.mean(data, axis = 0)
    
    #Iterations
    for i in range(niter):
        cluster_allocs, mus,covs, weights, acc_rate,key = run_one_gibbs(
            data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,tau,key)
        acc_rates.append(acc_rate)
        
        if i > nburn and i % thin == 0:
            allocs_out.append(cluster_allocs)
            mus_out.append(mus.copy())
            covs_out.append(covs.copy())
            weights_out.append(weights)
            
        if i % 10 == 0 and i > 11:
            a = time.time()
            print("\rIter {0} / {1}".format(i+1, niter) + " Remaining minutes: " + str(round((a-b)*(niter-i)/(60*10) ,1)) , flush=False, end=" ")
            b = time.time()
            print("Acceptance rate: " + str(np.mean(acc_rates[-10:])))
            
    return allocs_out, mus_out,covs_out, weights_out,acc_rates

# %%
#RUNNING THE MCMC
grad_out = []
covs_out_ = []
mus_out_ = []
h_out = []
start = time.time()
allocs_out, mus_out,covs_out, weights_out,accept_rate_out = run_mcmc(data, k,rng_key , niter = 4000,nburn = 1000,thin = 5)
end = time.time()
print("Total time: " + str(end-start))
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:3556: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# skip assert _assert_compare_to_zero
# skip assert _assert_near
# Iter 21 / 4000 Remaining minutes: 281.0 Acceptance rate: 0.92645395
# Iter 31 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.50391006
# Iter 41 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.57698447
# Iter 51 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9002101
# Iter 61 / 4000 Remaining minutes: 0.5 Acceptance rate: 0.96818054
# Iter 71 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.7188595
# Iter 81 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.8309727
# Iter 91 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.87222433
# Iter 101 / 4000 Remaining minutes: 0.5 Acceptance rate: 0.8807619
# Iter 111 / 4000 Remaining minutes: 0.5 Acceptance rate: 0.94303906
# Iter 121 / 4000 Remaining minutes: 0.5 Acceptance rate: 0.9489155
# Iter 131 / 4000 Remaining minutes: 0.5 Acceptance rate: 0.9491466
# Iter 141 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.90354884
# Iter 151 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.8885042
# Iter 161 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9711981
# Iter 171 / 4000 Remaining minutes: 0.5 Acceptance rate: 0.9288502
# Iter 181 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.92795247
# Iter 191 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.8831278
# Iter 201 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9607145
# Iter 211 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9102085
# Iter 221 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.95859116
# Iter 231 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.95598793
# Iter 241 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.97711354
# Iter 251 / 4000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 261 / 4000 Remaining minutes: 1.1 Acceptance rate: 1.0
# Iter 271 / 4000 Remaining minutes: 0.8 Acceptance rate: 0.97768354
# Iter 281 / 4000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 291 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9941486
# Iter 301 / 4000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 311 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9904622
# Iter 321 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9816519
# Iter 331 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9768961
# Iter 341 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9305847
# Iter 351 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.91291314
# Iter 361 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.80189264
# Iter 371 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.8508951
# Iter 381 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.965717
# Iter 391 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.8828352
# Iter 401 / 4000 Remaining minutes: 0.5 Acceptance rate: 0.8713007
# Iter 411 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.89781284
# Iter 421 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9817408
# Iter 431 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9733399
# Iter 441 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9127922
# Iter 451 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9582709
# Iter 461 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.946188
# Iter 471 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9004332
# Iter 481 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9935873
# Iter 491 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9899275
# Iter 501 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9755438
# Iter 511 / 4000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 521 / 4000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 531 / 4000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 541 / 4000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 551 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.96351993
# Iter 561 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.93120986
# Iter 571 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.97898597
# Iter 581 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9230324
# Iter 591 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.71694005
# Iter 601 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.73721665
# Iter 611 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9771864
# Iter 621 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.98970586
# Iter 631 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.993729
# Iter 641 / 4000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 651 / 4000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 661 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.99308836
# Iter 671 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9769977
# Iter 681 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.99903315
# Iter 691 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9890808
# Iter 701 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.97517776
# Iter 711 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.8929871
# Iter 721 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9830505
# Iter 731 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9766917
# Iter 741 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.89014673
# Iter 751 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.90903866
# Iter 761 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.81412107
# Iter 771 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.97141516
# Iter 781 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9684726
# Iter 791 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.935993
# Iter 801 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.93718654
# Iter 811 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.8782862
# Iter 821 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9261004
# Iter 831 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.94863683
# Iter 841 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9278432
# Iter 851 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.8507844
# Iter 861 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.89298105
# Iter 871 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.90648353
# Iter 881 / 4000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 891 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9269765
# Iter 901 / 4000 Remaining minutes: 0.8 Acceptance rate: 0.96518534
# Iter 911 / 4000 Remaining minutes: 0.8 Acceptance rate: 0.93512964
# Iter 921 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9790083
# Iter 931 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9608324
# Iter 941 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9145937
# Iter 951 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9499653
# Iter 961 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.944849
# Iter 971 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9249296
# Iter 981 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9464301
# Iter 991 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9836354
# Iter 1001 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1011 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9523083
# Iter 1021 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.8722418
# Iter 1031 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.78785574
# Iter 1041 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.6772728
# Iter 1051 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.826797
# Iter 1061 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.6818937
# Iter 1071 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.78172976
# Iter 1081 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.8609476
# Iter 1091 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.8934833
# Iter 1101 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.98217785
# Iter 1111 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.7898654
# Iter 1121 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.8280652
# Iter 1131 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.6530476
# Iter 1141 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9436078
# Iter 1151 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.89121705
# Iter 1161 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.8773885
# Iter 1171 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.7399189
# Iter 1181 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.7862388
# Iter 1191 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.72209656
# Iter 1201 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.7489032
# Iter 1211 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.84717333
# Iter 1221 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.898399
# Iter 1231 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.848886
# Iter 1241 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.763595
# Iter 1251 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.7199194
# Iter 1261 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.6322361
# Iter 1271 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.8817433
# Iter 1281 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1291 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9593673
# Iter 1301 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9114615
# Iter 1311 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.96281815
# Iter 1321 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.885616
# Iter 1331 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.8799898
# Iter 1341 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.8930439
# Iter 1351 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.96872056
# Iter 1361 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9384707
# Iter 1371 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.922392
# Iter 1381 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9028328
# Iter 1391 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1401 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9968964
# Iter 1411 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1421 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.98670006
# Iter 1431 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1441 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1451 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1461 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1471 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1481 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1491 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1501 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1511 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.952037
# Iter 1521 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1531 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1541 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9779552
# Iter 1551 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1561 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1571 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1581 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1591 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1601 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1611 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.99451697
# Iter 1621 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1631 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1641 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1651 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9999426
# Iter 1661 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1671 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1681 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1691 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9224993
# Iter 1701 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1711 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1721 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1731 / 4000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 1741 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1751 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1761 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1771 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9917191
# Iter 1781 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9568407
# Iter 1791 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9087985
# Iter 1801 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1811 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9255425
# Iter 1821 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9541033
# Iter 1831 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1841 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1851 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.99231386
# Iter 1861 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9506229
# Iter 1871 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9349971
# Iter 1881 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.989627
# Iter 1891 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9678863
# Iter 1901 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1911 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1921 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1931 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1941 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1951 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1961 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1971 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1981 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9848914
# Iter 1991 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9902762
# Iter 2001 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9926795
# Iter 2011 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.8865646
# Iter 2021 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.95128995
# Iter 2031 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.8829096
# Iter 2041 / 4000 Remaining minutes: 0.4 Acceptance rate: 0.9956024
# Iter 2051 / 4000 Remaining minutes: 0.3 Acceptance rate: 0.9507278
# Iter 2061 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.94017303
# Iter 2071 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.94253016
# Iter 2081 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9534666
# Iter 2091 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9632489
# Iter 2101 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9373778
# Iter 2111 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.92740077
# Iter 2121 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.94368494
# Iter 2131 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.89374113
# Iter 2141 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.8879744
# Iter 2151 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.96120656
# Iter 2161 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.97623396
# Iter 2171 / 4000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 2181 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.96797866
# Iter 2191 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9363478
# Iter 2201 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9685036
# Iter 2211 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.88428086
# Iter 2221 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9430841
# Iter 2231 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.97966987
# Iter 2241 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9632292
# Iter 2251 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.8820089
# Iter 2261 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.849483
# Iter 2271 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.94450504
# Iter 2281 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.92649305
# Iter 2291 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9097477
# Iter 2301 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.95236015
# Iter 2311 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.7982882
# Iter 2321 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.949093
# Iter 2331 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9623502
# Iter 2341 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9026947
# Iter 2351 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9850416
# Iter 2361 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9273963
# Iter 2371 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.88904727
# Iter 2381 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.89968604
# Iter 2391 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.8672557
# Iter 2401 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9680203
# Iter 2411 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9618147
# Iter 2421 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.98993623
# Iter 2431 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9418233
# Iter 2441 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9579881
# Iter 2451 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9198402
# Iter 2461 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.8668731
# Iter 2471 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9733366
# Iter 2481 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9124751
# Iter 2491 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.82359296
# Iter 2501 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.955815
# Iter 2511 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9284868
# Iter 2521 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.8655222
# Iter 2531 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.90254056
# Iter 2541 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9597456
# Iter 2551 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9273812
# Iter 2561 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.9307914
# Iter 2571 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.89833146
# Iter 2581 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.8982929
# Iter 2591 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.82195985
# Iter 2601 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9422817
# Iter 2611 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9162475
# Iter 2621 / 4000 Remaining minutes: 0.2 Acceptance rate: 0.86938953
# Iter 2631 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.95029956
# Iter 2641 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.90144795
# Iter 2651 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.91255987
# Iter 2661 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.84826076
# Iter 2671 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9736301
# Iter 2681 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9477124
# Iter 2691 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.8760419
# Iter 2701 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.89440364
# Iter 2711 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.884359
# Iter 2721 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9443308
# Iter 2731 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9485283
# Iter 2741 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.8838049
# Iter 2751 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.8148907
# Iter 2761 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.8135599
# Iter 2771 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.867832
# Iter 2781 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9005785
# Iter 2791 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.92337006
# Iter 2801 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9198923
# Iter 2811 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9098282
# Iter 2821 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.8969842
# Iter 2831 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.97367334
# Iter 2841 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9818279
# Iter 2851 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9790904
# Iter 2861 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9110087
# Iter 2871 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9270155
# Iter 2881 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.97815883
# Iter 2891 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.86212766
# Iter 2901 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.96104443
# Iter 2911 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9667799
# Iter 2921 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.94588596
# Iter 2931 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9689053
# Iter 2941 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9517657
# Iter 2951 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9931474
# Iter 2961 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9781753
# Iter 2971 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9777791
# Iter 2981 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.97630167
# Iter 2991 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.976762
# Iter 3001 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9916053
# Iter 3011 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9655181
# Iter 3021 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9557759
# Iter 3031 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9849866
# Iter 3041 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.99478656
# Iter 3051 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9949258
# Iter 3061 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3071 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9876164
# Iter 3081 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9751929
# Iter 3091 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.90849763
# Iter 3101 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.920545
# Iter 3111 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.96135026
# Iter 3121 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9812685
# Iter 3131 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9722845
# Iter 3141 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9545499
# Iter 3151 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.96024483
# Iter 3161 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9637164
# Iter 3171 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9600129
# Iter 3181 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3191 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3201 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3211 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3221 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3231 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3241 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3251 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9235428
# Iter 3261 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9591023
# Iter 3271 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.73170006
# Iter 3281 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3291 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9106285
# Iter 3301 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.8473379
# Iter 3311 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9505965
# Iter 3321 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.96755236
# Iter 3331 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3341 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3351 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3361 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.94828445
# Iter 3371 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.95270693
# Iter 3381 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.77975285
# Iter 3391 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.86465615
# Iter 3401 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3411 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3421 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3431 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3441 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9061564
# Iter 3451 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.99378806
# Iter 3461 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.8776307
# Iter 3471 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9179584
# Iter 3481 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.98612654
# Iter 3491 / 4000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 3501 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.9977043
# Iter 3511 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.99735624
# Iter 3521 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3531 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9395555
# Iter 3541 / 4000 Remaining minutes: 0.1 Acceptance rate: 0.99862844
# Iter 3551 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9190556
# Iter 3561 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3571 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3581 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3591 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9634553
# Iter 3601 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3611 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3621 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.98429835
# Iter 3631 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.958646
# Iter 3641 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9741235
# Iter 3651 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9845853
# Iter 3661 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.98831385
# Iter 3671 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9993719
# Iter 3681 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.99440956
# Iter 3691 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.96173203
# Iter 3701 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3711 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9583484
# Iter 3721 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.97912073
# Iter 3731 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9758229
# Iter 3741 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3751 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3761 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9045024
# Iter 3771 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.8796089
# Iter 3781 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.8885256
# Iter 3791 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9820598
# Iter 3801 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.83705175
# Iter 3811 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9286868
# Iter 3821 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3831 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.8390673
# Iter 3841 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.835193
# Iter 3851 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9251601
# Iter 3861 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3871 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9635332
# Iter 3881 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.8904303
# Iter 3891 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.97995776
# Iter 3901 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3911 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3921 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.99631184
# Iter 3931 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3941 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3951 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3961 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9831111
# Iter 3971 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3981 / 4000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 3991 / 4000 Remaining minutes: 0.0 Acceptance rate: 0.9406475
# Total time: 68.94343280792236

# %%
yy = []
for i in range(len(allocs_out)):
    yy.append(len(np.unique(allocs_out[i])))

xx,cc = np.unique(yy,return_counts=True)
print(xx,cc)
plt.bar(xx,cc)
# Out:
# [4 5 6] [529  64   6]
# <BarContainer object of 3 artists>

# %%
for h in range(k):
    currd = data[allocs_out[-1] == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [mu[i][0] for mu in mus_out]
    second_comp = [mu[i][1] for mu in mus_out]

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__mu_x", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_mu_y", fontsize=16)

    plt.show()

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [covs[i][0,0] for covs in covs_out]
    second_comp = [covs[i][0,1] for covs in covs_out]
    third_comp = [covs[i][1,1] for covs in covs_out]

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__cov_xx", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_cov_xy", fontsize=16)
    
    axes[2].plot(np.arange(len(third_comp)), third_comp,)
    axes[2].set_title(str(i) + "_cov_yy", fontsize=16)

    plt.show()

# %%
def get_psm(clus_alloc_chain):
    """
    Returns the posterior similarity matrix, i.e.
        out[i, j] = P(c_i == c_j | all the rest)
    for each pair of observations
    """
    #Fare confronto tra colonna i e j della matrice e poi calcolare da li
    c_chain = np.vstack(clus_alloc_chain)
    out = np.zeros((c_chain.shape[1], c_chain.shape[1]))
    for i in range(c_chain.shape[1]):
        for j in range(c_chain.shape[1]):
            out[i,j] = np.sum(c_chain[:,i] == c_chain[:,j]) / c_chain.shape[0]
            
    return out


def minbinder_sample(clus_alloc_chain, psm):
    """
    Finds the iteration for which the Binder loss is minimized
    and returns the associated clustering
    """
    losses = np.zeros(len(clus_alloc_chain))
    c_chain = np.vstack(clus_alloc_chain)
    
    # You can either cycle through the iterations, or 
    # cycle through the entries in the PSM [i, j]
    # and vectorize the same operation for each iteration!
    
    mat = np.zeros( ( c_chain.shape[0], c_chain.shape[1]**2 ) )
    k = 0
    for i in range(c_chain.shape[1]):
        for j in range(c_chain.shape[1]):
            mat[:,k] = ( (c_chain[:,i] == c_chain[:,j]).astype(int) - psm[i,j] * np.ones(c_chain.shape[0]) ) **2
            k = k+1
    
    losses = np.sum(mat, axis = 1)
    
    best_iter = np.argmin(losses)
    return clus_alloc_chain[best_iter]



def unique_vals_given_clus(unique_vals_chain, clus_alloc_chain, best_clus,n_clus):
    #Finds the unique values associated to the best clusters obtained during MCMC
    
    c_allocs = np.stack(clus_alloc_chain)
    uniq_vals = np.stack(unique_vals_chain)
    means = uniq_vals[:, :, : , 0]
    variances = uniq_vals[:, :, : , 1:3]
    out1 = []
    out2 = []
    for h in range(n_clus):
        data_idx = np.where(best_clus == h)[0]
        uniq_vals_idx = c_allocs[:, data_idx] # -> Matrix [n_iter x n_data_in_clus]
        means_by_iter = np.empty((c_allocs.shape[0], len(data_idx),2))
        vars_by_iter = np.empty((c_allocs.shape[0], len(data_idx),2,2))
        for i in range(c_allocs.shape[0]):
            means_by_iter[i, :] = means[i,uniq_vals_idx[i,:],:]
            vars_by_iter[i, :] = variances[i,uniq_vals_idx[i,:]]

        avg_mean_by_iter = np.mean(means_by_iter , axis = 1)
        avg_var_by_iter = np.mean(vars_by_iter , axis = 1)
        
        muhat = np.mean(avg_mean_by_iter,axis=0)
        sigsqhat = np.mean(avg_var_by_iter,axis=0)
        out1.append(np.array(muhat))
        out2.append(np.array(sigsqhat))
    
    #If there are no points in certain clusters, the output would be full of NANs for the cluster. This gives problems
    #I replace the NANs with some 0
    for i in range(len(out1)):
        if(np.any(np.isnan(out1[i]))):
            out1[i] = np.zeros(shape = out1[i].shape)
        if(np.any(np.isnan(out2[i]))):
            out2[i] = np.eye(N = out2[i].shape[0])
    
        
    return out1,out2


psm = get_psm(allocs_out)
best_clus = minbinder_sample(allocs_out,psm)

uniq_vals_out = []
for n in range(len(mus_out)):
    mus = mus_out[n]
    covs = covs_out[n]
    arr = np.zeros(shape=(k,2,3))
    for i in range(k):
        mu = mus[i]
        cov = covs[i]
        arr[i,:,:] = np.array( [ [mu[0],cov[0,0],cov[0,1]] , [mu[1],cov[1,0],cov[1,1]] ])
    uniq_vals_out.append(arr)
    
mu_lis,var_lis = unique_vals_given_clus(uniq_vals_out, allocs_out, best_clus,k)
weights = np.sum(best_clus == np.arange(k)[:, np.newaxis], axis=1) / len(data)
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/leopere/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:182: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)

# %%
for h in range(k):
    currd = data[best_clus == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])
