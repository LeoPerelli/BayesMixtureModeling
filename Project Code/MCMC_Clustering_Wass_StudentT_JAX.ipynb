# %%
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pandas as pd
import time
import scipy

#Separate import for numpy and jax.numpy to have major felxibility
import jax.numpy as jnp
import numpy as np
from jax import jit,lax,random
from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions
from tensorflow_probability.substrates import jax as jtfp
jtfd = jtfp.distributions
import jax.scipy as js

np.random.seed(0)

# %%
sampled_perturbed = np.load('test4.npy')
#sampled_perturbed=np.genfromtxt('faithful.csv', delimiter=',')
data = sampled_perturbed[0 : 1000]
#DEFINING NUMBER OF CLUSTERS AND DIMENSION OF DATA
k = 10
d = 2
df=7
df_cost=df/(df-2)
#Key to store for random generation
rng_key = random.PRNGKey(0)

# %%
plt.scatter(data[:,0],data[:,1])

# %%
from IPython.core.pylabtools import select_figure_formats
@jit
def g(x):
    """
    Function to modulate the Wasserstein Distance
    """
  
    
    f=(5/(1+jnp.exp(-0.6*(x-5))))-0.237

    return f

@jit
def sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    
    
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,key = sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
    
    
@jit
def sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,subk1 = sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
    

@jit
def sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov, bijector,key):
    """
    Sample new mean and covariance matrix through the bijection
    """
    key , subk1 , subk2 = random.split(key,3)

    mix = 0.1
    bimix_gauss = jtfd.MixtureSameFamily(
        
                     mixture_distribution=jtfd.Categorical(probs=[mix, 1-mix]),
                     components_distribution=jtfd.MultivariateNormalDiag(loc=[mu_old,mu_old],scale_diag=[[3,3],[0.1,0.1]])
                   )  

    mu = bimix_gauss.sample(seed = subk1)
    
    chol = jnp.linalg.cholesky(cov_old)
    vec = bijector.inverse(chol)
    vec_sampl = jtfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    
    return mu,cov,log_jac,key

@jit
def compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    nan_vec = jnp.repeat(jnp.array([jnp.nan]),len(cluster_allocs))
    
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0-3)
    
    # NW distribution terms
    num_0 = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    
    eval_vec=evaluate_student_T(data,mu,cov,df)
    eval_vec_old=evaluate_student_T(data,mu_old,cov_old,df)
    
    num_1 = jnp.nansum( jnp.where(cluster_allocs == h,eval_vec,nan_vec))
    den_1 = jnp.nansum( jnp.where(cluster_allocs == h,eval_vec_old,nan_vec))


    
     # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term

@jit
def compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0-3)
    
    # NW distribution terms
    num = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))
    
    return num  - den + sum_ + jac_term
  
@jit
def evaluate_NW_log(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = jnp.linalg.inv(phi_n)
    chol = jnp.linalg.cholesky(W) 
    inv_cov = jnp.linalg.inv(x_cov)

    f1 = jtfd.WishartTriL(df=nu_n.astype(float), scale_tril=chol).log_prob(inv_cov)
    f2 = jtfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

@jit
def compute_Wasserstein(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Student-t Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = jnp.linalg.norm(mu_1 - mu_2, ord = 2)
    
    #Compute square root of cov_2
    s = jnp.sqrt(jnp.linalg.det(cov_2))
    t = jnp.sqrt(jnp.trace(cov_2) + 2*s)
    sqrt_C2 = 1/t * (cov_2 + s*jnp.eye(2))
    
    C1_sqrt_C2 = jnp.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = jnp.matmul(sqrt_C2,C1_sqrt_C2)
    
    #Compute square root of sqrt_C2_C1_sqrt_C2
    s = jnp.sqrt(jnp.linalg.det(sqrt_C2_C1_sqrt_C2))
    t = jnp.sqrt(jnp.trace(sqrt_C2_C1_sqrt_C2) + 2*s)
    mat_sqrt = 1/t * (sqrt_C2_C1_sqrt_C2 + s*jnp.eye(2))
    
    trace = jnp.trace(cov_1 + cov_2 - 2 * mat_sqrt)

    # Function g
    return g(norm+trace)

@jit
def update_weights(cluster_allocs, weights, k, alpha,key):

    key, subk = random.split(key)
    n_clus = len(weights)
    n_by_clus = jnp.array([jnp.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = jnp.ones(n_clus) * alpha + n_by_clus
    return jtfd.Dirichlet(post_params.astype(float)).sample(seed = subk),key

# %%
@jit
def evaluate_student_T(data,mu,cov,df):
  
  scale=cov*(df-2)/df
  inv_scale=jnp.linalg.inv(scale)
  det_scale=jnp.linalg.det(scale)
  p=2
  
  def inner_f (x):
    eval_vec=js.special.gammaln((df+p)/2)-js.special.gammaln(df/2)-0.5*jnp.log(jnp.power(df,p)*jnp.power(jnp.pi,p)*det_scale)-((df+p)/2)*jnp.log(1+(1/df)*(jnp.dot((x-mu).T ,jnp.dot(inv_scale, x-mu))))
    return eval_vec
  ris=jnp.apply_along_axis(inner_f,1,data)
  
  return ris
 
def update_cluster_allocs(data, weights, mus, covs,key):
    key, subk = random.split(key)
    logprobs=[]
    for h in range(k):
      v=evaluate_student_T(data,mus[h],covs[h],df)
      v=np.expand_dims(v,axis=1)
      if (h==0):
        logprobs=v
      else:
        logprobs=np.concatenate((logprobs,v),axis=1)
    logprobs += jnp.log(weights)
    probs =  jnp.exp(logprobs)/(jnp.sum(jnp.exp(logprobs), axis=1))[:,None]
    return jtfd.Categorical(probs=probs, validate_args=True).sample(seed = subk),key

# %%
def run_one_gibbs(data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Run one gibbs sampler iteration
    Takes in input values of the previous iteration and sample the new values from sample_uniq_vals_fullcond, update_weights and update_cluster_allocs
    Returns:   
    
    -cluster_allocs: for every data point, the cluster assigned
    -uniq_vals: array of parameters of the distributions. Matrix has d rows of the type:[mu[0], var[0,0], var[0,1]]
    -weights: array with the weights of the clusters 
     """
    key, subk = random.split(key)
    n_clus = len(weights)
    for h in range(n_clus):
        
        #Extract data assigned to cluster h and sample 
        clusdata = data[cluster_allocs == h]
        if(len(clusdata) != 0):
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
        else:
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)


    weights,key = update_weights(cluster_allocs ,weights, k, alpha,key)

    cluster_allocs,key = update_cluster_allocs(data, weights, mus,covs,key)

    return cluster_allocs, mus,covs, weights, acc_rate,key

def run_mcmc(data, k, key , niter=1000, nburn=300, thin=5 ): 
    """
    Runs entire MCMC
    Takes in input data, number of clusters, number of iterations, burn-in and thin
    Returns the parameters recorded after burn-in phase
    """

    b = time.time() # only to measure time
    
    #Bijector setup
    jtfb = jtfp.bijectors
    bij = jtfb.Chain([
            jtfb.TransformDiagonal(jtfb.Softplus()),
            jtfb.FillTriangular()])

    #Starting Values
    cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
    weights = jnp.ones(k)/k
    alpha = 0.1
    lam = 0.1
    mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.linalg.inv(np.diag(np.ones(d))/lam) ).sample(k,seed = key))
    covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(2)) ).sample(k,seed = key))
    
    #Proposal Covariances
    cov_prop_cov = 0.02 * jnp.eye(3) #covariance matrix for the covariance sampling
    cov_prop_mu = jnp.eye(2)   #covariance matrix for the mean sampling
    
    #Output values
    allocs_out = []
    mus_out = []
    covs_out = []
    weights_out = []
    acc_rates = []
    
    #Useful value
    data_mean = np.mean(data, axis = 0)
    
    #Iterations
    for i in range(niter):
        cluster_allocs, mus,covs, weights, acc_rate,key = run_one_gibbs(
            data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,key)
        acc_rates.append(acc_rate)
        
        if i > nburn and i % thin == 0:
            allocs_out.append(cluster_allocs)
            mus_out.append(mus.copy())
            covs_out.append(covs.copy())
            weights_out.append(weights)
            
        if i % 10 == 0 and i > 11:
            a = time.time()
            print("\rIter {0} / {1}".format(i+1, niter) + " Remaining minutes: " + str(round((a-b)*(niter-i)/(60*10) ,1)) , flush=False, end=" ")
            b = time.time()
            print("Acceptance rate: " + str(np.mean(acc_rates[-10:])))
            
    return allocs_out, mus_out,covs_out, weights_out,acc_rates

# %%
#RUNNING THE MCMC
start = time.time()
allocs_out, mus_out,covs_out, weights_out,accept_rate_out = run_mcmc(data, k,rng_key , niter = 3000,nburn = 1000,thin = 5)
end = time.time()
print("Total time: " + str(end-start))
# Out:
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:6493: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:6493: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:3552: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# Iter 21 / 3000 Remaining minutes: 7.3 Acceptance rate: 0.24179044
# Iter 31 / 3000 Remaining minutes: 2.3 Acceptance rate: 0.17781088
# Iter 41 / 3000 Remaining minutes: 2.3 Acceptance rate: 0.25150865
# Iter 51 / 3000 Remaining minutes: 2.4 Acceptance rate: 0.121878624
# Iter 61 / 3000 Remaining minutes: 2.4 Acceptance rate: 0.035077162
# Iter 71 / 3000 Remaining minutes: 2.4 Acceptance rate: 0.11665992
# Iter 81 / 3000 Remaining minutes: 2.5 Acceptance rate: 0.11997805
# Iter 91 / 3000 Remaining minutes: 2.3 Acceptance rate: 0.11021043
# Iter 101 / 3000 Remaining minutes: 2.4 Acceptance rate: 0.06322923
# Iter 111 / 3000 Remaining minutes: 2.3 Acceptance rate: 0.11386987
# Iter 121 / 3000 Remaining minutes: 2.3 Acceptance rate: 0.14974183
# Iter 131 / 3000 Remaining minutes: 2.3 Acceptance rate: 0.030667027
# Iter 141 / 3000 Remaining minutes: 2.3 Acceptance rate: 0.25880468
# Iter 151 / 3000 Remaining minutes: 2.3 Acceptance rate: 0.19896606
# Iter 161 / 3000 Remaining minutes: 2.3 Acceptance rate: 0.17457448
# Iter 171 / 3000 Remaining minutes: 2.2 Acceptance rate: 0.027024915
# Iter 181 / 3000 Remaining minutes: 2.3 Acceptance rate: 0.10998615
# Iter 191 / 3000 Remaining minutes: 2.2 Acceptance rate: 0.28955227
# Iter 201 / 3000 Remaining minutes: 2.3 Acceptance rate: 0.20562086
# Iter 211 / 3000 Remaining minutes: 2.3 Acceptance rate: 0.10259546
# Iter 221 / 3000 Remaining minutes: 2.7 Acceptance rate: 0.12986827
# Iter 231 / 3000 Remaining minutes: 2.6 Acceptance rate: 0.079587795
# Iter 241 / 3000 Remaining minutes: 2.2 Acceptance rate: 0.1375683
# Iter 251 / 3000 Remaining minutes: 2.2 Acceptance rate: 0.10460681
# Iter 261 / 3000 Remaining minutes: 2.2 Acceptance rate: 0.102993324
# Iter 271 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.3001597
# Iter 281 / 3000 Remaining minutes: 2.2 Acceptance rate: 0.10062313
# Iter 291 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.0040298533
# Iter 301 / 3000 Remaining minutes: 2.2 Acceptance rate: 0.15631995
# Iter 311 / 3000 Remaining minutes: 2.2 Acceptance rate: 0.011902658
# Iter 321 / 3000 Remaining minutes: 2.2 Acceptance rate: 0.0038164444
# Iter 331 / 3000 Remaining minutes: 2.2 Acceptance rate: 0.045218967
# Iter 341 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.00044653798
# Iter 351 / 3000 Remaining minutes: 2.2 Acceptance rate: 0.0012608937
# Iter 361 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.005387659
# Iter 371 / 3000 Remaining minutes: 2.2 Acceptance rate: 9.096078e-05
# Iter 381 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.0020528731
# Iter 391 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.0006729996
# Iter 401 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.04327243
# Iter 411 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.084641725
# Iter 421 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.0020102493
# Iter 431 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.00084908074
# Iter 441 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.010357329
# Iter 451 / 3000 Remaining minutes: 2.2 Acceptance rate: 0.012127025
# Iter 461 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.00709972
# Iter 471 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.0034713305
# Iter 481 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.10270748
# Iter 491 / 3000 Remaining minutes: 2.0 Acceptance rate: 0.0048786355
# Iter 501 / 3000 Remaining minutes: 2.1 Acceptance rate: 0.0008150552
# Iter 511 / 3000 Remaining minutes: 2.0 Acceptance rate: 0.002673961
# Iter 521 / 3000 Remaining minutes: 1.9 Acceptance rate: 0.0003503884
# Iter 531 / 3000 Remaining minutes: 2.0 Acceptance rate: 0.001166424
# Iter 541 / 3000 Remaining minutes: 2.0 Acceptance rate: 0.0018157471
# Iter 551 / 3000 Remaining minutes: 2.0 Acceptance rate: 0.0012634906
# Iter 561 / 3000 Remaining minutes: 2.0 Acceptance rate: 0.0007500065
# Iter 571 / 3000 Remaining minutes: 1.9 Acceptance rate: 0.00033525546
# Iter 581 / 3000 Remaining minutes: 2.0 Acceptance rate: 0.0003733468
# Iter 591 / 3000 Remaining minutes: 1.9 Acceptance rate: 1.3214289e-05
# Iter 601 / 3000 Remaining minutes: 2.0 Acceptance rate: 0.00016953632
# Iter 611 / 3000 Remaining minutes: 2.0 Acceptance rate: 0.00053029414
# Iter 621 / 3000 Remaining minutes: 1.9 Acceptance rate: 0.00014961399
# Iter 631 / 3000 Remaining minutes: 1.8 Acceptance rate: 0.0020596287
# Iter 641 / 3000 Remaining minutes: 1.9 Acceptance rate: 0.0025272458
# Iter 651 / 3000 Remaining minutes: 1.9 Acceptance rate: 0.01637471
# Iter 661 / 3000 Remaining minutes: 1.9 Acceptance rate: 0.0003685854
# Iter 671 / 3000 Remaining minutes: 1.9 Acceptance rate: 0.0024969107
# Iter 681 / 3000 Remaining minutes: 1.8 Acceptance rate: 0.0023389643
# Iter 691 / 3000 Remaining minutes: 1.9 Acceptance rate: 2.483888e-06
# Iter 701 / 3000 Remaining minutes: 1.9 Acceptance rate: 0.00040928758
# Iter 711 / 3000 Remaining minutes: 1.8 Acceptance rate: 0.057730448
# Iter 721 / 3000 Remaining minutes: 1.9 Acceptance rate: 0.028173199
# Iter 731 / 3000 Remaining minutes: 1.8 Acceptance rate: 0.022127023
# Iter 741 / 3000 Remaining minutes: 1.8 Acceptance rate: 0.0008903433
# Iter 751 / 3000 Remaining minutes: 1.8 Acceptance rate: 0.00072572357
# Iter 761 / 3000 Remaining minutes: 1.8 Acceptance rate: 0.0012984115
# Iter 771 / 3000 Remaining minutes: 1.8 Acceptance rate: 0.00665626
# Iter 781 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.004298212
# Iter 791 / 3000 Remaining minutes: 1.8 Acceptance rate: 0.00066829054
# Iter 801 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.0019254427
# Iter 811 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.0005880408
# Iter 821 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.00054016535
# Iter 831 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.0003116415
# Iter 841 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.009988634
# Iter 851 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.0017638721
# Iter 861 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.0069621974
# Iter 871 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.037229553
# Iter 881 / 3000 Remaining minutes: 1.7 Acceptance rate: 6.3416934e-05
# Iter 891 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.048680797
# Iter 901 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.010901025
# Iter 911 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.000100355
# Iter 921 / 3000 Remaining minutes: 1.6 Acceptance rate: 0.0003570414
# Iter 931 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.008367447
# Iter 941 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.03585481
# Iter 951 / 3000 Remaining minutes: 1.6 Acceptance rate: 0.002488173
# Iter 961 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.00032397287
# Iter 971 / 3000 Remaining minutes: 1.6 Acceptance rate: 0.00058331934
# Iter 981 / 3000 Remaining minutes: 1.7 Acceptance rate: 0.007008812
# Iter 991 / 3000 Remaining minutes: 1.6 Acceptance rate: 0.002754539
# Iter 1001 / 3000 Remaining minutes: 1.6 Acceptance rate: 0.003289632
# Iter 1011 / 3000 Remaining minutes: 1.6 Acceptance rate: 0.00013759064
# Iter 1021 / 3000 Remaining minutes: 1.6 Acceptance rate: 0.0010593717
# Iter 1031 / 3000 Remaining minutes: 1.6 Acceptance rate: 0.00013256539
# Iter 1041 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.00095580367
# Iter 1051 / 3000 Remaining minutes: 1.6 Acceptance rate: 0.00013853108
# Iter 1061 / 3000 Remaining minutes: 1.6 Acceptance rate: 2.4861987e-05
# Iter 1071 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.0018898232
# Iter 1081 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.0001873259
# Iter 1091 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.00015144424
# Iter 1101 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.0016827462
# Iter 1111 / 3000 Remaining minutes: 1.6 Acceptance rate: 0.019854223
# Iter 1121 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.025268042
# Iter 1131 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.0009529471
# Iter 1141 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.00041391008
# Iter 1151 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.002663388
# Iter 1161 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.0049398914
# Iter 1171 / 3000 Remaining minutes: 1.4 Acceptance rate: 0.000643705
# Iter 1181 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.009316567
# Iter 1191 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.006265074
# Iter 1201 / 3000 Remaining minutes: 1.4 Acceptance rate: 0.007826488
# Iter 1211 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.035993032
# Iter 1221 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.000118264186
# Iter 1231 / 3000 Remaining minutes: 1.4 Acceptance rate: 7.7271514e-05
# Iter 1241 / 3000 Remaining minutes: 1.4 Acceptance rate: 0.051815994
# Iter 1251 / 3000 Remaining minutes: 1.5 Acceptance rate: 0.055402953
# Iter 1261 / 3000 Remaining minutes: 1.4 Acceptance rate: 0.0029431146
# Iter 1271 / 3000 Remaining minutes: 1.4 Acceptance rate: 0.00061403256
# Iter 1281 / 3000 Remaining minutes: 1.4 Acceptance rate: 0.0068118894
# Iter 1291 / 3000 Remaining minutes: 1.4 Acceptance rate: 0.00511361
# Iter 1301 / 3000 Remaining minutes: 1.4 Acceptance rate: 0.026444335
# Iter 1311 / 3000 Remaining minutes: 1.4 Acceptance rate: 0.009478713
# Iter 1321 / 3000 Remaining minutes: 1.3 Acceptance rate: 0.019480523
# Iter 1331 / 3000 Remaining minutes: 1.3 Acceptance rate: 0.018488046
# Iter 1341 / 3000 Remaining minutes: 1.3 Acceptance rate: 0.00013178817
# Iter 1351 / 3000 Remaining minutes: 1.3 Acceptance rate: 0.00028285288
# Iter 1361 / 3000 Remaining minutes: 1.3 Acceptance rate: 3.140978e-05
# Iter 1371 / 3000 Remaining minutes: 1.3 Acceptance rate: 0.009411144
# Iter 1381 / 3000 Remaining minutes: 1.3 Acceptance rate: 0.005602401
# Iter 1391 / 3000 Remaining minutes: 1.3 Acceptance rate: 2.3644378e-05
# Iter 1401 / 3000 Remaining minutes: 1.3 Acceptance rate: 0.0026810158
# Iter 1411 / 3000 Remaining minutes: 1.3 Acceptance rate: 1.0480381e-05
# Iter 1421 / 3000 Remaining minutes: 1.2 Acceptance rate: 9.5141084e-05
# Iter 1431 / 3000 Remaining minutes: 1.2 Acceptance rate: 0.00017815609
# Iter 1441 / 3000 Remaining minutes: 1.3 Acceptance rate: 0.017835442
# Iter 1451 / 3000 Remaining minutes: 1.3 Acceptance rate: 4.4358153e-06
# Iter 1461 / 3000 Remaining minutes: 1.3 Acceptance rate: 0.0064626285
# Iter 1471 / 3000 Remaining minutes: 1.3 Acceptance rate: 0.0060549676
# Iter 1481 / 3000 Remaining minutes: 1.2 Acceptance rate: 1.2558499e-05
# Iter 1491 / 3000 Remaining minutes: 1.2 Acceptance rate: 0.015445855
# Iter 1501 / 3000 Remaining minutes: 1.2 Acceptance rate: 0.03487548
# Iter 1511 / 3000 Remaining minutes: 1.2 Acceptance rate: 0.101119176
# Iter 1521 / 3000 Remaining minutes: 1.2 Acceptance rate: 0.040791724
# Iter 1531 / 3000 Remaining minutes: 1.2 Acceptance rate: 0.021826612
# Iter 1541 / 3000 Remaining minutes: 1.1 Acceptance rate: 0.02733181
# Iter 1551 / 3000 Remaining minutes: 1.2 Acceptance rate: 0.006183474
# Iter 1561 / 3000 Remaining minutes: 1.2 Acceptance rate: 0.00016323593
# Iter 1571 / 3000 Remaining minutes: 1.2 Acceptance rate: 0.0008747922
# Iter 1581 / 3000 Remaining minutes: 1.1 Acceptance rate: 0.00025779477
# Iter 1591 / 3000 Remaining minutes: 1.1 Acceptance rate: 0.001690841
# Iter 1601 / 3000 Remaining minutes: 1.1 Acceptance rate: 0.00052168086
# Iter 1611 / 3000 Remaining minutes: 1.1 Acceptance rate: 5.0357085e-07
# Iter 1621 / 3000 Remaining minutes: 1.1 Acceptance rate: 0.0024055638
# Iter 1631 / 3000 Remaining minutes: 1.1 Acceptance rate: 0.10448525
# Iter 1641 / 3000 Remaining minutes: 1.1 Acceptance rate: 0.0009160383
# Iter 1651 / 3000 Remaining minutes: 1.1 Acceptance rate: 0.00028050257
# Iter 1661 / 3000 Remaining minutes: 1.1 Acceptance rate: 1.3154104e-05
# Iter 1671 / 3000 Remaining minutes: 1.1 Acceptance rate: 0.0001015927
# Iter 1681 / 3000 Remaining minutes: 1.0 Acceptance rate: 0.00022773899
# Iter 1691 / 3000 Remaining minutes: 1.0 Acceptance rate: 0.0002922013
# Iter 1701 / 3000 Remaining minutes: 1.0 Acceptance rate: 0.0058897575
# Iter 1711 / 3000 Remaining minutes: 1.0 Acceptance rate: 0.0011228882
# Iter 1721 / 3000 Remaining minutes: 1.0 Acceptance rate: 0.00012962526
# Iter 1731 / 3000 Remaining minutes: 1.0 Acceptance rate: 7.548377e-05
# Iter 1741 / 3000 Remaining minutes: 1.0 Acceptance rate: 0.021402221
# Iter 1751 / 3000 Remaining minutes: 1.0 Acceptance rate: 0.0013069834
# Iter 1761 / 3000 Remaining minutes: 1.0 Acceptance rate: 0.0023019896
# Iter 1771 / 3000 Remaining minutes: 1.0 Acceptance rate: 0.00047007552
# Iter 1781 / 3000 Remaining minutes: 1.0 Acceptance rate: 0.004176626
# Iter 1791 / 3000 Remaining minutes: 1.0 Acceptance rate: 0.0008406967
# Iter 1801 / 3000 Remaining minutes: 0.9 Acceptance rate: 0.0012187505
# Iter 1811 / 3000 Remaining minutes: 0.9 Acceptance rate: 0.00022236523
# Iter 1821 / 3000 Remaining minutes: 0.9 Acceptance rate: 4.6697405e-06
# Iter 1831 / 3000 Remaining minutes: 0.9 Acceptance rate: 0.00056298415
# Iter 1841 / 3000 Remaining minutes: 0.9 Acceptance rate: 0.0003611176
# Iter 1851 / 3000 Remaining minutes: 1.0 Acceptance rate: 0.0075192116
# Iter 1861 / 3000 Remaining minutes: 0.9 Acceptance rate: 3.054481e-05
# Iter 1871 / 3000 Remaining minutes: 0.9 Acceptance rate: 2.3773777e-05
# Iter 1881 / 3000 Remaining minutes: 0.9 Acceptance rate: 0.005117867
# Iter 1891 / 3000 Remaining minutes: 0.9 Acceptance rate: 0.0007665407
# Iter 1901 / 3000 Remaining minutes: 0.9 Acceptance rate: 0.0005726678
# Iter 1911 / 3000 Remaining minutes: 0.9 Acceptance rate: 0.0011893759
# Iter 1921 / 3000 Remaining minutes: 0.9 Acceptance rate: 0.0018661951
# Iter 1931 / 3000 Remaining minutes: 0.9 Acceptance rate: 0.004143741
# Iter 1941 / 3000 Remaining minutes: 0.8 Acceptance rate: 0.001343201
# Iter 1951 / 3000 Remaining minutes: 0.9 Acceptance rate: 0.006517706
# Iter 1961 / 3000 Remaining minutes: 0.8 Acceptance rate: 2.2482029e-05
# Iter 1971 / 3000 Remaining minutes: 0.8 Acceptance rate: 0.0036821063
# Iter 1981 / 3000 Remaining minutes: 0.8 Acceptance rate: 0.00010376854
# Iter 1991 / 3000 Remaining minutes: 0.8 Acceptance rate: 0.0018535077
# Iter 2001 / 3000 Remaining minutes: 0.8 Acceptance rate: 6.5891677e-06
# Iter 2011 / 3000 Remaining minutes: 0.8 Acceptance rate: 0.00071017013
# Iter 2021 / 3000 Remaining minutes: 0.8 Acceptance rate: 0.0043339618
# Iter 2031 / 3000 Remaining minutes: 1.0 Acceptance rate: 0.0066328766
# Iter 2041 / 3000 Remaining minutes: 1.5 Acceptance rate: 4.334957e-05
# Iter 2051 / 3000 Remaining minutes: 1.6 Acceptance rate: 0.00010322599
# Iter 2061 / 3000 Remaining minutes: 0.9 Acceptance rate: 0.00064806297
# Iter 2071 / 3000 Remaining minutes: 0.8 Acceptance rate: 0.0008532483
# Iter 2081 / 3000 Remaining minutes: 0.7 Acceptance rate: 0.007520313
# Iter 2091 / 3000 Remaining minutes: 0.7 Acceptance rate: 0.004662924
# Iter 2101 / 3000 Remaining minutes: 0.7 Acceptance rate: 0.00017250869
# Iter 2111 / 3000 Remaining minutes: 0.7 Acceptance rate: 8.998026e-05
# Iter 2121 / 3000 Remaining minutes: 0.7 Acceptance rate: 5.405338e-05
# Iter 2131 / 3000 Remaining minutes: 0.7 Acceptance rate: 0.00012036477
# Iter 2141 / 3000 Remaining minutes: 0.7 Acceptance rate: 0.0068450295
# Iter 2151 / 3000 Remaining minutes: 0.7 Acceptance rate: 7.9834324e-05
# Iter 2161 / 3000 Remaining minutes: 0.7 Acceptance rate: 0.00013893683
# Iter 2171 / 3000 Remaining minutes: 0.7 Acceptance rate: 0.00030386393
# Iter 2181 / 3000 Remaining minutes: 0.7 Acceptance rate: 0.00030944662
# Iter 2191 / 3000 Remaining minutes: 0.6 Acceptance rate: 0.0073600663
# Iter 2201 / 3000 Remaining minutes: 0.6 Acceptance rate: 0.00094345707
# Iter 2211 / 3000 Remaining minutes: 0.6 Acceptance rate: 0.00010673172
# Iter 2221 / 3000 Remaining minutes: 0.6 Acceptance rate: 5.86256e-05
# Iter 2231 / 3000 Remaining minutes: 0.6 Acceptance rate: 0.01029126
# Iter 2241 / 3000 Remaining minutes: 0.6 Acceptance rate: 0.0004942267
# Iter 2251 / 3000 Remaining minutes: 0.6 Acceptance rate: 0.0037144609
# Iter 2261 / 3000 Remaining minutes: 0.6 Acceptance rate: 0.0011758043
# Iter 2271 / 3000 Remaining minutes: 0.6 Acceptance rate: 0.0009069761
# Iter 2281 / 3000 Remaining minutes: 0.6 Acceptance rate: 0.008504712
# Iter 2291 / 3000 Remaining minutes: 0.6 Acceptance rate: 2.6183092e-05
# Iter 2301 / 3000 Remaining minutes: 0.6 Acceptance rate: 0.00012795319
# Iter 2311 / 3000 Remaining minutes: 0.6 Acceptance rate: 0.022857655
# Iter 2321 / 3000 Remaining minutes: 0.5 Acceptance rate: 0.023245718
# Iter 2331 / 3000 Remaining minutes: 0.5 Acceptance rate: 0.00038648926
# Iter 2341 / 3000 Remaining minutes: 0.5 Acceptance rate: 0.0016590657
# Iter 2351 / 3000 Remaining minutes: 0.5 Acceptance rate: 0.011629575
# Iter 2361 / 3000 Remaining minutes: 0.5 Acceptance rate: 0.0002545296
# Iter 2371 / 3000 Remaining minutes: 0.5 Acceptance rate: 0.004154479
# Iter 2381 / 3000 Remaining minutes: 0.5 Acceptance rate: 3.217226e-06
# Iter 2391 / 3000 Remaining minutes: 0.5 Acceptance rate: 0.0017773043
# Iter 2401 / 3000 Remaining minutes: 0.5 Acceptance rate: 2.5837337e-05
# Iter 2411 / 3000 Remaining minutes: 0.5 Acceptance rate: 0.029207239
# Iter 2421 / 3000 Remaining minutes: 0.5 Acceptance rate: 0.00024802572
# Iter 2431 / 3000 Remaining minutes: 0.5 Acceptance rate: 0.011173532
# Iter 2441 / 3000 Remaining minutes: 0.4 Acceptance rate: 1.3913571e-05
# Iter 2451 / 3000 Remaining minutes: 0.4 Acceptance rate: 0.0040908116
# Iter 2461 / 3000 Remaining minutes: 0.4 Acceptance rate: 0.0016521228
# Iter 2471 / 3000 Remaining minutes: 0.4 Acceptance rate: 0.016561428
# Iter 2481 / 3000 Remaining minutes: 0.4 Acceptance rate: 0.028721392
# Iter 2491 / 3000 Remaining minutes: 0.4 Acceptance rate: 0.0054941257
# Iter 2501 / 3000 Remaining minutes: 0.4 Acceptance rate: 2.0514939e-05
# Iter 2511 / 3000 Remaining minutes: 0.4 Acceptance rate: 0.00020218967
# Iter 2521 / 3000 Remaining minutes: 0.4 Acceptance rate: 0.004349212
# Iter 2531 / 3000 Remaining minutes: 0.4 Acceptance rate: 0.0008970212
# Iter 2541 / 3000 Remaining minutes: 0.4 Acceptance rate: 0.019219836
# Iter 2551 / 3000 Remaining minutes: 0.4 Acceptance rate: 5.5135122e-05
# Iter 2561 / 3000 Remaining minutes: 0.4 Acceptance rate: 0.11504443
# Iter 2571 / 3000 Remaining minutes: 0.3 Acceptance rate: 0.01187629
# Iter 2581 / 3000 Remaining minutes: 0.3 Acceptance rate: 2.4759085e-05
# Iter 2591 / 3000 Remaining minutes: 0.3 Acceptance rate: 0.0003293311
# Iter 2601 / 3000 Remaining minutes: 0.3 Acceptance rate: 0.0009341213
# Iter 2611 / 3000 Remaining minutes: 0.3 Acceptance rate: 0.008535853
# Iter 2621 / 3000 Remaining minutes: 0.3 Acceptance rate: 0.0009974494
# Iter 2631 / 3000 Remaining minutes: 0.3 Acceptance rate: 0.083451055
# Iter 2641 / 3000 Remaining minutes: 0.3 Acceptance rate: 0.00019316419
# Iter 2651 / 3000 Remaining minutes: 0.3 Acceptance rate: 0.00029312097
# Iter 2661 / 3000 Remaining minutes: 0.3 Acceptance rate: 0.0052929744
# Iter 2671 / 3000 Remaining minutes: 0.3 Acceptance rate: 3.6881767e-05
# Iter 2681 / 3000 Remaining minutes: 0.3 Acceptance rate: 0.00024886912
# Iter 2691 / 3000 Remaining minutes: 0.2 Acceptance rate: 0.0017937559
# Iter 2701 / 3000 Remaining minutes: 0.3 Acceptance rate: 1.4269249e-07
# Iter 2711 / 3000 Remaining minutes: 0.2 Acceptance rate: 0.0056262
# Iter 2721 / 3000 Remaining minutes: 0.2 Acceptance rate: 0.00079429883
# Iter 2731 / 3000 Remaining minutes: 0.2 Acceptance rate: 0.0020575705
# Iter 2741 / 3000 Remaining minutes: 0.2 Acceptance rate: 0.012764084
# Iter 2751 / 3000 Remaining minutes: 0.2 Acceptance rate: 0.00045874872
# Iter 2761 / 3000 Remaining minutes: 0.2 Acceptance rate: 0.013582992
# Iter 2771 / 3000 Remaining minutes: 0.2 Acceptance rate: 0.0074410597
# Iter 2781 / 3000 Remaining minutes: 0.2 Acceptance rate: 0.0025602668
# Iter 2791 / 3000 Remaining minutes: 0.2 Acceptance rate: 0.0014029385
# Iter 2801 / 3000 Remaining minutes: 0.2 Acceptance rate: 2.762226e-06
# Iter 2811 / 3000 Remaining minutes: 0.2 Acceptance rate: 0.00040966543
# Iter 2821 / 3000 Remaining minutes: 0.1 Acceptance rate: 0.00017866046
# Iter 2831 / 3000 Remaining minutes: 0.1 Acceptance rate: 0.003652832
# Iter 2841 / 3000 Remaining minutes: 0.1 Acceptance rate: 0.0033599113
# Iter 2851 / 3000 Remaining minutes: 0.1 Acceptance rate: 0.01153232
# Iter 2861 / 3000 Remaining minutes: 0.1 Acceptance rate: 0.0012256913
# Iter 2871 / 3000 Remaining minutes: 0.1 Acceptance rate: 0.008508305
# Iter 2881 / 3000 Remaining minutes: 0.1 Acceptance rate: 0.00010170792
# Iter 2891 / 3000 Remaining minutes: 0.1 Acceptance rate: 0.026321147
# Iter 2901 / 3000 Remaining minutes: 0.1 Acceptance rate: 0.001237834
# Iter 2911 / 3000 Remaining minutes: 0.1 Acceptance rate: 0.0010454226
# Iter 2921 / 3000 Remaining minutes: 0.1 Acceptance rate: 0.0036246986
# Iter 2931 / 3000 Remaining minutes: 0.1 Acceptance rate: 0.0026755864
# Iter 2941 / 3000 Remaining minutes: 0.0 Acceptance rate: 6.035745e-07
# Iter 2951 / 3000 Remaining minutes: 0.0 Acceptance rate: 0.0043097525
# Iter 2961 / 3000 Remaining minutes: 0.0 Acceptance rate: 0.017749738
# Iter 2971 / 3000 Remaining minutes: 0.0 Acceptance rate: 0.0051091
# Iter 2981 / 3000 Remaining minutes: 0.0 Acceptance rate: 0.0014059496
# Iter 2991 / 3000 Remaining minutes: 0.0 Acceptance rate: 0.00023398487
# Total time: 147.09999537467957

# %%
def get_psm(clus_alloc_chain):
    """
    Returns the posterior similarity matrix, i.e.
        out[i, j] = P(c_i == c_j | all the rest)
    for each pair of observations
    """
    #Fare confronto tra colonna i e j della matrice e poi calcolare da li
    c_chain = np.vstack(clus_alloc_chain)
    out = np.zeros((c_chain.shape[1], c_chain.shape[1]))
    for i in range(c_chain.shape[1]):
        for j in range(c_chain.shape[1]):
            out[i,j] = np.sum(c_chain[:,i] == c_chain[:,j]) / c_chain.shape[0]
            
    return out


def minbinder_sample(clus_alloc_chain, psm):
    """
    Finds the iteration for which the Binder loss is minimized
    and returns the associated clustering
    """
    losses = np.zeros(len(clus_alloc_chain))
    c_chain = np.vstack(clus_alloc_chain)
    
    # You can either cycle through the iterations, or 
    # cycle through the entries in the PSM [i, j]
    # and vectorize the same operation for each iteration!
    
    mat = np.zeros( ( c_chain.shape[0], c_chain.shape[1]**2 ) )
    k = 0
    for i in range(c_chain.shape[1]):
        for j in range(c_chain.shape[1]):
            mat[:,k] = ( (c_chain[:,i] == c_chain[:,j]).astype(int) - psm[i,j] * np.ones(c_chain.shape[0]) ) **2
            k = k+1
    
    losses = np.sum(mat, axis = 1)
    
    best_iter = np.argmin(losses)
    return clus_alloc_chain[best_iter]



def unique_vals_given_clus(unique_vals_chain, clus_alloc_chain, best_clus,n_clus):
    #Finds the unique values associated to the best clusters obtained during MCMC
    
    c_allocs = np.stack(clus_alloc_chain)
    uniq_vals = np.stack(unique_vals_chain)
    means = uniq_vals[:, :, : , 0]
    variances = uniq_vals[:, :, : , 1:3]
    out1 = []
    out2 = []
    for h in range(n_clus):
        data_idx = np.where(best_clus == h)[0]
        uniq_vals_idx = c_allocs[:, data_idx] # -> Matrix [n_iter x n_data_in_clus]
        means_by_iter = np.empty((c_allocs.shape[0], len(data_idx),2))
        vars_by_iter = np.empty((c_allocs.shape[0], len(data_idx),2,2))
        for i in range(c_allocs.shape[0]):
            means_by_iter[i, :] = means[i,uniq_vals_idx[i,:],:]
            vars_by_iter[i, :] = variances[i,uniq_vals_idx[i,:]]

        avg_mean_by_iter = np.mean(means_by_iter , axis = 1)
        avg_var_by_iter = np.mean(vars_by_iter , axis = 1)
        
        muhat = np.mean(avg_mean_by_iter,axis=0)
        sigsqhat = np.mean(avg_var_by_iter,axis=0)
        out1.append(np.array(muhat))
        out2.append(np.array(sigsqhat))
    
    #If there are no points in certain clusters, the output would be full of NANs for the cluster. This gives problems
    #I replace the NANs with some 0
    for i in range(len(out1)):
        if(np.any(np.isnan(out1[i]))):
            out1[i] = np.zeros(shape = out1[i].shape)
        if(np.any(np.isnan(out2[i]))):
            out2[i] = np.eye(N = out2[i].shape[0])
    
        
    return out1,out2


psm = get_psm(allocs_out)
best_clus = minbinder_sample(allocs_out,psm)

uniq_vals_out = []
for n in range(len(mus_out)):
    mus = mus_out[n]
    covs = covs_out[n]
    arr = np.zeros(shape=(k,2,3))
    for i in range(k):
        mu = mus[i]
        cov = covs[i]
        arr[i,:,:] = np.array( [ [mu[0],cov[0,0],cov[0,1]] , [mu[1],cov[1,0],cov[1,1]] ])
    uniq_vals_out.append(arr)
    
mu_lis,var_lis = unique_vals_given_clus(uniq_vals_out, allocs_out, best_clus,k)
weights = np.sum(best_clus == np.arange(k)[:, np.newaxis], axis=1) / len(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)

# %%
#View the number of points inside each cluster at the best iteration
print(pd.Series(best_clus).value_counts())
x, y = np.unique(best_clus, return_counts=True)
plt.bar(x, y)
# Out:
# 9    91
# 3    91
# 4    83
# 2     6
# dtype: int64
# <BarContainer object of 4 artists>

# %%
for h in range(k):
    currd = data[best_clus == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [mu[i][0] for mu in mus_out]
    second_comp = [mu[i][1] for mu in mus_out]

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__mu_x", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_mu_y", fontsize=16)

    plt.show()

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [covs[i][0,0] for covs in covs_out]
    second_comp = [covs[i][0,1] for covs in covs_out]
    third_comp = [covs[i][1,1] for covs in covs_out]

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__cov_xx", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_cov_xy", fontsize=16)
    
    axes[2].plot(np.arange(len(third_comp)), third_comp,)
    axes[2].set_title(str(i) + "_cov_yy", fontsize=16)

    plt.show()

# %%
for i in range(k):
    weights = [w[i] for w in weights_out]
    plt.plot(np.arange(len(weights)) , weights)
