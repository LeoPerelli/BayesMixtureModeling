# %%
from M_w_Gibbs_functions import run_mcmc
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pandas as pd
import time
import scipy

#Separate import for numpy and jax.numpy to have major felxibility
import jax.numpy as jnp
import numpy as np
from jax import jit,lax,random
from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions
from tensorflow_probability.substrates import jax as jtfp
jtfd = jtfp.distributions

np.random.seed(0)
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
sampled_perturbed = np.load('Project Code/sampled_2D_two_clusters.npy')
data = sampled_perturbed[0 : 1000]
k = 5
d = 2
rng_key = random.PRNGKey(0)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
allocs_out, uniq_vals_out, weights_out,key = run_mcmc(data, k ,d,rng_key,niter=100)
# Out:
# num_10.0
# prod6.191098297716302
# den_10.0
# beta
# 6.191098297716302
# num_10.0
# prod0.46136768996858835
# den_10.0
# beta
# 0.46136768996858835
# num_10.0
# prod0.11648832880084345
# den_10.0
# beta
# 0.11648832880084345
# num_10.0
# prod0.3158259589797385
# den_10.0
# beta
# 0.3158259589797385
# num_10.0
# prod0.22562572871514244
# den_10.0
# beta
# 0.22562572871514244
# Iter 1 / 100 Remaining minutes: 0.1 num_10.0
# prod0.02688584294532845
# den_10.0
# beta
# 0.02688584294532845
# num_10.0
# prod0.08934248257403309
# den_10.0
# beta
# 0.08934248257403309
# num_10.0
# prod0.13134334355383367
# den_10.0
# beta
# 0.13134334355383367
# num_10.0
# prod0.0025812137767862804
# den_19.8616e-320
# beta
# 0.0025812137767862804
# num_10.0
# prod0.32082320455449426
# den_10.0
# beta
# 0.32082320455449426
# num_10.0
# prod0.021050291485252413
# den_10.0
# beta
# 0.021050291485252413
# num_10.0
# prod0.12595693679631897
# den_10.0
# beta
# 0.12595693679631897
# num_10.0
# prod0.01752318481224863
# den_10.0
# beta
# 0.01752318481224863
# num_10.0
# prod0.001590566872528291
# den_18.045486191940006e-270
# beta
# 0.001590566872528291
# num_10.0
# prod0.07539960326859983
# den_10.0
# beta
# 0.07539960326859983
# num_10.0
# prod0.2406839060142336
# den_10.0
# beta
# 0.2406839060142336
# num_10.0
# prod0.050917832281765815
# den_10.0
# beta
# 0.050917832281765815
# num_10.0
# prod0.15060343587310124
# den_10.0
# beta
# 0.15060343587310124
# num_14.0043247216482664e-282
# prod0.07110679391818585
# den_11.2704192768421798e-193
# beta
# 0.07110679391818585
# num_10.0
# prod0.06245620117768382
# den_10.0
# beta
# 0.06245620117768382
# num_10.0
# prod0.01003288720503014
# den_10.0
# beta
# 0.01003288720503014
# num_10.0
# prod0.20163821355307113
# den_10.0
# beta
# 0.20163821355307113
# num_10.0
# prod0.03724683675577812
# den_10.0
# beta
# 0.03724683675577812
# num_10.0
# prod0.00045220606636482496
# den_10.0
# beta
# 0.00045220606636482496
# num_10.0
# prod0.38371587126796186
# den_10.0
# beta
# 0.38371587126796186
# num_10.0
# prod0.019399679289876046
# den_10.0
# beta
# 0.019399679289876046
# num_10.0
# prod0.2092637954371193
# den_10.0
# beta
# 0.2092637954371193
# num_10.0
# prod0.04623513137358886
# den_10.0
# beta
# 0.04623513137358886
# num_11.3157869562962636e-269
# prod0.009747297103189032
# den_11.5120399001414222e-255
# beta
# 0.009747297103189032
# num_10.0
# prod0.13986435278744036
# den_10.0
# beta
# 0.13986435278744036
# num_10.0
# prod0.2549592969791347
# den_10.0
# beta
# 0.2549592969791347
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8919fcd3bee6> in <module>
# ----> 1 allocs_out, uniq_vals_out, weights_out,key = run_mcmc(data, k ,d,rng_key,niter=100)
#
# ~/Desktop/MTM/Magistrale/Secondo_anno/Primo_Semestre/Bayesian/BayesMixtureModeling/M_w_Gibbs_functions.py in run_mcmc(data, k, d, key, niter, nburn, thin)
#     259     for i in range(niter):
#     260         cluster_allocs, uniq_vals, weights , key = run_one_gibbs(
# --> 261             data, cluster_allocs, uniq_vals, weights, alpha, lam , key)
#     262
#     263         if i > nburn and i % thin == 0:
#
# ~/Desktop/MTM/Magistrale/Secondo_anno/Primo_Semestre/Bayesian/BayesMixtureModeling/M_w_Gibbs_functions.py in run_one_gibbs(data, cluster_allocs, uniq_vals, weights, alpha, lam, key)
#     217         clusdata = data[cluster_allocs == h]
#     218         if len(clusdata) != 0:
# --> 219             uniq_vals[h, :], acc_rate = sample_uniq_vals_fullcond_Wasserstein(clusdata, lam, uniq_vals, h, key)
#     220
#     221     weights = update_weights(cluster_allocs ,n_clus, k, alpha)
#
# ~/Desktop/MTM/Magistrale/Secondo_anno/Primo_Semestre/Bayesian/BayesMixtureModeling/M_w_Gibbs_functions.py in sample_uniq_vals_fullcond_Wasserstein(clusdata, lam, uniq_vals, h, key)
#      41
#      42     # Compute acceptance rate(and return it for tuning)
# ---> 43     beta = compute_beta(uniq_vals, h, mu, cov, mu_n, lam_n, phi_n, nu_n, mu_old, cov_old)
#      44     print("beta")
#      45     print(beta)
#
# ~/Desktop/MTM/Magistrale/Secondo_anno/Primo_Semestre/Bayesian/BayesMixtureModeling/M_w_Gibbs_functions.py in compute_beta(uniq_vals, h, mu, cov, mu_n, lam_n, phi_n, nu_n, mu_old, cov_old)
#     137     # Target distribution terms
#     138     num_1 = evaluate_NIW(mu, cov, mu_n, lam_n, phi_n, nu_n)
# --> 139     den_1 = evaluate_NIW(mu_old, cov_old , mu_n, lam_n, phi_n, nu_n)
#     140
#     141     # Wasserstein Distances
#
# ~/Desktop/MTM/Magistrale/Secondo_anno/Primo_Semestre/Bayesian/BayesMixtureModeling/M_w_Gibbs_functions.py in evaluate_NIW(x_mu, x_cov, mu_n, lam_n, phi_n, nu_n)
#      94
#      95     f1 = tfd.WishartTriL(df=nu_n, scale_tril=chol).prob(inv_cov)
# ---> 96     f2 = tfd.MultivariateNormalFullCovariance(mu_n, x_cov/(lam_n)).prob(x_mu)
#      97     return f1 * f2
#      98
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/distributions/distribution.py in prob(self, value, name, **kwargs)
#    1342         values of type `self.dtype`.
#    1343     """
# -> 1344     return self._call_prob(value, name, **kwargs)
#    1345
#    1346   def _call_unnormalized_log_prob(self, value, name, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/distributions/distribution.py in _call_prob(self, value, name, **kwargs)
#    1324     with self._name_and_control_scope(name, value, kwargs):
#    1325       if hasattr(self, '_prob'):
# -> 1326         return self._prob(value, **kwargs)
#    1327       if hasattr(self, '_log_prob'):
#    1328         return tf.exp(self._log_prob(value, **kwargs))
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/internal/distribution_util.py in _fn(*args, **kwargs)
#    1360     @functools.wraps(fn)
#    1361     def _fn(*args, **kwargs):
# -> 1362       return fn(*args, **kwargs)
#    1363
#    1364     if _fn.__doc__ is None:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/distributions/mvn_linear_operator.py in _prob(self, x)
#     247   @distribution_util.AppendDocstring(_mvn_sample_note)
#     248   def _prob(self, x):
# --> 249     return super(MultivariateNormalLinearOperator, self)._prob(x)
#     250
#     251   def _mean(self):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/distributions/transformed_distribution.py in _prob(self, y, **kwargs)
#     380   def _prob(self, y, **kwargs):
#     381     if not hasattr(self.distribution, '_prob'):
# --> 382       return tf.exp(self._log_prob(y, **kwargs))
#     383     distribution_kwargs, bijector_kwargs = self._kwargs_split_fn(kwargs)
#     384
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/internal/distribution_util.py in _fn(*args, **kwargs)
#    1360     @functools.wraps(fn)
#    1361     def _fn(*args, **kwargs):
# -> 1362       return fn(*args, **kwargs)
#    1363
#    1364     if _fn.__doc__ is None:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/distributions/mvn_linear_operator.py in _log_prob(self, x)
#     243   @distribution_util.AppendDocstring(_mvn_sample_note)
#     244   def _log_prob(self, x):
# --> 245     return super(MultivariateNormalLinearOperator, self)._log_prob(x)
#     246
#     247   @distribution_util.AppendDocstring(_mvn_sample_note)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/distributions/transformed_distribution.py in _log_prob(self, y, **kwargs)
#     366
#     367     ildj = self.bijector.inverse_log_det_jacobian(
# --> 368         y, event_ndims=event_ndims, **bijector_kwargs)
#     369     if self.bijector._is_injective:  # pylint: disable=protected-access
#     370       base_log_prob = self.distribution.log_prob(x, **distribution_kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/bijectors/bijector.py in inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs)
#    1559       ValueError: if the value of `event_ndims` is not valid for this bijector.
#    1560     """
# -> 1561     return self._call_inverse_log_det_jacobian(y, event_ndims, name, **kwargs)
#    1562
#    1563   def _call_forward_log_det_jacobian(self, x, event_ndims, name, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/bijectors/composition.py in _call_inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs)
#     537       event_ndims = nest_util.coerce_structure(
#     538           self.inverse_min_event_ndims, event_ndims)
# --> 539       return self._inverse_log_det_jacobian(y, event_ndims, **kwargs)
#     540
#     541   def _inverse_log_det_jacobian(self, y, event_ndims, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/bijectors/composition.py in _inverse_log_det_jacobian(self, y, event_ndims, **kwargs)
#     551       ldj = tf.convert_to_tensor(
#     552           bm.bijector.inverse_log_det_jacobian(bm.x, bm.x_event_ndims,
# --> 553                                                **bm.kwargs),
#     554           dtype_hint=ldj_sum.dtype)
#     555
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/bijectors/bijector.py in inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs)
#    1559       ValueError: if the value of `event_ndims` is not valid for this bijector.
#    1560     """
# -> 1561     return self._call_inverse_log_det_jacobian(y, event_ndims, name, **kwargs)
#    1562
#    1563   def _call_forward_log_det_jacobian(self, x, event_ndims, name, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/bijectors/bijector.py in _call_inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs)
#    1515
#    1516         return reduce_jacobian_det_over_shape(
# -> 1517             ildj, reduce_shape, sum_fn=self._sum_fn)
#    1518
#    1519   def inverse_log_det_jacobian(self,
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/bijectors/bijector.py in reduce_jacobian_det_over_shape(unreduced, reduce_shape, sum_fn)
#    2363   # and reduce over the trailing dimensions.
#    2364   ones = tf.ones(reduce_shape, unreduced.dtype)
# -> 2365   reduce_dims = ps.range(-ps.size(reduce_shape), 0)
#    2366   return sum_fn(ones * unreduced, axis=reduce_dims)
#    2367
#
# </Users/leopere/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-621> in range(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/substrates/numpy/internal/prefer_static.py in wrap(***failed resolving arguments***)
#      78                      for arg, arg_ in zip(flat_args, flat_args_))
#      79     if all_static:
# ---> 80       [args_, kwargs_] = tf.nest.pack_sequence_as([args, kwargs], flat_args_)
#      81       return static_fn(*args_, **kwargs_)
#      82     return original_fn(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/python/internal/backend/numpy/nest.py in pack_sequence_as(structure, flat_sequence, **kwargs)
#     329     return tree_util.tree_unflatten(
#     330         tree_util.tree_structure(structure), flat_sequence)
# --> 331   return dm_tree.unflatten_as(structure, flat_sequence)
#     332
#     333
#
# ~/anaconda3/lib/python3.7/site-packages/tree/__init__.py in unflatten_as(structure, flat_sequence)
#     453         % (len(flat_structure), len(flat_sequence), structure, flat_sequence))
#     454
# --> 455   _, packed = _packed_nest_with_indices(structure, flat_sequence, 0)
#     456   return _sequence_like(structure, packed)
#     457
#
# ~/anaconda3/lib/python3.7/site-packages/tree/__init__.py in _packed_nest_with_indices(structure, flat, index)
#     389   for s in _yield_value(structure):
#     390     if is_nested(s):
# --> 391       new_index, child = _packed_nest_with_indices(s, flat, index)
#     392       packed.append(_sequence_like(s, child))
#     393       index = new_index
#
# ~/anaconda3/lib/python3.7/site-packages/tree/__init__.py in _packed_nest_with_indices(structure, flat, index)
#     387   """
#     388   packed = []
# --> 389   for s in _yield_value(structure):
#     390     if is_nested(s):
#     391       new_index, child = _packed_nest_with_indices(s, flat, index)
#
# ~/anaconda3/lib/python3.7/site-packages/tree/__init__.py in _yield_value(iterable)
#     205
#     206 def _yield_value(iterable):
# --> 207   for _, v in _yield_sorted_items(iterable):
#     208     yield v
#     209
#
# ~/anaconda3/lib/python3.7/site-packages/tree/__init__.py in _yield_sorted_items(iterable)
#     224     The iterable's (key, value) pairs, in order of sorted keys.
#     225   """
# --> 226   if isinstance(iterable, collections_abc.Mapping):
#     227     # Iterate through dictionaries in a deterministic order by sorting the
#     228     # keys. Notice this means that we ignore the original order of `OrderedDict`
#
# ~/anaconda3/lib/python3.7/abc.py in __instancecheck__(cls, instance)
#     137         def __instancecheck__(cls, instance):
#     138             """Override for isinstance(instance, cls)."""
# --> 139             return _abc_instancecheck(cls, instance)
#     140
#     141         def __subclasscheck__(cls, subclass):
#
# KeyboardInterrupt:
