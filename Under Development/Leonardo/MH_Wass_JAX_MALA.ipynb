# %%
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pandas as pd
import time
import scipy

#Separate import for numpy and jax.numpy to have major felxibility
import jax.numpy as jnp
import numpy as np
from jax import jit,lax,random,grad,vmap
from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions
from tensorflow_probability.substrates import jax as jtfp
jtfd = jtfp.distributions

np.random.seed(0)

# %%
#sampled_perturbed = np.load('sampled_2D_two_clusters.npy')
sampled_perturbed = np.load('test4.npy')
data = sampled_perturbed[0 : 1000]
#DEFINING NUMBER OF CLUSTERS AND DIMENSION OF DATA
k = 15
d = 2
#Key to store for random generation
rng_key = random.PRNGKey(0)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
@jit
def g(x):
    """
    Diggle Graton Modulation Function
    """
    #Shape parameters
    r = 5
    gamma = 0.5
    asymptote = 5
    logic0 = jnp.logical_and(0 < x,x <= 1e-5)  
    logic1 = jnp.logical_and( 1e-5 < x,x <= r)          
    logic2 = r < x       
    logic3 = x <= 0
    return (logic0 * x + logic1*(1e-5 +  jnp.power((x-1e-5)/r,1/gamma)) + logic2)*asymptote + logic3*1e-10

@jit
def sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,key = sample_from_MALA(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,data,cluster_allocs,h,mus,covs,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key

  
@jit
def sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs,h,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein when the cluster
    is empty
    """
    
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,subk1 = sample_from_MALA_empty(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,mus,covs,h,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
   

@jit
def spd_matrix_sqrt(X):
    eigvals, eigvecs = jnp.linalg.eigh(X)
    return eigvecs @ jnp.diag(jnp.sqrt(eigvals)) @ eigvecs.T

spd_matrix_sqrt_vec = vmap(spd_matrix_sqrt)
trace_vec = vmap(jnp.trace)

@jit
def wasserstein_to_normals(mu, cov, other_mus, other_covs):
    mean_dist = jnp.sum((other_mus - mu) ** 2, axis=1)
    cov_sqrt = spd_matrix_sqrt(cov)
    weird_term = trace_vec(spd_matrix_sqrt_vec(
        jnp.matmul(cov_sqrt, jnp.matmul(other_covs, cov_sqrt))))
    return g(jnp.nan_to_num(mean_dist + (trace_vec(other_covs) + jnp.trace(cov) - 2 * weird_term)))

@jit
def sum_dist_to_others(mu, cov, mask, other_mus, other_covs):   
    all_dists = jnp.log(wasserstein_to_normals(mu, cov, other_mus, other_covs))
    return jnp.sum(all_dists * mask)




@jit
def TargetFullCondEmptyCluster(mu,cov,mask,mus,covs):   
    """
    The full conditional from which we sample using Metropolis Hastings, written in a JAX-differentiable way,in
    the case where the cluster is empty
    """
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    #Normal Wishart Term
    normal_wishart = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    
    #Wasserstein Term
    wass_dist = sum_dist_to_others(mu, cov, mask, mus, covs) 
    return normal_wishart + wass_dist

@jit
def TargetFullCond(mu,cov,mask,h,cluster_allocs,data,mus,covs):   
    """
    The full conditional from which we sample using Metropolis Hastings, written in a JAX-differentiable way
    """
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    #Normal Wishart Term
    normal_wishart = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)

    #Data Term
    normal_data = jnp.sum(jnp.where(cluster_allocs == h,jtfd.MultivariateNormalFullCovariance(mu, cov).log_prob(data),0))
    
    #Wasserstein Term
    wass_dist = sum_dist_to_others(mu, cov, mask, mus, covs)    
    
    return normal_data + wass_dist + normal_wishart

@jit
def sample_from_MALA(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,data,cluster_allocs,h,mus,covs,bijector,key):
    """
    Sample new mean and covariance matrix through the bijection using MALA proposal
    """
    key , subk1 , subk2 = random.split(key,3)
    
    #Compute gradients of log wrt mu and cov
    mask = jnp.ones(mus.shape[0])
    mask = mask.at[h].set(0.0)
    mask = jnp.array(mask)
     
    grad_log_mu,grad_log_cov = grad(TargetFullCond,argnums=[0,1])(mu_old,cov_old,mask,h,cluster_allocs,data,mus,covs)
#     grad_out.append(grad_log_cov)
#     mus_out_mala.append(mus.copy())
#     covs_out_mala.append(covs.copy())
#     mask_out.append(mask.copy())
#     h_out.append(h)
#     mus_old.append(mu_old)
#     covs_old.append(cov_old)
#     cluster_allocs_out.append(cluster_allocs)
    
    #Compute cov proposal
    #print('cov_old' + str(cov_old))
    logic = jnp.any(jnp.isnan(spd_matrix_sqrt(cov_old + tau*grad_log_cov))).astype(float)
    #print('logic' + str(logic))
    #print('grad' + str(grad_log_cov))
    cov_mean = (1-logic)*(jnp.nan_to_num(cov_old + tau*grad_log_cov)) + logic*cov_old
    #print('cov_mean' + str(cov_mean))
    #cov_mean = cov_old + tau*grad_log_cov
    chol = jnp.linalg.cholesky(cov_mean)
    vec = bijector.inverse(chol)
    vec_sampl = jtfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))

    
    #Compute mu proposal
    mu_mean = (1-logic)*(mu_old + tau*grad_log_mu) + logic*mu_old
    mu = jtfd.MultivariateNormalFullCovariance(mu_mean, cov_prop_mu).sample(seed = subk1)
    
    return mu,cov,log_jac,key


@jit
def sample_from_MALA_empty(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,mus,covs,h,bijector,key):
    """
    Sample new mean and covariance matrix through the bijection using MALA proposal, in the case where cluster 
    is empty
    """
    key , subk1 , subk2 = random.split(key,3)
    
    #Compute gradients of log wrt mu and cov
    mask = jnp.ones(mus.shape[0])
    mask = mask.at[h].set(0.0)
    mask = jnp.array(mask)
    grad_log_mu,grad_log_cov = grad(TargetFullCondEmptyCluster,argnums=[0,1])(mu_old,cov_old,mask,mus,covs)

    #Compute mu proposal
    mu_mean = mu_old + tau*grad_log_mu
    mu = jtfd.MultivariateNormalFullCovariance(mu_mean, cov_prop_mu).sample(seed = subk1)
    
    #Compute cov proposal
    #cov_mean = cov_old + tau*grad_log_cov
    logic = jnp.isnan(spd_matrix_sqrt(cov_old + tau*grad_log_cov)).astype(float)
    cov_mean = (1-logic)*(jnp.nan_to_num(cov_old + tau*grad_log_cov)) + logic*cov_old
    chol = jnp.linalg.cholesky(cov_mean)
    vec = bijector.inverse(chol)
    vec_sampl = jtfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    
    return mu,cov,log_jac,key


@jit
def compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    cluster_allocs_expanded = jnp.expand_dims(cluster_allocs,axis = 1)
    nan_vec = jnp.repeat(jnp.array([[jnp.nan,jnp.nan]]),len(cluster_allocs),axis=0)
    clusdata = jnp.where(jnp.concatenate((cluster_allocs_expanded,cluster_allocs_expanded),axis = 1) == h,data,nan_vec)
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    # NW distribution terms
    num_0 = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu, cov).log_prob(clusdata))
    den_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu_old, cov_old).log_prob(clusdata))
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term



@jit
def compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    # NW distribution terms
    num = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))
    
    return num  - den + sum_ + jac_term


@jit
def evaluate_NW_log(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = jnp.linalg.inv(phi_n)
    chol = jnp.linalg.cholesky(W) 
    inv_cov = jnp.linalg.inv(x_cov)

    #f1 = jtfd.WishartTriL(df=nu_n, scale_tril=chol).log_prob(inv_cov)
    f1 = jtfd.WishartTriL(df=nu_n.astype(float), scale_tril=chol).log_prob(inv_cov)
    f2 = jtfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

@jit
def compute_Wasserstein(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = jnp.linalg.norm(mu_1 - mu_2, ord = 2)
    
    #Compute square root of cov_2
    s = jnp.sqrt(jnp.linalg.det(cov_2))
    t = jnp.sqrt(jnp.trace(cov_2) + 2*s)
    sqrt_C2 = 1/t * (cov_2 + s*jnp.eye(2))
    
    C1_sqrt_C2 = jnp.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = jnp.matmul(sqrt_C2,C1_sqrt_C2)
    
    #Compute square root of sqrt_C2_C1_sqrt_C2
    s = jnp.sqrt(jnp.linalg.det(sqrt_C2_C1_sqrt_C2))
    t = jnp.sqrt(jnp.trace(sqrt_C2_C1_sqrt_C2) + 2*s)
    mat_sqrt = 1/t * (sqrt_C2_C1_sqrt_C2 + s*jnp.eye(2))
    
    trace = jnp.trace(cov_1 + cov_2 - 2 * mat_sqrt)

    # Function g
    return g(norm+trace) 

@jit
def update_weights(cluster_allocs, weights, k, alpha,key):

    key, subk = random.split(key)
    n_clus = len(weights)
    n_by_clus = jnp.array([jnp.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = jnp.ones(n_clus) * alpha + n_by_clus
    return jtfd.Dirichlet(post_params.astype(float)).sample(seed = subk),key
    #return jtfd.Dirichlet(post_params).sample(seed = subk),key
@jit
def update_cluster_allocs(data, weights, mus, covs,key):
    #print(weights)
    key, subk = random.split(key)
    logprobs = jtfd.MultivariateNormalFullCovariance(mus, covs).log_prob(data[:, jnp.newaxis])
    logprobs += jnp.log(weights)
    probs =  jnp.exp(logprobs)/(jnp.sum(jnp.exp(logprobs), axis=1))[:,None]
    return jtfd.Categorical(probs=probs, validate_args=True).sample(seed = subk),key

# %%
def g(x):
    """
    Diggle Graton Modulation Function
    """
    #Shape parameters
    r = 5
    gamma = 0.5
    asymptote = 5
    logic0 = jnp.logical_and(0 < x,x <= 1e-5)  
    logic1 = jnp.logical_and( 1e-5 < x,x <= r)          
    logic2 = r < x       
    logic3 = x <= 0
    return (logic0 * x + logic1*(1e-5 +  jnp.power((x-1e-5)/r,1/gamma)) + logic2)*asymptote + logic3*1e-10

def sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    #Starting point of MH
    mu_old = mus[h].copy()
    cov_old = covs[h].copy()
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,key = sample_from_MALA(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,data,cluster_allocs,h,mus,covs,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key

  

def sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs,h,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein when the cluster
    is empty
    """
    
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,subk1 = sample_from_MALA_empty(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,mus,covs,h,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
   

def spd_matrix_sqrt(X):
    eigvals, eigvecs = jnp.linalg.eigh(X)
    return eigvecs @ jnp.diag(jnp.sqrt(eigvals)) @ eigvecs.T

spd_matrix_sqrt_vec = vmap(spd_matrix_sqrt)
trace_vec = vmap(jnp.trace)


def wasserstein_to_normals(mu, cov, other_mus, other_covs):
    mean_dist = jnp.sum((other_mus - mu) ** 2, axis=1)
    cov_sqrt = spd_matrix_sqrt(cov)
    weird_term = trace_vec(spd_matrix_sqrt_vec(
        jnp.matmul(cov_sqrt, jnp.matmul(other_covs, cov_sqrt))))
    return g(jnp.nan_to_num(mean_dist + (trace_vec(other_covs) + jnp.trace(cov) - 2 * weird_term)))


def sum_dist_to_others(mu, cov, mask, other_mus, other_covs):   
    all_dists = jnp.log(wasserstein_to_normals(mu, cov, other_mus, other_covs))
    return jnp.sum(all_dists * mask)



def TargetFullCondEmptyCluster(mu,cov,mask,mus,covs):   
    """
    The full conditional from which we sample using Metropolis Hastings, written in a JAX-differentiable way,in
    the case where the cluster is empty
    """
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    #Normal Wishart Term
    normal_wishart = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    
    #Wasserstein Term
    wass_dist = sum_dist_to_others(mu, cov, mask, mus, covs) 
    return normal_wishart + wass_dist


def TargetFullCond(mu,cov,mask,h,cluster_allocs,data,mus,covs):   
    """
    The full conditional from which we sample using Metropolis Hastings, written in a JAX-differentiable way
    """
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    #Normal Wishart Term
    normal_wishart = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)

    #Data Term
    normal_data = jnp.sum(jnp.where(cluster_allocs == h,jtfd.MultivariateNormalFullCovariance(mu, cov).log_prob(data),0))
    
    #Wasserstein Term
    wass_dist = sum_dist_to_others(mu, cov, mask, mus, covs)    
    
    return normal_data + wass_dist + normal_wishart


def sample_from_MALA(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,data,cluster_allocs,h,mus,covs,bijector,key):
    """
    Sample new mean and covariance matrix through the bijection using MALA proposal
    """
    key , subk1 , subk2 = random.split(key,3)
    
    #Compute gradients of log wrt mu and cov
    mask = jnp.ones(mus.shape[0])
    mask = mask.at[h].set(0.0)
    mask = jnp.array(mask)
     
    print('cov_old' + str(cov_old))
    print('mu_old' + str(mu_old))
    print('h' + str(h))
    grad_log_mu,grad_log_cov = grad(TargetFullCond,argnums=[0,1])(mu_old,cov_old,mask,h,cluster_allocs,data,mus,covs)
    print('grad_cov' + str(grad_log_cov))
    print('grad_mu' + str(grad_log_mu))
    grad_out.append(grad_log_cov)
    mus_out_mala.append(mus.copy())
    covs_out_mala.append(covs.copy())
    mask_out.append(mask.copy())
    h_out.append(h)
    mus_old.append(mu_old)
    covs_old.append(cov_old)
    cluster_allocs_out.append(cluster_allocs)

    #Compute mu proposal
    mu_mean = mu_old + tau*grad_log_mu
    mu = jtfd.MultivariateNormalFullCovariance(mu_mean, cov_prop_mu).sample(seed = subk1)
    
    #Compute cov proposal
    #logic = jnp.any(jnp.isnan(spd_matrix_sqrt(cov_old + tau*grad_log_cov)))
    #print('logic' + str(logic))
    #cov_mean = (1-logic)*(np.nan_to_num(cov_old + tau*grad_log_cov)) + logic*cov_old
    cov_mean = cov_old + tau*grad_log_cov
    print('cov_mean' + str(cov_mean))
    chol = jnp.linalg.cholesky(cov_mean)
    print('chol' + str(chol) )
    vec = bijector.inverse(chol)
    vec_sampl = jtfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    print('sampled_mu' + str(mu))
    return mu,cov,log_jac,key



def sample_from_MALA_empty(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,mus,covs,h,bijector,key):
    """
    Sample new mean and covariance matrix through the bijection using MALA proposal, in the case where cluster 
    is empty
    """
    key , subk1 , subk2 = random.split(key,3)
    
    #Compute gradients of log wrt mu and cov
    mask = jnp.ones(mus.shape[0])
    mask = mask.at[h].set(0.0)
    mask = jnp.array(mask)
    grad_log_mu,grad_log_cov = grad(TargetFullCondEmptyCluster,argnums=[0,1])(mu_old,cov_old,mask,mus,covs)

    #Compute mu proposal
    mu_mean = mu_old + tau*grad_log_mu
    mu = jtfd.MultivariateNormalFullCovariance(mu_mean, cov_prop_mu).sample(seed = subk1)
    
    #Compute cov proposal
    cov_mean = cov_old + tau*grad_log_cov
    #logic = jnp.isnan(spd_matrix_sqrt(cov_old + tau*grad_log_cov))
    #cov_mean = (1-logic)*(np.nan_to_num(cov_old + tau*grad_log_cov)) + logic*cov_old
    chol = jnp.linalg.cholesky(cov_mean)
    vec = bijector.inverse(chol)
    vec_sampl = jtfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    
    return mu,cov,log_jac,key



def compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    cluster_allocs_expanded = jnp.expand_dims(cluster_allocs,axis = 1)
    nan_vec = jnp.repeat(jnp.array([[jnp.nan,jnp.nan]]),len(cluster_allocs),axis=0)
    clusdata = jnp.where(jnp.concatenate((cluster_allocs_expanded,cluster_allocs_expanded),axis = 1) == h,data,nan_vec)
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    # NW distribution terms
    num_0 = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu, cov).log_prob(clusdata))
    den_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu_old, cov_old).log_prob(clusdata))
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term




def compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    # NW distribution terms
    num = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))
    
    return num  - den + sum_ + jac_term



def evaluate_NW_log(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = jnp.linalg.inv(phi_n)
    chol = jnp.linalg.cholesky(W) 
    inv_cov = jnp.linalg.inv(x_cov)

    f1 = jtfd.WishartTriL(df=nu_n, scale_tril=chol).log_prob(inv_cov)
    #f1 = jtfd.WishartTriL(df=nu_n.astype(float), scale_tril=chol).log_prob(inv_cov)
    f2 = jtfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2


def compute_Wasserstein(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = jnp.linalg.norm(mu_1 - mu_2, ord = 2)
    
    #Compute square root of cov_2
    s = jnp.sqrt(jnp.linalg.det(cov_2))
    t = jnp.sqrt(jnp.trace(cov_2) + 2*s)
    sqrt_C2 = 1/t * (cov_2 + s*jnp.eye(2))
    
    C1_sqrt_C2 = jnp.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = jnp.matmul(sqrt_C2,C1_sqrt_C2)
    
    #Compute square root of sqrt_C2_C1_sqrt_C2
    s = jnp.sqrt(jnp.linalg.det(sqrt_C2_C1_sqrt_C2))
    t = jnp.sqrt(jnp.trace(sqrt_C2_C1_sqrt_C2) + 2*s)
    mat_sqrt = 1/t * (sqrt_C2_C1_sqrt_C2 + s*jnp.eye(2))
    
    trace = jnp.trace(cov_1 + cov_2 - 2 * mat_sqrt)

    # Function g
    return g(norm+trace) 


def update_weights(cluster_allocs, weights, k, alpha,key):

    key, subk = random.split(key)
    n_clus = len(weights)
    n_by_clus = jnp.array([jnp.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = jnp.ones(n_clus) * alpha + n_by_clus
    #return jtfd.Dirichlet(post_params.astype(float)).sample(seed = subk),key
    return jtfd.Dirichlet(post_params).sample(seed = subk),key
    

def update_cluster_allocs(data, weights, mus, covs,key):
    #print(weights)
    key, subk = random.split(key)
    logprobs = jtfd.MultivariateNormalFullCovariance(mus, covs).log_prob(data[:, jnp.newaxis])
    logprobs += jnp.log(weights)
    probs =  jnp.exp(logprobs)/(jnp.sum(jnp.exp(logprobs), axis=1))[:,None]
    return jtfd.Categorical(probs=probs, validate_args=True).sample(seed = subk),key

# %%
def run_one_gibbs(data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Run one gibbs sampler iteration
    Takes in input values of the previous iteration and sample the new values from sample_uniq_vals_fullcond, update_weights and update_cluster_allocs
    Returns:   
    
    -cluster_allocs: for every data point, the cluster assigned
    -uniq_vals: array of parameters of the distributions. Matrix has d rows of the type:[mu[0], var[0,0], var[0,1]]
    -weights: array with the weights of the clusters 
     """
    key, subk = random.split(key)
    n_clus = len(weights)
    for h in range(n_clus):

        #Extract data assigned to cluster h and sample 
        clusdata = data[cluster_allocs == h]
        if(len(clusdata) != 0):
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,tau,key)
        else:
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,tau,key)


    weights,key = update_weights(cluster_allocs ,weights, k, alpha,key)

    cluster_allocs,key = update_cluster_allocs(data, weights, mus,covs,key)

    return cluster_allocs, mus,covs, weights, acc_rate,key

def run_mcmc(data, k, key , niter=1000, nburn=300, thin=5 ): 
    """
    Runs entire MCMC
    Takes in input data, number of clusters, number of iterations, burn-in and thin
    Returns the parameters recorded after burn-in phase
    """

    b = time.time() # only to measure time
    
    #Bijector setup
    jtfb = jtfp.bijectors
    bij = jtfb.Chain([
            jtfb.TransformDiagonal(jtfb.Softplus()),
            jtfb.FillTriangular()])

    #Starting Values
    cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
    weights = jnp.ones(k)/k
    alpha = 0.1
    lam = 0.1
    mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.eye(2) ).sample(k,seed = key))
    covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(2)) ).sample(k,seed = key))
    
    #Proposal Covariances
    tau = 0.000001
    cov_prop_cov = jnp.sqrt(2*tau)*jnp.eye(3) #covariance matrix for the covariance sampling
    cov_prop_mu =  jnp.sqrt(2*tau)*jnp.eye(2)   #covariance matrix for the mean sampling
    
    #Output values
    allocs_out = []
    mus_out = []
    covs_out = []
    weights_out = []
    acc_rates = []
    
    #Useful value
    data_mean = np.mean(data, axis = 0)
    
    #Iterations
    for i in range(niter):
        cluster_allocs, mus,covs, weights, acc_rate,key = run_one_gibbs(
            data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,tau,key)
        acc_rates.append(acc_rate)
        
        if i > nburn and i % thin == 0:
            allocs_out.append(cluster_allocs)
            mus_out.append(mus.copy())
            covs_out.append(covs.copy())
            weights_out.append(weights)
            
        if i % 10 == 0 and i > 11:
            a = time.time()
            print("\rIter {0} / {1}".format(i+1, niter) + " Remaining minutes: " + str(round((a-b)*(niter-i)/(60*10) ,1)) , flush=False, end=" ")
            b = time.time()
            print("Acceptance rate: " + str(np.mean(acc_rates[-10:])))
            
    return allocs_out, mus_out,covs_out, weights_out,acc_rates

# %%
#RUNNING THE MCMC
grad_out = []
mus_out_mala = []
covs_out_mala = []
mask_out = []
h_out = []
mus_old = []
covs_old = []
cluster_allocs_out = []
logics = []
start = time.time()
allocs_out, mus_out,covs_out, weights_out,accept_rate_out = run_mcmc(data, k,rng_key , niter = 2000,nburn = 1000,thin = 5)
end = time.time()
print("Total time: " + str(end-start))
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:3556: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# skip assert _assert_compare_to_zero
# skip assert _assert_near
# Iter 21 / 2000 Remaining minutes: 148.6 Acceptance rate: 0.5695669
# Iter 31 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.58103615
# Iter 41 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.6657874
# Iter 51 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.4904418
# Iter 61 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.53582495
# Iter 71 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.7509749
# Iter 81 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.68870914
# Iter 91 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.59361184
# Iter 101 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.44581288
# Iter 111 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.55114454
# Iter 121 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.45194197
# Iter 131 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.26908702
# Iter 141 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.4022824
# Iter 151 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.3774963
# Iter 161 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.398225
# Iter 171 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.27019438
# Iter 181 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.31268722
# Iter 191 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.38027132
# Iter 201 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.5655147
# Iter 211 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.45269984
# Iter 221 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.20081277
# Iter 231 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.45214796
# Iter 241 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.373017
# Iter 251 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.20272359
# Iter 261 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.44196528
# Iter 271 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.30896974
# Iter 281 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.46686202
# Iter 291 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.5445059
# Iter 301 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.52542794
# Iter 311 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.6167291
# Iter 321 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.22175768
# Iter 331 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.5134883
# Iter 341 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.36247268
# Iter 351 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.5976247
# Iter 361 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.33901238
# Iter 371 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.45892295
# Iter 381 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.37668422
# Iter 391 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.48073372
# Iter 401 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.17561749
# Iter 411 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.40130773
# Iter 421 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.27163607
# Iter 431 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.39612025
# Iter 441 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.30498987
# Iter 451 / 2000 Remaining minutes: 0.8 Acceptance rate: 0.32744354
# Iter 461 / 2000 Remaining minutes: 1.1 Acceptance rate: 0.5716753
# Iter 471 / 2000 Remaining minutes: 1.0 Acceptance rate: 0.49657893
# Iter 481 / 2000 Remaining minutes: 1.1 Acceptance rate: 0.43927345
# Iter 491 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.31706348
# Iter 501 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.18539225
# Iter 511 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.5096987
# Iter 521 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.37400538
# Iter 531 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.24202362
# Iter 541 / 2000 Remaining minutes: 0.9 Acceptance rate: 0.37589508
# Iter 551 / 2000 Remaining minutes: 0.8 Acceptance rate: 0.4853263
# Iter 561 / 2000 Remaining minutes: 1.0 Acceptance rate: 0.46098748
# Iter 571 / 2000 Remaining minutes: 0.6 Acceptance rate: 0.35972658
# Iter 581 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.3951632
# Iter 591 / 2000 Remaining minutes: 0.7 Acceptance rate: 0.46023798
# Iter 601 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.5333222
# Iter 611 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.5953143
# Iter 621 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.52143437
# Iter 631 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.47671723
# Iter 641 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.32195497
# Iter 651 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.40755826
# Iter 661 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.56441677
# Iter 671 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.21752834
# Iter 681 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.5760447
# Iter 691 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.22956936
# Iter 701 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.30853176
# Iter 711 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.49600154
# Iter 721 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.2936477
# Iter 731 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.44809666
# Iter 741 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.5035192
# Iter 751 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.3214321
# Iter 761 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.2549215
# Iter 771 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.2868472
# Iter 781 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.43721667
# Iter 791 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.23760788
# Iter 801 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.25381142
# Iter 811 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.34625807
# Iter 821 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.43248755
# Iter 831 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.45021778
# Iter 841 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.36604905
# Iter 851 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.40893397
# Iter 861 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.6256306
# Iter 871 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.3841607
# Iter 881 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.60699135
# Iter 891 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.48741212
# Iter 901 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.4228797
# Iter 911 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.313598
# Iter 921 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.30909073
# Iter 931 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.38681823
# Iter 941 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.4239611
# Iter 951 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.49770933
# Iter 961 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.28362468
# Iter 971 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.45898813
# Iter 981 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.6378383
# Iter 991 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.26897916
# Iter 1001 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.3534218
# Iter 1011 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.4568406
# Iter 1021 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.4269542
# Iter 1031 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.3548454
# Iter 1041 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.36837652
# Iter 1051 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.3518159
# Iter 1061 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.31399974
# Iter 1071 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.28292665
# Iter 1081 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.24376383
# Iter 1091 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.23678274
# Iter 1101 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.4547875
# Iter 1111 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.3984816
# Iter 1121 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.52149236
# Iter 1131 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.11660244
# Iter 1141 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.54823226
# Iter 1151 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.35421947
# Iter 1161 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.38080627
# Iter 1171 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.3977133
# Iter 1181 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.2766417
# Iter 1191 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.49407062
# Iter 1201 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.32847354
# Iter 1211 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.1576654
# Iter 1221 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.46243143
# Iter 1231 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.37178078
# Iter 1241 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.54664147
# Iter 1251 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.43688798
# Iter 1261 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.46522427
# Iter 1271 / 2000 Remaining minutes: 0.5 Acceptance rate: 0.3314514
# Iter 1281 / 2000 Remaining minutes: 0.4 Acceptance rate: 0.72126955
# Iter 1291 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.3002733
# Iter 1301 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.3699047
# Iter 1311 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.3997322
# Iter 1321 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.18622755
# Iter 1331 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.25188228
# Iter 1341 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.3360607
# Iter 1351 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.42986903
# Iter 1361 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.16721168
# Iter 1371 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.26331034
# Iter 1381 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.21151412
# Iter 1391 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.52232647
# Iter 1401 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.66247815
# Iter 1411 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.2671961
# Iter 1421 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.49440613
# Iter 1431 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.4249178
# Iter 1441 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.35088757
# Iter 1451 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.28333497
# Iter 1461 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.27365848
# Iter 1471 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.43042606
# Iter 1481 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.29032683
# Iter 1491 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.4053503
# Iter 1501 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.55432814
# Iter 1511 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.24247399
# Iter 1521 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.47208348
# Iter 1531 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.3881804
# Iter 1541 / 2000 Remaining minutes: 0.3 Acceptance rate: 0.30780545
# Iter 1551 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.29053563
# Iter 1561 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.26708424
# Iter 1571 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.53437024
# Iter 1581 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.22802067
# Iter 1591 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.22169769
# Iter 1601 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.29357153
# Iter 1611 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.4097318
# Iter 1621 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.31723613
# Iter 1631 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.47851467
# Iter 1641 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.38085413
# Iter 1651 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.7453394
# Iter 1661 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.49379355
# Iter 1671 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.3391822
# Iter 1681 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.3871346
# Iter 1691 / 2000 Remaining minutes: 0.2 Acceptance rate: 0.3529245
# Iter 1701 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.310574
# Iter 1711 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.28387126
# Iter 1721 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.2952654
# Iter 1731 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.39217025
# Iter 1741 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.29793185
# Iter 1751 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.18147108
# Iter 1761 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.41108504
# Iter 1771 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.208608
# Iter 1781 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.33336097
# Iter 1791 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.15287188
# Iter 1801 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.575095
# Iter 1811 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.32984224
# Iter 1821 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.3077093
# Iter 1831 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.37468615
# Iter 1841 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.23420084
# Iter 1851 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.295317
# Iter 1861 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.40941596
# Iter 1871 / 2000 Remaining minutes: 0.0 Acceptance rate: 0.46347743
# Iter 1881 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.3387495
# Iter 1891 / 2000 Remaining minutes: 0.1 Acceptance rate: 0.2203104
# Iter 1901 / 2000 Remaining minutes: 0.0 Acceptance rate: 0.33659822
# Iter 1911 / 2000 Remaining minutes: 0.0 Acceptance rate: 0.6264168
# Iter 1921 / 2000 Remaining minutes: 0.0 Acceptance rate: 0.33730492
# Iter 1931 / 2000 Remaining minutes: 0.0 Acceptance rate: 0.3983574
# Iter 1941 / 2000 Remaining minutes: 0.0 Acceptance rate: 0.3691262
# Iter 1951 / 2000 Remaining minutes: 0.0 Acceptance rate: 0.38476628
# Iter 1961 / 2000 Remaining minutes: 0.0 Acceptance rate: 0.25851414
# Iter 1971 / 2000 Remaining minutes: 0.0 Acceptance rate: 0.29079014
# Iter 1981 / 2000 Remaining minutes: 0.0 Acceptance rate: 0.45867777
# Iter 1991 / 2000 Remaining minutes: 0.0 Acceptance rate: 0.34919637
# Total time: 82.43556308746338

# %%
idx = 25
tau = 0.00001
mu_old = jnp.array(mus_old[idx])
cov_old = jnp.array(covs_old[idx])
mask = mask_out[idx]
h = h_out[idx]
#mask = mask.at[h].set(0.0)
cluster_allocs = cluster_allocs_out[idx]
mus = mus_out_mala[idx]
covs = jnp.array(covs_out_mala[idx])
grad_log_mu,grad_log_cov = grad(TargetFullCond,argnums=[0,1])(mu_old,cov_old,mask,h,cluster_allocs,data,mus,covs)
print(grad_log_cov)
print(grad_log_mu)
print(grad_out[idx])
print(mus)
print(covs)
print(h)
# Out:
# [[nan nan]
#  [nan nan]]
# [-18.156784  18.274538]
# [[nan nan]
#  [nan nan]]
# [[  1.926586     2.8632243 ]
#  [  1.2591225    3.2164013 ]
#  [  3.3939672    2.7689903 ]
#  [  1.8030052    2.8075926 ]
#  [  1.6868743    1.8586217 ]
#  [  0.02280413   2.4386106 ]
#  [  3.158293     2.3164408 ]
#  [  2.9391665    2.0392094 ]
#  [  1.7458706    3.4559102 ]
#  [  2.5475526    0.44294983]
#  [ 18.637505   -17.862051  ]
#  [  3.1095598    0.8207809 ]
#  [  1.1801625    0.7429019 ]
#  [  1.6035874    1.7520187 ]
#  [  1.7809496    0.81082183]]
# [[[ 1.5463121e+00  1.5902870e+00]
#   [ 1.5902870e+00  3.8346939e+00]]
#
#  [[ 1.7368763e+01 -8.8611263e-01]
#   [-8.8611263e-01  4.1838160e+00]]
#
#  [[ 9.9390399e-01 -1.1447761e+00]
#   [-1.1447761e+00  4.4123130e+00]]
#
#  [[ 4.0565011e-01 -9.8029887e-03]
#   [-9.8029887e-03  3.7797525e+00]]
#
#  [[ 4.0638518e-01  6.1620677e-01]
#   [ 6.1620677e-01  5.8763676e+00]]
#
#  [[ 5.8440280e-01 -5.2275097e-01]
#   [-5.2275097e-01  1.7811315e+00]]
#
#  [[ 5.7029996e+00  5.1189022e+00]
#   [ 5.1189022e+00  1.1651333e+01]]
#
#  [[ 2.2173879e+00 -1.6566101e+00]
#   [-1.6566101e+00  1.7133652e+00]]
#
#  [[ 4.0410614e-01  4.0622834e-02]
#   [ 4.0622834e-02  8.0851418e-01]]
#
#  [[ 1.3018987e+00 -1.8350651e-02]
#   [-1.8350651e-02  3.3577321e+00]]
#
#  [[ 1.5442646e+06 -1.7986189e+06]
#   [-1.7986189e+06  2.0948714e+06]]
#
#  [[ 3.5171494e+00 -8.6725038e-01]
#   [-8.6725038e-01  8.4905171e-01]]
#
#  [[ 5.0410980e-01  4.5976685e-03]
#   [ 4.5976685e-03  3.1732252e-01]]
#
#  [[ 9.6643066e-01 -3.6082074e-01]
#   [-3.6082074e-01  7.8600162e-01]]
#
#  [[ 4.8138881e+00 -6.3508103e-04]
#   [-6.3508103e-04  6.3090172e+00]]]
# 10

# %%
for idx in range(len(mus_out_mala)):
    mu_old = jnp.array(mus_old[idx])
    cov_old = jnp.array(covs_old[idx])
    mask = mask_out[idx]
    h = h_out[idx]
    mask = mask.at[h].set(0.0)
    cluster_allocs = cluster_allocs_out[idx]
    mus = mus_out_mala[idx]
    covs = jnp.array(covs_out_mala[idx])
    grad_log_mu,grad_log_cov = grad(TargetFullCond,argnums=[0,1])(mu_old,cov_old,mask,h,cluster_allocs,data,mus,covs)
    print(grad_log_cov)

# %%
yy = []
for i in range(len(allocs_out)):
    yy.append(len(np.unique(allocs_out[i])))

xx,cc = np.unique(yy,return_counts=True)
print(xx,cc)
plt.bar(xx,cc)
# Out:
# [ 6  7  8  9 10] [21 75 68 31  4]
# <BarContainer object of 5 artists>

# %%
for h in range(k):
    currd = data[allocs_out[-1] == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [mu[i][0] for mu in mus_out]
    second_comp = [mu[i][1] for mu in mus_out]

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__mu_x", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_mu_y", fontsize=16)

    plt.show()

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [covs[i][0,0] for covs in covs_out]
    second_comp = [covs[i][0,1] for covs in covs_out]
    third_comp = [covs[i][1,1] for covs in covs_out]

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__cov_xx", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_cov_xy", fontsize=16)
    
    axes[2].plot(np.arange(len(third_comp)), third_comp,)
    axes[2].set_title(str(i) + "_cov_yy", fontsize=16)

    plt.show()

# %%
def get_psm(clus_alloc_chain):
    """
    Returns the posterior similarity matrix, i.e.
        out[i, j] = P(c_i == c_j | all the rest)
    for each pair of observations
    """
    #Fare confronto tra colonna i e j della matrice e poi calcolare da li
    c_chain = np.vstack(clus_alloc_chain)
    out = np.zeros((c_chain.shape[1], c_chain.shape[1]))
    for i in range(c_chain.shape[1]):
        for j in range(c_chain.shape[1]):
            out[i,j] = np.sum(c_chain[:,i] == c_chain[:,j]) / c_chain.shape[0]
            
    return out


def minbinder_sample(clus_alloc_chain, psm):
    """
    Finds the iteration for which the Binder loss is minimized
    and returns the associated clustering
    """
    losses = np.zeros(len(clus_alloc_chain))
    c_chain = np.vstack(clus_alloc_chain)
    
    # You can either cycle through the iterations, or 
    # cycle through the entries in the PSM [i, j]
    # and vectorize the same operation for each iteration!
    
    mat = np.zeros( ( c_chain.shape[0], c_chain.shape[1]**2 ) )
    k = 0
    for i in range(c_chain.shape[1]):
        for j in range(c_chain.shape[1]):
            mat[:,k] = ( (c_chain[:,i] == c_chain[:,j]).astype(int) - psm[i,j] * np.ones(c_chain.shape[0]) ) **2
            k = k+1
    
    losses = np.sum(mat, axis = 1)
    
    best_iter = np.argmin(losses)
    return clus_alloc_chain[best_iter]



def unique_vals_given_clus(unique_vals_chain, clus_alloc_chain, best_clus,n_clus):
    #Finds the unique values associated to the best clusters obtained during MCMC
    
    c_allocs = np.stack(clus_alloc_chain)
    uniq_vals = np.stack(unique_vals_chain)
    means = uniq_vals[:, :, : , 0]
    variances = uniq_vals[:, :, : , 1:3]
    out1 = []
    out2 = []
    for h in range(n_clus):
        data_idx = np.where(best_clus == h)[0]
        uniq_vals_idx = c_allocs[:, data_idx] # -> Matrix [n_iter x n_data_in_clus]
        means_by_iter = np.empty((c_allocs.shape[0], len(data_idx),2))
        vars_by_iter = np.empty((c_allocs.shape[0], len(data_idx),2,2))
        for i in range(c_allocs.shape[0]):
            means_by_iter[i, :] = means[i,uniq_vals_idx[i,:],:]
            vars_by_iter[i, :] = variances[i,uniq_vals_idx[i,:]]

        avg_mean_by_iter = np.mean(means_by_iter , axis = 1)
        avg_var_by_iter = np.mean(vars_by_iter , axis = 1)
        
        muhat = np.mean(avg_mean_by_iter,axis=0)
        sigsqhat = np.mean(avg_var_by_iter,axis=0)
        out1.append(np.array(muhat))
        out2.append(np.array(sigsqhat))
    
    #If there are no points in certain clusters, the output would be full of NANs for the cluster. This gives problems
    #I replace the NANs with some 0
    for i in range(len(out1)):
        if(np.any(np.isnan(out1[i]))):
            out1[i] = np.zeros(shape = out1[i].shape)
        if(np.any(np.isnan(out2[i]))):
            out2[i] = np.eye(N = out2[i].shape[0])
    
        
    return out1,out2


psm = get_psm(allocs_out)
best_clus = minbinder_sample(allocs_out,psm)

uniq_vals_out = []
for n in range(len(mus_out)):
    mus = mus_out[n]
    covs = covs_out[n]
    arr = np.zeros(shape=(k,2,3))
    for i in range(k):
        mu = mus[i]
        cov = covs[i]
        arr[i,:,:] = np.array( [ [mu[0],cov[0,0],cov[0,1]] , [mu[1],cov[1,0],cov[1,1]] ])
    uniq_vals_out.append(arr)
    
mu_lis,var_lis = unique_vals_given_clus(uniq_vals_out, allocs_out, best_clus,k)
weights = np.sum(best_clus == np.arange(k)[:, np.newaxis], axis=1) / len(data)
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/leopere/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:182: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)

# %%
for h in range(k):
    currd = data[best_clus == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])
