# %%
# %%javascript
# MathJax.Hub.Config({
#     TeX: { equationNumbers: { autoNumber: "AMS" } }
# });

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions

np.random.seed(0)

# %%
sampled = np.load('sampled_2D.npy')

# %%
data = sampled

# %%
k = 4
d = 2

# %%
M = np.array(np.diag(5*np.ones(d)))
MM = tf.convert_to_tensor(M)

# %%
def run_one_gibbs(data, cluster_allocs, uniq_vals, weights):

    n_clus = len(weights)
    
    for h in range(n_clus):
        clusdata = data[cluster_allocs == h]
        if len(clusdata) == 0:
            uniq_vals[h, :] = sample_uniq_vals_prior()
        else:
            uniq_vals[h, :] = sample_uniq_vals_fullcond(clusdata)
    
    cluster_allocs = update_cluster_allocs(data, weights, uniq_vals)
    
    weights = update_weights(cluster_allocs, n_clus, k)
    
    return cluster_allocs, uniq_vals, weights

def run_mcmc(data, k, niter=5000, nburn=3000, thin=5):    #niter=7500, nburn=2500,
    cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
    weights = np.ones(k) / k
    
    # 4  bivariate normal e 4 matrices 2x2
    uniq_vals = np.dstack([
        tfd.MultivariateNormalFullCovariance(np.mean(np.array(data)), np.linalg.inv(np.diag(np.ones(d)))).sample(k),
        tfd.WishartLinearOperator(df=d+1, scale=tf.convert_to_tensor(np.diag(5*np.ones(d)))).sample(k)])
    
    allocs_out = []
    uniq_vals_out = []
    weights_out = []
    
    for i in range(niter):
        cluster_allocs, uniq_vals, weights = run_one_gibbs(
            data, cluster_allocs, uniq_vals, weights)
        
        if i > nburn and i % thin == 0:
            allocs_out.append(cluster_allocs)
            uniq_vals_out.append(uniq_vals)
            weights_out.append(weights)
            
        if i % 10 == 0:
            print("\rIter {0} / {1}".format(i+1, niter), flush=True, end=" ")
            
    return allocs_out, uniq_vals_out, weights_out

# %%
def update_cluster_allocs(data, weights, uniq_vals):
    
    #logprobs = tfd.Normal(uniq_vals[:, 0], np.sqrt(uniq_vals[:, 1:2])).log_prob(data[:, np.newaxis])
    logprobs = tfd.MultivariateNormalFullCovariance(uniq_vals[:,:,0], tf.linalg.sqrtm(uniq_vals[:,:,1:3])).log_prob(data[:, np.newaxis])
    logprobs += np.log(weights)
    probs =  np.exp(logprobs)/np.sum(np.exp(logprobs))
    for i in range(len(probs)):
        if np.all(probs[i] == 0):
            probs[i] = np.ones(k) / k
    return tfd.Categorical(probs=probs).sample()


def update_weights(cluster_allocs, n_clus, k):

    n_by_clus = np.array([np.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = np.ones(k) / k + n_by_clus
    return tfd.Dirichlet(post_params.astype(float)).sample()


def sample_uniq_vals_prior():
    
    var = tfd.WishartLinearOperator(df=d+1, scale=np.diag(5*np.ones(d))).sample()
    mu = tfd.MultivariateNormalFullCovariance(np.mean(np.array(data)), tf.linalg.inv(var)).sample()
    return np.array([mu, var])
    

def sample_uniq_vals_fullcond(clusdata):
    
    n=len(clusdata)
    var = tfd.WishartLinearOperator(df=d+1, scale=np.diag(5*np.ones(d))+n*np.var(clusdata)+(n/1+n)*np.dot(np.mean(clusdata)-np.mean(data),np.mean(clusdata)-np.mean(data))).sample()
    mu = tfd.MultivariateNormalFullCovariance((np.mean(np.array(data))+n*np.mean(clusdata))/(1+n), np.array(tf.linalg.inv((1+n)*var))).sample()
    invar = tf.linalg.inv(var)
    return np.array([[mu[0], invar[0,0], invar[0,1]],[mu[1], invar[1,0], invar[1,1]]])

# %%
allocs_out, uniq_vals_out, weights_out = run_mcmc(data, k)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9348/1481455572.py in <module>
# ----> 1 allocs_out, uniq_vals_out, weights_out = run_mcmc(data, k)
#
# ~\AppData\Local\Temp/ipykernel_9348/3581725709.py in run_mcmc(data, k, niter, nburn, thin)
#      23     uniq_vals = np.dstack([
#      24         tfd.MultivariateNormalFullCovariance(np.mean(np.array(data)), np.linalg.inv(np.diag(np.ones(d)))).sample(k),
# ---> 25         tfd.WishartLinearOperator(df=d+1, scale=tf.convert_to_tensor(np.diag(5*np.ones(d)))).sample(k)])
#      26
#      27     allocs_out = []
#
# c:\users\danie\appdata\local\programs\python\python38\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\users\danie\appdata\local\programs\python\python38\lib\site-packages\tensorflow_probability\substrates\numpy\distributions\distribution.py in wrapped_init(***failed resolving arguments***)
#     343       # called, here is the place to do it.
#     344       self_._parameters = None
# --> 345       default_init(self_, *args, **kwargs)
#     346       # Note: if we ever want to override things set in `self` by subclass
#     347       # `__init__`, here is the place to do it.
#
# c:\users\danie\appdata\local\programs\python\python38\lib\site-packages\tensorflow_probability\substrates\numpy\distributions\wishart.py in __init__(self, df, scale, input_output_cholesky, validate_args, allow_nan_stats, name)
#     124           df, name='df', dtype=dtype)
#     125
# --> 126       super(WishartLinearOperator, self).__init__(
#     127           dtype=dtype,
#     128           validate_args=validate_args,
#
# c:\users\danie\appdata\local\programs\python\python38\lib\site-packages\tensorflow_probability\substrates\numpy\distributions\distribution.py in __init__(self, dtype, reparameterization_type, validate_args, allow_nan_stats, parameters, graph_parents, name)
#     631     if not self._defer_all_assertions:
#     632       self._initial_parameter_control_dependencies = tuple(
# --> 633           d for d in self._parameter_control_dependencies(is_init=True)
#     634           if d is not None)
#     635     else:
#
# c:\users\danie\appdata\local\programs\python\python38\lib\site-packages\tensorflow_probability\substrates\numpy\distributions\wishart.py in _parameter_control_dependencies(self, is_init)
#     457             'scale.dtype={} is not a floating-point type.'.format(
#     458                 self._scale.dtype))
# --> 459       if not self._scale.is_square:
#     460         raise ValueError('scale must be square.')
#     461       dtype_util.assert_same_float_dtype([self._df, self._scale])
#
# c:\users\danie\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\framework\ops.py in __getattr__(self, name)
#     399         from tensorflow.python.ops.numpy_ops import np_config
#     400         np_config.enable_numpy_behavior()""".format(type(self).__name__, name))
# --> 401     self.__getattribute__(name)
#     402
#     403   @staticmethod
#
# AttributeError: 'tensorflow.python.framework.ops.EagerTensor' object has no attribute 'is_square'

# %%
plt.hist(data, density=True, alpha=0.1)
for h in range(k):
    currd = data[allocs_out[-1] == h]
    plt.scatter(currd, np.zeros_like(currd) + 0.001 * (h+1))

# %%
for h in range(k):
    currd = data[allocs_out[-1] == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd],)
