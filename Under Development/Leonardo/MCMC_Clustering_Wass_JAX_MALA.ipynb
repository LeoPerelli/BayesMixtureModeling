# %%
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pandas as pd
import time
import scipy

#Separate import for numpy and jax.numpy to have major felxibility
import jax.numpy as jnp
import numpy as np
from jax import jit,lax,random,grad,vmap
from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions
from tensorflow_probability.substrates import jax as jtfp
jtfd = jtfp.distributions

np.random.seed(0)

# %%
#sampled_perturbed = np.load('Data/sampled_2D_two_clusters.npy')
sampled_perturbed = np.load('test4.npy')
data = sampled_perturbed[0 : 1000]
#DEFINING NUMBER OF CLUSTERS AND DIMENSION OF DATA
k = 15
d = 2
#Key to store for random generation
rng_key = random.PRNGKey(0)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
x = np.linspace(-1e-9,1e-9,1000)
y = g(x)
plt.plot(x,y)

grad(g)(6.0)
# Out:
# DeviceArray(0., dtype=float32)

# %%
@jit
def g(x):
    """
    Diggle Graton Modulation Function
    """
    #Shape parameters
    r = 5
    gamma = 0.5
    asymptote = 5
    logic0 = jnp.logical_and(0 < x,x <= 1e-5)  
    logic1 = jnp.logical_and( 1e-5 < x,x <= r)          
    logic2 = r < x       
    logic3 = x <= 0
    return (logic0 * x + logic1*(1e-5 +  jnp.power((x-1e-5)/r,1/gamma)) + logic2)*asymptote + logic3*1e-10

@jit
def sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,key = sample_from_MALA(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,data,cluster_allocs,h,mus,covs,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key

  
@jit
def sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs,h,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein when the cluster
    is empty
    """
    
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,subk1 = sample_from_MALA_empty(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,mus,covs,h,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
   
@jit
def spd_matrix_sqrt(X):
    eigvals, eigvecs = jnp.linalg.eigh(X)
    return eigvecs @ jnp.diag(jnp.sqrt(eigvals)) @ eigvecs.T

spd_matrix_sqrt_vec = vmap(spd_matrix_sqrt)
trace_vec = vmap(jnp.trace)

@jit
def wasserstein_to_normals(mu, cov, other_mus, other_covs):
    mean_dist = jnp.sum((other_mus - mu) ** 2, axis=1)
    cov_sqrt = spd_matrix_sqrt(cov)
    weird_term = trace_vec(spd_matrix_sqrt_vec(
        jnp.matmul(cov_sqrt, jnp.matmul(other_covs, cov_sqrt))))
    return g(jnp.nan_to_num(mean_dist + (trace_vec(other_covs) + jnp.trace(cov) - 2 * weird_term)))

@jit
def sum_dist_to_others(mu, cov, mask, other_mus, other_covs):   
    all_dists = jnp.log(wasserstein_to_normals(mu, cov, other_mus, other_covs))
    return jnp.sum(all_dists * mask)


@jit
def TargetFullCondEmptyCluster(mu,cov,mask,mus,covs,bijector):   
    """
    The full conditional from which we sample using Metropolis Hastings, written in a JAX-differentiable way,in
    the case where the cluster is empty
    """
    
    cov = jnp.matmul(bijector.forward(cov),jnp.transpose(bijector.forward(cov)))
    covs = jnp.matmul(bijector.forward(covs),jnp.transpose(bijector.forward(covs),axes = [0,2,1]))
 
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    #Normal Wishart Term
    normal_wishart = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    
    #Wasserstein Term
    wass_dist = sum_dist_to_others(mu, cov, mask, mus, covs)
    return normal_wishart + wass_dist

@jit
def TargetFullCond(mu,cov,mask,h,cluster_allocs,data,mus,covs,bijector):   
    """
    The full conditional from which we sample using Metropolis Hastings, written in a JAX-differentiable way
    """
    
    cov = jnp.matmul(bijector.forward(cov),jnp.transpose(bijector.forward(cov)))
    covs = jnp.matmul(bijector.forward(covs),jnp.transpose(bijector.forward(covs),axes = [0,2,1]))
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    #Normal Wishart Term
    normal_wishart = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)

    #Data Term
    normal_data = jnp.sum(jnp.where(cluster_allocs == h,jtfd.MultivariateNormalFullCovariance(mu, cov).log_prob(data),0))
    
    #Wasserstein Term
    wass_dist = sum_dist_to_others(mu, cov, mask, mus, covs)
    
    return normal_data + wass_dist + normal_wishart


@jit
def sample_from_MALA(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,data,cluster_allocs,h,mus,covs,bijector,key):
    """
    Sample new mean and covariance matrix through the bijection using MALA proposal
    """
    key , subk1 , subk2 = random.split(key,3)
    
    #Compute gradients of log wrt mu and cov
    mask = jnp.ones(mus.shape[0])
    mask.at[h].set(0.0)
    mask = jnp.array(mask)
    
    cov_old_vec = bijector.inverse(jnp.linalg.cholesky(cov_old))
    covs_vec = bijector.inverse(jnp.linalg.cholesky(covs))
     
    grad_log_mu,grad_log_cov = grad(TargetFullCond,argnums=[0,1])(mu_old,cov_old_vec,mask,h,cluster_allocs,data,mus,covs_vec,bijector)
    grad_out.append(grad_log_cov)

    #Compute mu proposal
    mu_mean = mu_old + tau*grad_log_mu
    mu = jtfd.MultivariateNormalFullCovariance(mu_mean, cov_prop_mu).sample(seed = subk1)
    
    #Compute cov proposal
    cov_mean_vec = cov_old_vec + tau*grad_log_cov
    
    vec_sampl = jtfd.MultivariateNormalFullCovariance(cov_mean_vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    


    return mu,cov,log_jac,key



@jit
def sample_from_MALA_empty(mu_old,cov_prop_mu,cov_old,cov_prop_cov,tau,mus,covs,h,bijector,key):
    """
    Sample new mean and covariance matrix through the bijection using MALA proposal, in the case where cluster 
    is empty
    """
    key , subk1 , subk2 = random.split(key,3)
    
    #Compute gradients of log wrt mu and cov
    mask = jnp.ones(mus.shape[0])
    mask.at[h].set(0.0)
    mask = jnp.array(mask)
    
    cov_old_vec = bijector.inverse(jnp.linalg.cholesky(cov_old))
    covs_vec = bijector.inverse(jnp.linalg.cholesky(covs))
 
    
    grad_log_mu,grad_log_cov = grad(TargetFullCondEmptyCluster,argnums=[0,1])(mu_old,cov_old_vec,mask,mus,covs_vec,bijector)

    #Compute mu proposal
    mu_mean = mu_old + tau*grad_log_mu
    mu = jtfd.MultivariateNormalFullCovariance(mu_mean, cov_prop_mu).sample(seed = subk1)
    
    #Compute cov proposal
    cov_mean_vec = cov_old_vec + tau*grad_log_cov
    
    vec_sampl = jtfd.MultivariateNormalFullCovariance(cov_mean_vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    


    
    return mu,cov,log_jac,key



@jit
def compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    cluster_allocs_expanded = jnp.expand_dims(cluster_allocs,axis = 1)
    nan_vec = jnp.repeat(jnp.array([[jnp.nan,jnp.nan]]),len(cluster_allocs),axis=0)
    clusdata = jnp.where(jnp.concatenate((cluster_allocs_expanded,cluster_allocs_expanded),axis = 1) == h,data,nan_vec)
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5.0
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    # NW distribution terms
    num_0 = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu, cov).log_prob(clusdata))
    den_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu_old, cov_old).log_prob(clusdata))
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term



@jit
def compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0 - 3)
    
    # NW distribution terms
    num = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))
    
    return num  - den + sum_ + jac_term


@jit
def evaluate_NW_log(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = jnp.linalg.inv(phi_n)
    chol = jnp.linalg.cholesky(W) 
    inv_cov = jnp.linalg.inv(x_cov)

    f1 = jtfd.WishartTriL(df=nu_n.astype(float), scale_tril=chol).log_prob(inv_cov)
    #f1 = jtfd.WishartTriL(df=float(nu_n), scale_tril=chol).log_prob(inv_cov)
    f2 = jtfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

@jit
def compute_Wasserstein(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = jnp.linalg.norm(mu_1 - mu_2, ord = 2)
    
    #Compute square root of cov_2
    s = jnp.sqrt(jnp.linalg.det(cov_2))
    t = jnp.sqrt(jnp.trace(cov_2) + 2*s)
    sqrt_C2 = 1/t * (cov_2 + s*jnp.eye(2))
    
    C1_sqrt_C2 = jnp.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = jnp.matmul(sqrt_C2,C1_sqrt_C2)
    
    #Compute square root of sqrt_C2_C1_sqrt_C2
    s = jnp.sqrt(jnp.linalg.det(sqrt_C2_C1_sqrt_C2))
    t = jnp.sqrt(jnp.trace(sqrt_C2_C1_sqrt_C2) + 2*s)
    mat_sqrt = 1/t * (sqrt_C2_C1_sqrt_C2 + s*jnp.eye(2))
    
    trace = jnp.trace(cov_1 + cov_2 - 2 * mat_sqrt)

    # Function g
    return g(norm+trace) 

@jit
def update_weights(cluster_allocs, weights, k, alpha,key):

    key, subk = random.split(key)
    n_clus = len(weights)
    n_by_clus = jnp.array([jnp.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = jnp.ones(n_clus) * alpha + n_by_clus
    return jtfd.Dirichlet(post_params.astype(float)).sample(seed = subk),key
    #return jtfd.Dirichlet(post_params).sample(seed = subk),key

@jit
def update_cluster_allocs(data, weights, mus, covs,key):
    #print(weights)
    key, subk = random.split(key)
    logprobs = jtfd.MultivariateNormalFullCovariance(mus, covs).log_prob(data[:, jnp.newaxis])
    logprobs += jnp.log(weights)
    probs =  jnp.exp(logprobs)/(jnp.sum(jnp.exp(logprobs), axis=1))[:,None]
    return jtfd.Categorical(probs=probs, validate_args=True).sample(seed = subk),key

# %%
def run_one_gibbs(data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,tau,key):
    """
    Run one gibbs sampler iteration
    Takes in input values of the previous iteration and sample the new values from sample_uniq_vals_fullcond, update_weights and update_cluster_allocs
    Returns:   
    
    -cluster_allocs: for every data point, the cluster assigned
    -uniq_vals: array of parameters of the distributions. Matrix has d rows of the type:[mu[0], var[0,0], var[0,1]]
    -weights: array with the weights of the clusters 
     """
    key, subk = random.split(key)
    n_clus = len(weights)
    for h in range(n_clus):

        #Extract data assigned to cluster h and sample 
        clusdata = data[cluster_allocs == h]
        if(len(clusdata) != 0):
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,tau,key)
        else:
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,tau,key)


    weights,key = update_weights(cluster_allocs ,weights, k, alpha,key)

    cluster_allocs,key = update_cluster_allocs(data, weights, mus,covs,key)

    return cluster_allocs, mus,covs, weights, acc_rate,key

def run_mcmc(data, k, key , niter=1000, nburn=300, thin=5 ): 
    """
    Runs entire MCMC
    Takes in input data, number of clusters, number of iterations, burn-in and thin
    Returns the parameters recorded after burn-in phase
    """

    b = time.time() # only to measure time
    
    #Bijector setup
    jtfb = jtfp.bijectors
    bij = jtfb.Chain([
            jtfb.TransformDiagonal(jtfb.Softplus()),
            jtfb.FillTriangular()])

    #Starting Values
    cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
    weights = jnp.ones(k)/k
    alpha = 0.1
    lam = 0.1
    mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.eye(2) ).sample(k,seed = key))
    covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(2)) ).sample(k,seed = key))
    
    #Proposal Covariances
    tau = 0.0001
    cov_prop_cov = jnp.sqrt(2*tau)*jnp.eye(3) #covariance matrix for the covariance sampling
    cov_prop_mu =  jnp.sqrt(2*tau)*jnp.eye(2)   #covariance matrix for the mean sampling
#     cov_prop_cov = np.power(tau,1/4)*jnp.eye(3) #covariance matrix for the covariance sampling
#     cov_prop_mu =  np.power(tau,1/4)*jnp.eye(2)   #covariance matrix for the mean sampling
   
    
    #Output values
    allocs_out = []
    mus_out = []
    covs_out = []
    weights_out = []
    acc_rates = []
    
    #Useful value
    data_mean = np.mean(data, axis = 0)
    
    #Iterations
    for i in range(niter):
        cluster_allocs, mus,covs, weights, acc_rate,key = run_one_gibbs(
            data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,tau,key)
        acc_rates.append(acc_rate)
        
        if i > nburn and i % thin == 0:
            allocs_out.append(cluster_allocs)
            mus_out.append(mus.copy())
            covs_out.append(covs.copy())
            weights_out.append(weights)
            
        if i % 10 == 0 and i > 11:
            a = time.time()
            print("\rIter {0} / {1}".format(i+1, niter) + " Remaining minutes: " + str(round((a-b)*(niter-i)/(60*10) ,1)) , flush=False, end=" ")
            b = time.time()
            print("Acceptance rate: " + str(np.mean(acc_rates[-10:])))
            
    return allocs_out, mus_out,covs_out, weights_out,acc_rates

# %%
#RUNNING THE MCMC
grad_out = []
covs_out_ = []
mus_out_ = []
h_out = []
start = time.time()
allocs_out, mus_out,covs_out, weights_out,accept_rate_out = run_mcmc(data, k,rng_key , niter = 6000,nburn = 4000,thin = 5)
end = time.time()
print("Total time: " + str(end-start))
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:3556: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# Iter 21 / 6000 Remaining minutes: 12.8 Acceptance rate: 0.46187228
# Iter 31 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.30549473
# Iter 41 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.05410341
# Iter 51 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.3547938
# Iter 61 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.22640848
# Iter 71 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.26250654
# Iter 81 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.25221318
# Iter 91 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.14366049
# Iter 101 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.2549133
# Iter 111 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.34727973
# Iter 121 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.4848276
# Iter 131 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.51181734
# Iter 141 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.45576948
# Iter 151 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.6002493
# Iter 161 / 6000 Remaining minutes: 1.2 Acceptance rate: 0.5696182
# Iter 171 / 6000 Remaining minutes: 1.2 Acceptance rate: 0.5216459
# Iter 181 / 6000 Remaining minutes: 1.2 Acceptance rate: 0.3455841
# Iter 191 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.22941515
# Iter 201 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.057477165
# Iter 211 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.15023237
# Iter 221 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.4492813
# Iter 231 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.36084065
# Iter 241 / 6000 Remaining minutes: 1.3 Acceptance rate: 0.18530867
# Iter 251 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.15105423
# Iter 261 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.24891105
# Iter 271 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.1940043
# Iter 281 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.33647135
# Iter 291 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.35921967
# Iter 301 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.23523144
# Iter 311 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.39023182
# Iter 321 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.48740205
# Iter 331 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.5104829
# Iter 341 / 6000 Remaining minutes: 1.4 Acceptance rate: 0.24501339
# Iter 351 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.48952103
# Iter 361 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.5411116
# Iter 371 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.30516693
# Iter 381 / 6000 Remaining minutes: 1.6 Acceptance rate: 0.75636446
# Iter 391 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.54956853
# Iter 401 / 6000 Remaining minutes: 1.7 Acceptance rate: 0.29269928
# Iter 411 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.22043319
# Iter 421 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.25497705
# Iter 431 / 6000 Remaining minutes: 1.2 Acceptance rate: 0.31156301
# Iter 441 / 6000 Remaining minutes: 1.2 Acceptance rate: 0.24793467
# Iter 451 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.26718038
# Iter 461 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.4236389
# Iter 471 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.41654286
# Iter 481 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.26738954
# Iter 491 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.5562697
# Iter 501 / 6000 Remaining minutes: 1.5 Acceptance rate: 0.7934648
# Iter 511 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.9626959
# Iter 521 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.8564126
# Iter 531 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.9502619
# Iter 541 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.9922155
# Iter 551 / 6000 Remaining minutes: 0.9 Acceptance rate: 1.0
# Iter 561 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.9650377
# Iter 571 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.96893346
# Iter 581 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.9699589
# Iter 591 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.894117
# Iter 601 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.936
# Iter 611 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.97203
# Iter 621 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.8725977
# Iter 631 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.93616563
# Iter 641 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.9537681
# Iter 651 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.78994316
# Iter 661 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.77483624
# Iter 671 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.88830185
# Iter 681 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.84685296
# Iter 691 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.7394372
# Iter 701 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.8861743
# Iter 711 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.9068502
# Iter 721 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.92642355
# Iter 731 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.8883363
# Iter 741 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.821241
# Iter 751 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.9806382
# Iter 761 / 6000 Remaining minutes: 0.9 Acceptance rate: 0.9013443
# Iter 771 / 6000 Remaining minutes: 1.1 Acceptance rate: 0.9928316
# Iter 781 / 6000 Remaining minutes: 0.8 Acceptance rate: 0.96596736
# Iter 791 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.94890994
# Iter 801 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.9044358
# Iter 811 / 6000 Remaining minutes: 1.0 Acceptance rate: 0.9711254
# Iter 821 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9812447
# Iter 831 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.97283685
# Iter 841 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.9640476
# Iter 851 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.99789333
# Iter 861 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.97293484
# Iter 871 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.9717523
# Iter 881 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.93229675
# Iter 891 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.9191291
# Iter 901 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.96074533
# Iter 911 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9720253
# Iter 921 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.96074426
# Iter 931 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.98646545
# Iter 941 / 6000 Remaining minutes: 0.7 Acceptance rate: 1.0
# Iter 951 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9838856
# Iter 961 / 6000 Remaining minutes: 0.7 Acceptance rate: 1.0
# Iter 971 / 6000 Remaining minutes: 0.6 Acceptance rate: 1.0
# Iter 981 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.99750865
# Iter 991 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.97925377
# Iter 1001 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.99356097
# Iter 1011 / 6000 Remaining minutes: 0.6 Acceptance rate: 1.0
# Iter 1021 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.9950722
# Iter 1031 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.98723125
# Iter 1041 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.95555294
# Iter 1051 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.9730995
# Iter 1061 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.96788657
# Iter 1071 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.96055794
# Iter 1081 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.9470428
# Iter 1091 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.8975092
# Iter 1101 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.84622383
# Iter 1111 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9168726
# Iter 1121 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.89715594
# Iter 1131 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9911852
# Iter 1141 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.8893898
# Iter 1151 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.92129153
# Iter 1161 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9592022
# Iter 1171 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9143984
# Iter 1181 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.950414
# Iter 1191 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.86894065
# Iter 1201 / 6000 Remaining minutes: 0.7 Acceptance rate: 0.8825795
# Iter 1211 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.94984436
# Iter 1221 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.71284103
# Iter 1231 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.86170644
# Iter 1241 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.80123395
# Iter 1251 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.7972924
# Iter 1261 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.69956803
# Iter 1271 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.93969953
# Iter 1281 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.89539033
# Iter 1291 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9497917
# Iter 1301 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.8807661
# Iter 1311 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.8009532
# Iter 1321 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9035708
# Iter 1331 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.8256632
# Iter 1341 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.89383495
# Iter 1351 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.98942393
# Iter 1361 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.85915214
# Iter 1371 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.92808646
# Iter 1381 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.98345864
# Iter 1391 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.98428315
# Iter 1401 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.990263
# Iter 1411 / 6000 Remaining minutes: 0.6 Acceptance rate: 1.0
# Iter 1421 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9900503
# Iter 1431 / 6000 Remaining minutes: 0.6 Acceptance rate: 1.0
# Iter 1441 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.980132
# Iter 1451 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9870087
# Iter 1461 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9580981
# Iter 1471 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9828947
# Iter 1481 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.93255216
# Iter 1491 / 6000 Remaining minutes: 0.6 Acceptance rate: 1.0
# Iter 1501 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.98298675
# Iter 1511 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9728559
# Iter 1521 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.96754694
# Iter 1531 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9632471
# Iter 1541 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9950029
# Iter 1551 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9963678
# Iter 1561 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.97568
# Iter 1571 / 6000 Remaining minutes: 0.6 Acceptance rate: 1.0
# Iter 1581 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.94356525
# Iter 1591 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.93456984
# Iter 1601 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.99899626
# Iter 1611 / 6000 Remaining minutes: 0.5 Acceptance rate: 1.0
# Iter 1621 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.99717426
# Iter 1631 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9601576
# Iter 1641 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.96038973
# Iter 1651 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.97823083
# Iter 1661 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9664917
# Iter 1671 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.99271125
# Iter 1681 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.98066026
# Iter 1691 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9404422
# Iter 1701 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.98190403
# Iter 1711 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.933809
# Iter 1721 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.92323273
# Iter 1731 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9554162
# Iter 1741 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9125643
# Iter 1751 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9721335
# Iter 1761 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9193908
# Iter 1771 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9661026
# Iter 1781 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9743317
# Iter 1791 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.93574774
# Iter 1801 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.99696845
# Iter 1811 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.88107187
# Iter 1821 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.98873186
# Iter 1831 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.90934193
# Iter 1841 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9026519
# Iter 1851 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.91606903
# Iter 1861 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9022115
# Iter 1871 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.85474205
# Iter 1881 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.85986626
# Iter 1891 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9369451
# Iter 1901 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9079488
# Iter 1911 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.96761686
# Iter 1921 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.9073979
# Iter 1931 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.97323847
# Iter 1941 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9174746
# Iter 1951 / 6000 Remaining minutes: 0.6 Acceptance rate: 0.81915617
# Iter 1961 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9296244
# Iter 1971 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.93643236
# Iter 1981 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.8439523
# Iter 1991 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9552348
# Iter 2001 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.919248
# Iter 2011 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.947406
# Iter 2021 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.92896
# Iter 2031 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9708044
# Iter 2041 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.90170604
# Iter 2051 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9019953
# Iter 2061 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.92670155
# Iter 2071 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9224852
# Iter 2081 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9255397
# Iter 2091 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.91965973
# Iter 2101 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9377594
# Iter 2111 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.8775837
# Iter 2121 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.90671885
# Iter 2131 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9602426
# Iter 2141 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9274004
# Iter 2151 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9946477
# Iter 2161 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9575615
# Iter 2171 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9681549
# Iter 2181 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.96811885
# Iter 2191 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.8925508
# Iter 2201 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.95238286
# Iter 2211 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.95696294
# Iter 2221 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9214284
# Iter 2231 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9897405
# Iter 2241 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9798533
# Iter 2251 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9794286
# Iter 2261 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9988968
# Iter 2271 / 6000 Remaining minutes: 0.5 Acceptance rate: 1.0
# Iter 2281 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.99403733
# Iter 2291 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.980416
# Iter 2301 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.96246034
# Iter 2311 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9650917
# Iter 2321 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9295784
# Iter 2331 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9551668
# Iter 2341 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9921994
# Iter 2351 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9218383
# Iter 2361 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9765521
# Iter 2371 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9161333
# Iter 2381 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9525282
# Iter 2391 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9694257
# Iter 2401 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.95906365
# Iter 2411 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.95780325
# Iter 2421 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9760891
# Iter 2431 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9989478
# Iter 2441 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.99831617
# Iter 2451 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9158112
# Iter 2461 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9903132
# Iter 2471 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.97594184
# Iter 2481 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9969163
# Iter 2491 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9334709
# Iter 2501 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.98951435
# Iter 2511 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.87119615
# Iter 2521 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9068073
# Iter 2531 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.97759056
# Iter 2541 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.88976085
# Iter 2551 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.99041224
# Iter 2561 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.83825415
# Iter 2571 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.97248936
# Iter 2581 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9610034
# Iter 2591 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.92355263
# Iter 2601 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.89561063
# Iter 2611 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.92562485
# Iter 2621 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.70578563
# Iter 2631 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.93453014
# Iter 2641 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.73665845
# Iter 2651 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.8757137
# Iter 2661 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9073488
# Iter 2671 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.86434555
# Iter 2681 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.89330304
# Iter 2691 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9298981
# Iter 2701 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.9196122
# Iter 2711 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.8992907
# Iter 2721 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9505879
# Iter 2731 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9654134
# Iter 2741 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.98465997
# Iter 2751 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9490038
# Iter 2761 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.94631654
# Iter 2771 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9188763
# Iter 2781 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9773585
# Iter 2791 / 6000 Remaining minutes: 0.5 Acceptance rate: 0.99688834
# Iter 2801 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.99197066
# Iter 2811 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.958156
# Iter 2821 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.91933215
# Iter 2831 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.7662321
# Iter 2841 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9018116
# Iter 2851 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.95129013
# Iter 2861 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9038285
# Iter 2871 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.7949299
# Iter 2881 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.8335894
# Iter 2891 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.74887925
# Iter 2901 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.879475
# Iter 2911 / 6000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 2921 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.8058901
# Iter 2931 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9042717
# Iter 2941 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9513294
# Iter 2951 / 6000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 2961 / 6000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 2971 / 6000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 2981 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.98381984
# Iter 2991 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9196512
# Iter 3001 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.980069
# Iter 3011 / 6000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 3021 / 6000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 3031 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9170248
# Iter 3041 / 6000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 3051 / 6000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 3061 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9947295
# Iter 3071 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9537703
# Iter 3081 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.8934291
# Iter 3091 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.96595156
# Iter 3101 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.88339174
# Iter 3111 / 6000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 3121 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9941495
# Iter 3131 / 6000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 3141 / 6000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 3151 / 6000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 3161 / 6000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 3171 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.99474907
# Iter 3181 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.977883
# Iter 3191 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.95618886
# Iter 3201 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9715416
# Iter 3211 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9570648
# Iter 3221 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.9795389
# Iter 3231 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9287516
# Iter 3241 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.92248166
# Iter 3251 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.94692814
# Iter 3261 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9634638
# Iter 3271 / 6000 Remaining minutes: 0.4 Acceptance rate: 0.99570084
# Iter 3281 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9611529
# Iter 3291 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.89770967
# Iter 3301 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.89934653
# Iter 3311 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.97976005
# Iter 3321 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9675945
# Iter 3331 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.93040675
# Iter 3341 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.95686436
# Iter 3351 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9385681
# Iter 3361 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.959126
# Iter 3371 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.95471156
# Iter 3381 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9492547
# Iter 3391 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9620679
# Iter 3401 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9421252
# Iter 3411 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.94994986
# Iter 3421 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.94688874
# Iter 3431 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.91999924
# Iter 3441 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.94466317
# Iter 3451 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.92339945
# Iter 3461 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9505671
# Iter 3471 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.879248
# Iter 3481 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9835447
# Iter 3491 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9451834
# Iter 3501 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9509188
# Iter 3511 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9589995
# Iter 3521 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.99369824
# Iter 3531 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.91294414
# Iter 3541 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9923805
# Iter 3551 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 3561 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.95412713
# Iter 3571 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 3581 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9938691
# Iter 3591 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 3601 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 3611 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9682728
# Iter 3621 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.97343177
# Iter 3631 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9524743
# Iter 3641 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9501516
# Iter 3651 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9545058
# Iter 3661 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9591564
# Iter 3671 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 3681 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.97465324
# Iter 3691 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.992777
# Iter 3701 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 3711 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9910165
# Iter 3721 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9992975
# Iter 3731 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 3741 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9951844
# Iter 3751 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 3761 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9449825
# Iter 3771 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9758093
# Iter 3781 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.99314404
# Iter 3791 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9892228
# Iter 3801 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.8820616
# Iter 3811 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.8762239
# Iter 3821 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.92998874
# Iter 3831 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.98275834
# Iter 3841 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9977152
# Iter 3851 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.93497384
# Iter 3861 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.94013584
# Iter 3871 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9821637
# Iter 3881 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.97356856
# Iter 3891 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 3901 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.97331315
# Iter 3911 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.97720015
# Iter 3921 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9967281
# Iter 3931 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9968395
# Iter 3941 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 3951 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9985305
# Iter 3961 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 3971 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 3981 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 3991 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 4001 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 4011 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.98643416
# Iter 4021 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.98508024
# Iter 4031 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.92143166
# Iter 4041 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.90283376
# Iter 4051 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.9741049
# Iter 4061 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.990633
# Iter 4071 / 6000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 4081 / 6000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 4091 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.99765503
# Iter 4101 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9833868
# Iter 4111 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9880873
# Iter 4121 / 6000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 4131 / 6000 Remaining minutes: 0.3 Acceptance rate: 0.96777135
# Iter 4141 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.98820055
# Iter 4151 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9110821
# Iter 4161 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.91322154
# Iter 4171 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.83877003
# Iter 4181 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.84566116
# Iter 4191 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.95062554
# Iter 4201 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9822489
# Iter 4211 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.93063766
# Iter 4221 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9408661
# Iter 4231 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.977754
# Iter 4241 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.87211704
# Iter 4251 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.91133326
# Iter 4261 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.8725808
# Iter 4271 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.8693935
# Iter 4281 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9604662
# Iter 4291 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.8182608
# Iter 4301 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.895201
# Iter 4311 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.940468
# Iter 4321 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.93750095
# Iter 4331 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.89198494
# Iter 4341 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.8766762
# Iter 4351 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9845519
# Iter 4361 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.86078453
# Iter 4371 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.98600924
# Iter 4381 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9734212
# Iter 4391 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.90073377
# Iter 4401 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.91569936
# Iter 4411 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9492364
# Iter 4421 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.912897
# Iter 4431 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9716269
# Iter 4441 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9459306
# Iter 4451 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.98968804
# Iter 4461 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9572275
# Iter 4471 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9966459
# Iter 4481 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9823801
# Iter 4491 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.99401027
# Iter 4501 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9711772
# Iter 4511 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.95947343
# Iter 4521 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.96496534
# Iter 4531 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9966997
# Iter 4541 / 6000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 4551 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9761265
# Iter 4561 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.8720129
# Iter 4571 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.98866713
# Iter 4581 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9679713
# Iter 4591 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9780909
# Iter 4601 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.97921526
# Iter 4611 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9475676
# Iter 4621 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.994271
# Iter 4631 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.97022855
# Iter 4641 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9868655
# Iter 4651 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9874439
# Iter 4661 / 6000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 4671 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9210771
# Iter 4681 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9728819
# Iter 4691 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9968494
# Iter 4701 / 6000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 4711 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.99480027
# Iter 4721 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9497169
# Iter 4731 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.94963026
# Iter 4741 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.92550486
# Iter 4751 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9362894
# Iter 4761 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.963076
# Iter 4771 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.88017654
# Iter 4781 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.93739367
# Iter 4791 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.9793633
# Iter 4801 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9283274
# Iter 4811 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.9546348
# Iter 4821 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.96713746
# Iter 4831 / 6000 Remaining minutes: 0.2 Acceptance rate: 0.9318924
# Iter 4841 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.9876668
# Iter 4851 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.8776393
# Iter 4861 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.887677
# Iter 4871 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.7892267
# Iter 4881 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.8565877
# Iter 4891 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.99465466
# Iter 4901 / 6000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 4911 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.9610451
# Iter 4921 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.90030956
# Iter 4931 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.91777647
# Iter 4941 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.93817365
# Iter 4951 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.7159997
# Iter 4961 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.69510573
# Iter 4971 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.5952542
# Iter 4981 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.84121764
# Iter 4991 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.8018721
# Iter 5001 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.8750677
# Iter 5011 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.7183123
# Iter 5021 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.7744654
# Iter 5031 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.87211496
# Iter 5041 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.80526656
# Iter 5051 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.805689
# Iter 5061 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.60652775
# Iter 5071 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.25570816
# Iter 5081 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.48391318
# Iter 5091 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.67831206
# Iter 5101 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.71159023
# Iter 5111 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.7818244
# Iter 5121 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.57021964
# Iter 5131 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.5870995
# Iter 5141 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.7551372
# Iter 5151 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.6856501
# Iter 5161 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.78986967
# Iter 5171 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.81056273
# Iter 5181 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.8262019
# Iter 5191 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.82348603
# Iter 5201 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.63335115
# Iter 5211 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.684167
# Iter 5221 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.8743372
# Iter 5231 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.7915646
# Iter 5241 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.89217603
# Iter 5251 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.86558867
# Iter 5261 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.835498
# Iter 5271 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.7649349
# Iter 5281 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.68244493
# Iter 5291 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.7487545
# Iter 5301 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.7687942
# Iter 5311 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.72130764
# Iter 5321 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.87999773
# Iter 5331 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.8226547
# Iter 5341 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.934847
# Iter 5351 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.98332083
# Iter 5361 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.8740592
# Iter 5371 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.94500655
# Iter 5381 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.947279
# Iter 5391 / 6000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 5401 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.84341204
# Iter 5411 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.81567705
# Iter 5421 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.83439016
# Iter 5431 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.9574302
# Iter 5441 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.7430752
# Iter 5451 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.5722059
# Iter 5461 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.64625347
# Iter 5471 / 6000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 5481 / 6000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 5491 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.96196985
# Iter 5501 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.9589254
# Iter 5511 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.92805815
# Iter 5521 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.93405324
# Iter 5531 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.92866963
# Iter 5541 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.9284652
# Iter 5551 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.91165626
# Iter 5561 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.98323584
# Iter 5571 / 6000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 5581 / 6000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 5591 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.98556614
# Iter 5601 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.9478656
# Iter 5611 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.98772085
# Iter 5621 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.9598161
# Iter 5631 / 6000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 5641 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9865761
# Iter 5651 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.98010224
# Iter 5661 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.97087145
# Iter 5671 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.96886414
# Iter 5681 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.99015176
# Iter 5691 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.9542791
# Iter 5701 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.9688786
# Iter 5711 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9133997
# Iter 5721 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9208372
# Iter 5731 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9700613
# Iter 5741 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9055311
# Iter 5751 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.857734
# Iter 5761 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.92437875
# Iter 5771 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.96260417
# Iter 5781 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.93756354
# Iter 5791 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.82111037
# Iter 5801 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9441163
# Iter 5811 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9942465
# Iter 5821 / 6000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 5831 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9733273
# Iter 5841 / 6000 Remaining minutes: 0.1 Acceptance rate: 0.9861208
# Iter 5851 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.96471274
# Iter 5861 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9643904
# Iter 5871 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9830326
# Iter 5881 / 6000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 5891 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9300249
# Iter 5901 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9643316
# Iter 5911 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.96355504
# Iter 5921 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9526787
# Iter 5931 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.952915
# Iter 5941 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9253995
# Iter 5951 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.94705087
# Iter 5961 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.8106408
# Iter 5971 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.73498213
# Iter 5981 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.8845388
# Iter 5991 / 6000 Remaining minutes: 0.0 Acceptance rate: 0.9639694
# Total time: 50.17662692070007

# %%
yy = []
for i in range(len(allocs_out)):
    yy.append(len(np.unique(allocs_out[i])))

xx,cc = np.unique(yy,return_counts=True)
print(xx,cc)
plt.bar(xx,cc)
# Out:
# [ 6  7  8  9 10 11] [214 134  47   2   1   1]
# <BarContainer object of 6 artists>

# %%
for h in range(k):
    currd = data[allocs_out[-1] == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [mu[i][0] for mu in mus_out]
    second_comp = [mu[i][1] for mu in mus_out]

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__mu_x", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_mu_y", fontsize=16)

    plt.show()

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [covs[i][0,0] for covs in covs_out]
    second_comp = [covs[i][0,1] for covs in covs_out]
    third_comp = [covs[i][1,1] for covs in covs_out]

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__cov_xx", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_cov_xy", fontsize=16)
    
    axes[2].plot(np.arange(len(third_comp)), third_comp,)
    axes[2].set_title(str(i) + "_cov_yy", fontsize=16)

    plt.show()

# %%
def get_psm(clus_alloc_chain):
    """
    Returns the posterior similarity matrix, i.e.
        out[i, j] = P(c_i == c_j | all the rest)
    for each pair of observations
    """
    #Fare confronto tra colonna i e j della matrice e poi calcolare da li
    c_chain = np.vstack(clus_alloc_chain)
    out = np.zeros((c_chain.shape[1], c_chain.shape[1]))
    for i in range(c_chain.shape[1]):
        for j in range(c_chain.shape[1]):
            out[i,j] = np.sum(c_chain[:,i] == c_chain[:,j]) / c_chain.shape[0]
            
    return out


def minbinder_sample(clus_alloc_chain, psm):
    """
    Finds the iteration for which the Binder loss is minimized
    and returns the associated clustering
    """
    losses = np.zeros(len(clus_alloc_chain))
    c_chain = np.vstack(clus_alloc_chain)
    
    # You can either cycle through the iterations, or 
    # cycle through the entries in the PSM [i, j]
    # and vectorize the same operation for each iteration!
    
    mat = np.zeros( ( c_chain.shape[0], c_chain.shape[1]**2 ) )
    k = 0
    for i in range(c_chain.shape[1]):
        for j in range(c_chain.shape[1]):
            mat[:,k] = ( (c_chain[:,i] == c_chain[:,j]).astype(int) - psm[i,j] * np.ones(c_chain.shape[0]) ) **2
            k = k+1
    
    losses = np.sum(mat, axis = 1)
    
    best_iter = np.argmin(losses)
    return clus_alloc_chain[best_iter]



def unique_vals_given_clus(unique_vals_chain, clus_alloc_chain, best_clus,n_clus):
    #Finds the unique values associated to the best clusters obtained during MCMC
    
    c_allocs = np.stack(clus_alloc_chain)
    uniq_vals = np.stack(unique_vals_chain)
    means = uniq_vals[:, :, : , 0]
    variances = uniq_vals[:, :, : , 1:3]
    out1 = []
    out2 = []
    for h in range(n_clus):
        data_idx = np.where(best_clus == h)[0]
        uniq_vals_idx = c_allocs[:, data_idx] # -> Matrix [n_iter x n_data_in_clus]
        means_by_iter = np.empty((c_allocs.shape[0], len(data_idx),2))
        vars_by_iter = np.empty((c_allocs.shape[0], len(data_idx),2,2))
        for i in range(c_allocs.shape[0]):
            means_by_iter[i, :] = means[i,uniq_vals_idx[i,:],:]
            vars_by_iter[i, :] = variances[i,uniq_vals_idx[i,:]]

        avg_mean_by_iter = np.mean(means_by_iter , axis = 1)
        avg_var_by_iter = np.mean(vars_by_iter , axis = 1)
        
        muhat = np.mean(avg_mean_by_iter,axis=0)
        sigsqhat = np.mean(avg_var_by_iter,axis=0)
        out1.append(np.array(muhat))
        out2.append(np.array(sigsqhat))
    
    #If there are no points in certain clusters, the output would be full of NANs for the cluster. This gives problems
    #I replace the NANs with some 0
    for i in range(len(out1)):
        if(np.any(np.isnan(out1[i]))):
            out1[i] = np.zeros(shape = out1[i].shape)
        if(np.any(np.isnan(out2[i]))):
            out2[i] = np.eye(N = out2[i].shape[0])
    
        
    return out1,out2


psm = get_psm(allocs_out)
best_clus = minbinder_sample(allocs_out,psm)

uniq_vals_out = []
for n in range(len(mus_out)):
    mus = mus_out[n]
    covs = covs_out[n]
    arr = np.zeros(shape=(k,2,3))
    for i in range(k):
        mu = mus[i]
        cov = covs[i]
        arr[i,:,:] = np.array( [ [mu[0],cov[0,0],cov[0,1]] , [mu[1],cov[1,0],cov[1,1]] ])
    uniq_vals_out.append(arr)
    
mu_lis,var_lis = unique_vals_given_clus(uniq_vals_out, allocs_out, best_clus,k)
weights = np.sum(best_clus == np.arange(k)[:, np.newaxis], axis=1) / len(data)

# %%
for h in range(k):
    currd = data[best_clus == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])
