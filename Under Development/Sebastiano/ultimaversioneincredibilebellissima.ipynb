# %%
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pandas as pd
import time
import scipy

#Separate import for numpy and jax.numpy to have major felxibility
import jax.numpy as jnp
import numpy as np
from jax import jit,lax,random
from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions
from tensorflow_probability.substrates import jax as jtfp
jtfd = jtfp.distributions

np.random.seed(0)

# %%
sampled_perturbed = np.load('sampled_2D_two_clusters_near.npy')
data = sampled_perturbed[0 : 1000]
#DEFINING NUMBER OF CLUSTERS AND DIMENSION OF DATA
k = 10
d = 2
#Key to store for random generation
rng_key = random.PRNGKey(0)

# %%
@jit
def g(x):
    """
    Function to modulate the Wasserstein Distance
    """
  
    
    f=(5/(1+jnp.exp(-0.6*(x-5))))-0.237

    return f

@jit
def sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    
    
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,key = sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
    
    
@jit
def sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,subk1 = sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
    

@jit
def sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov, bijector,key):
    """
    Sample new mean and covariance matrix through the bijection
    """
    key , subk1 , subk2 = random.split(key,3)

    mix = 0.1
    bimix_gauss = jtfd.MixtureSameFamily(
        
                     mixture_distribution=jtfd.Categorical(probs=[mix, 1-mix]),
                     components_distribution=jtfd.MultivariateNormalDiag(loc=[mu_old,mu_old],scale_diag=[[3,3],[0.1,0.1]])
                   )  

    mu = bimix_gauss.sample(seed = subk1)
    
    chol = jnp.linalg.cholesky(cov_old)
    vec = bijector.inverse(chol)
    vec_sampl = jtfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    
    return mu,cov,log_jac,key

@jit
def compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    cluster_allocs_expanded = jnp.expand_dims(cluster_allocs,axis = 1)
    nan_vec = jnp.repeat(jnp.array([[jnp.nan,jnp.nan]]),len(cluster_allocs),axis=0)
    clusdata = jnp.where(jnp.concatenate((cluster_allocs_expanded,cluster_allocs_expanded),axis = 1) == h,data,nan_vec)
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0-3)
    
    # NW distribution terms
    num_0 = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu, cov).log_prob(clusdata))
    den_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu_old, cov_old).log_prob(clusdata))
    
     # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term

@jit
def compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0-3)
    
    # NW distribution terms
    num = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))
    
    return num  - den + sum_ + jac_term
  
@jit
def evaluate_NW_log(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = jnp.linalg.inv(phi_n)
    chol = jnp.linalg.cholesky(W) 
    inv_cov = jnp.linalg.inv(x_cov)

    f1 = jtfd.WishartTriL(df=nu_n.astype(float), scale_tril=chol).log_prob(inv_cov)
    f2 = jtfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

@jit
def compute_Wasserstein(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = jnp.linalg.norm(mu_1 - mu_2, ord = 2)
    
    #Compute square root of cov_2
    s = jnp.sqrt(jnp.linalg.det(cov_2))
    t = jnp.sqrt(jnp.trace(cov_2) + 2*s)
    sqrt_C2 = 1/t * (cov_2 + s*jnp.eye(2))
    
    C1_sqrt_C2 = jnp.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = jnp.matmul(sqrt_C2,C1_sqrt_C2)
    
    #Compute square root of sqrt_C2_C1_sqrt_C2
    s = jnp.sqrt(jnp.linalg.det(sqrt_C2_C1_sqrt_C2))
    t = jnp.sqrt(jnp.trace(sqrt_C2_C1_sqrt_C2) + 2*s)
    mat_sqrt = 1/t * (sqrt_C2_C1_sqrt_C2 + s*jnp.eye(2))
    
    trace = jnp.trace(cov_1 + cov_2 - 2 * mat_sqrt)

    # Function g
    return g(norm+trace)

@jit
def update_weights(cluster_allocs, weights, k, alpha,key):

    key, subk = random.split(key)
    n_clus = len(weights)
    n_by_clus = jnp.array([jnp.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = jnp.ones(n_clus) * alpha + n_by_clus
    return jtfd.Dirichlet(post_params.astype(float)).sample(seed = subk),key

@jit
def update_cluster_allocs(data, weights, mus, covs,key):
    #print(weights)
    key, subk = random.split(key)
    logprobs = jtfd.MultivariateNormalFullCovariance(mus, covs).log_prob(data[:, jnp.newaxis])
    logprobs += jnp.log(weights)
    probs =  jnp.exp(logprobs)/(jnp.sum(jnp.exp(logprobs), axis=1))[:,None]
    return jtfd.Categorical(probs=probs, validate_args=True).sample(seed = subk),key

# %%
def run_one_gibbs(data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Run one gibbs sampler iteration
    Takes in input values of the previous iteration and sample the new values from sample_uniq_vals_fullcond, update_weights and update_cluster_allocs
    Returns:   
    
    -cluster_allocs: for every data point, the cluster assigned
    -uniq_vals: array of parameters of the distributions. Matrix has d rows of the type:[mu[0], var[0,0], var[0,1]]
    -weights: array with the weights of the clusters 
     """
    key, subk = random.split(key)
    n_clus = len(weights)
    for h in range(n_clus):
        
        #Extract data assigned to cluster h and sample 
        clusdata = data[cluster_allocs == h]
        if(len(clusdata) != 0):
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
        else:
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)


    weights,key = update_weights(cluster_allocs ,weights, k, alpha,key)

    cluster_allocs,key = update_cluster_allocs(data, weights, mus,covs,key)

    return cluster_allocs, mus,covs, weights, acc_rate,key

def run_mcmc(data, k, key , niter=1000, nburn=300, thin=5 ): 
    """
    Runs entire MCMC
    Takes in input data, number of clusters, number of iterations, burn-in and thin
    Returns the parameters recorded after burn-in phase
    """

    b = time.time() # only to measure time
    
    #Bijector setup
    jtfb = jtfp.bijectors
    bij = jtfb.Chain([
            jtfb.TransformDiagonal(jtfb.Softplus()),
            jtfb.FillTriangular()])

    #Starting Values
    cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
    weights = jnp.ones(k)/k
    alpha = 0.1
    lam = 0.1
    mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.linalg.inv(np.diag(np.ones(d))/lam) ).sample(k,seed = key))
    covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(2)) ).sample(k,seed = key))
    
    #Proposal Covariances
    cov_prop_cov = 0.02 * jnp.eye(3) #covariance matrix for the covariance sampling
    cov_prop_mu = jnp.eye(2)   #covariance matrix for the mean sampling
    
    #Output values
    allocs_out = []
    mus_out = []
    covs_out = []
    weights_out = []
    acc_rates = []
    
    #Useful value
    data_mean = np.mean(data, axis = 0)
    
    #Iterations
    for i in range(niter):
        cluster_allocs, mus,covs, weights, acc_rate,key = run_one_gibbs(
            data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,key)
        acc_rates.append(acc_rate)
        
        if i > nburn and i % thin == 0:
            allocs_out.append(cluster_allocs)
            mus_out.append(mus.copy())
            covs_out.append(covs.copy())
            weights_out.append(weights)
            
        if i % 10 == 0 and i > 11:
            a = time.time()
            print("\rIter {0} / {1}".format(i+1, niter) + " Remaining minutes: " + str(round((a-b)*(niter-i)/(60*10) ,1)) , flush=False, end=" ")
            b = time.time()
            print("Acceptance rate: " + str(np.mean(acc_rates[-10:])))
            
    return allocs_out, mus_out,covs_out, weights_out,acc_rates

# %%
#RUNNING THE MCMC
start = time.time()
allocs_out, mus_out,covs_out, weights_out,accept_rate_out = run_mcmc(data, k,rng_key , niter = 5000,nburn = 1000,thin = 1)
end = time.time()
print("Total time: " + str(end-start))
# Out:
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:6493: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:6493: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:3552: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# skip assert _assert_compare_to_zero
# skip assert _assert_near
# Iter 21 / 5000 Remaining minutes: 265.9 Acceptance rate: 0.6125949
# Iter 31 / 5000 Remaining minutes: 2.6 Acceptance rate: 0.85407114
# Iter 41 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.74440205
# Iter 51 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.6381407
# Iter 61 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.6097081
# Iter 71 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.56763995
# Iter 81 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.65956753
# Iter 91 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.61793214
# Iter 101 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.7013023
# Iter 111 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.8210638
# Iter 121 / 5000 Remaining minutes: 2.6 Acceptance rate: 0.7420294
# Iter 131 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.71757394
# Iter 141 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.7424358
# Iter 151 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.7773531
# Iter 161 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.8802285
# Iter 171 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.98636705
# Iter 181 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.9993949
# Iter 191 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.8770801
# Iter 201 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.9518547
# Iter 211 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.9925707
# Iter 221 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.92829025
# Iter 231 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.9639565
# Iter 241 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.91497564
# Iter 251 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.8628181
# Iter 261 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.9630154
# Iter 271 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.8846124
# Iter 281 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.8987915
# Iter 291 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.77542603
# Iter 301 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.8247837
# Iter 311 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.9775108
# Iter 321 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.95808727
# Iter 331 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.9678739
# Iter 341 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.9574262
# Iter 351 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.8473045
# Iter 361 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.94870174
# Iter 371 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.8762089
# Iter 381 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.9910979
# Iter 391 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.95523417
# Iter 401 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.9316943
# Iter 411 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.9270414
# Iter 421 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.8576819
# Iter 431 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.95856875
# Iter 441 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.8805302
# Iter 451 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.6863607
# Iter 461 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.80805767
# Iter 471 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.8378355
# Iter 481 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.880299
# Iter 491 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.9500741
# Iter 501 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.8753626
# Iter 511 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.8590269
# Iter 521 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.7778254
# Iter 531 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.9157647
# Iter 541 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.9995991
# Iter 551 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.76931894
# Iter 561 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.7764967
# Iter 571 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.77629364
# Iter 581 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.8984604
# Iter 591 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.87876207
# Iter 601 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.68846697
# Iter 611 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.96681166
# Iter 621 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.7771739
# Iter 631 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.90605974
# Iter 641 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.7912848
# Iter 651 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.9619306
# Iter 661 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.96551406
# Iter 671 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.6565558
# Iter 681 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.8504776
# Iter 691 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.7212406
# Iter 701 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.7495875
# Iter 711 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.95737296
# Iter 721 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.82065547
# Iter 731 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.96975565
# Iter 741 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.91053516
# Iter 751 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.7656344
# Iter 761 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.88092804
# Iter 771 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.8890044
# Iter 781 / 5000 Remaining minutes: 2.1 Acceptance rate: 1.0
# Iter 791 / 5000 Remaining minutes: 2.1 Acceptance rate: 1.0
# Iter 801 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.9
# Iter 811 / 5000 Remaining minutes: 2.1 Acceptance rate: 1.0
# Iter 821 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.9087602
# Iter 831 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.879382
# Iter 841 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.9189085
# Iter 851 / 5000 Remaining minutes: 2.1 Acceptance rate: 1.0
# Iter 861 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.88298875
# Iter 871 / 5000 Remaining minutes: 2.1 Acceptance rate: 1.0
# Iter 881 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.91390574
# Iter 891 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.8985548
# Iter 901 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.900046
# Iter 911 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.7968737
# Iter 921 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.9601532
# Iter 931 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.6588472
# Iter 941 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.9643259
# Iter 951 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.8000022
# Iter 961 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.8920735
# Iter 971 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.9491006
# Iter 981 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.9
# Iter 991 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.8549179
# Iter 1001 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.9117609
# Iter 1011 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.7919025
# Iter 1021 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.9703301
# Iter 1031 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.9776246
# Iter 1041 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.46196145
# Iter 1051 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.4352705
# Iter 1061 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.5945317
# Iter 1071 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.4857483
# Iter 1081 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.6440752
# Iter 1091 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.63941133
# Iter 1101 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.8669132
# Iter 1111 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.97047997
# Iter 1121 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.8861393
# Iter 1131 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.9093577
# Iter 1141 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.61238545
# Iter 1151 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.48654753
# Iter 1161 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.98082817
# Iter 1171 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.7709736
# Iter 1181 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.6472625
# Iter 1191 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.86067027
# Iter 1201 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.98194474
# Iter 1211 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.90000045
# Iter 1221 / 5000 Remaining minutes: 1.9 Acceptance rate: 1.0
# Iter 1231 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.9
# Iter 1241 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.9936426
# Iter 1251 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.9013499
# Iter 1261 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.9020852
# Iter 1271 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.70030767
# Iter 1281 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.8816191
# Iter 1291 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.81046283
# Iter 1301 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.8882206
# Iter 1311 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.7844071
# Iter 1321 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.5562569
# Iter 1331 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.76363546
# Iter 1341 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.98684275
# Iter 1351 / 5000 Remaining minutes: 1.8 Acceptance rate: 1.0
# Iter 1361 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.753661
# Iter 1371 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.83143836
# Iter 1381 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.74154097
# Iter 1391 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.7424464
# Iter 1401 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.9
# Iter 1411 / 5000 Remaining minutes: 1.8 Acceptance rate: 1.0
# Iter 1421 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.859103
# Iter 1431 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.89843684
# Iter 1441 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.88561505
# Iter 1451 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.889633
# Iter 1461 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.9969214
# Iter 1471 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.8618494
# Iter 1481 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.9
# Iter 1491 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.90008295
# Iter 1501 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.9
# Iter 1511 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.8309425
# Iter 1521 / 5000 Remaining minutes: 1.7 Acceptance rate: 1.0
# Iter 1531 / 5000 Remaining minutes: 1.7 Acceptance rate: 1.0
# Iter 1541 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.91459024
# Iter 1551 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.79390144
# Iter 1561 / 5000 Remaining minutes: 1.7 Acceptance rate: 1.0
# Iter 1571 / 5000 Remaining minutes: 1.7 Acceptance rate: 1.0
# Iter 1581 / 5000 Remaining minutes: 1.8 Acceptance rate: 1.0
# Iter 1591 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.98640764
# Iter 1601 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.9000001
# Iter 1611 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.9034748
# Iter 1621 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.98611623
# Iter 1631 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.99304974
# Iter 1641 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.9000009
# Iter 1651 / 5000 Remaining minutes: 1.7 Acceptance rate: 1.0
# Iter 1661 / 5000 Remaining minutes: 1.7 Acceptance rate: 1.0
# Iter 1671 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.90353775
# Iter 1681 / 5000 Remaining minutes: 1.6 Acceptance rate: 1.0
# Iter 1691 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.9917801
# Iter 1701 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.99612445
# Iter 1711 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.9
# Iter 1721 / 5000 Remaining minutes: 1.6 Acceptance rate: 1.0
# Iter 1731 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.9133458
# Iter 1741 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.71750915
# Iter 1751 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.8638159
# Iter 1761 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.93785155
# Iter 1771 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.8556927
# Iter 1781 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.7242458
# Iter 1791 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.7044818
# Iter 1801 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.8875669
# Iter 1811 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.7534038
# Iter 1821 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.62473565
# Iter 1831 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.50047266
# Iter 1841 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.7910162
# Iter 1851 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.8832531
# Iter 1861 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.85947144
# Iter 1871 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.8860423
# Iter 1881 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.84233284
# Iter 1891 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.9359437
# Iter 1901 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.8000743
# Iter 1911 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.8756296
# Iter 1921 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.7839475
# Iter 1931 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.9969368
# Iter 1941 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.9574994
# Iter 1951 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.98608893
# Iter 1961 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.9967489
# Iter 1971 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.78301823
# Iter 1981 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.9778153
# Iter 1991 / 5000 Remaining minutes: 1.5 Acceptance rate: 1.0
# Iter 2001 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.8736458
# Iter 2011 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.95576656
# Iter 2021 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.68474257
# Iter 2031 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.8799044
# Iter 2041 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.95025796
# Iter 2051 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.7632444
# Iter 2061 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.7500027
# Iter 2071 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.6365909
# Iter 2081 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.7346229
# Iter 2091 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.7618219
# Iter 2101 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.817927
# Iter 2111 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.8579213
# Iter 2121 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.99867076
# Iter 2131 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.89532936
# Iter 2141 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.97413653
# Iter 2151 / 5000 Remaining minutes: 1.4 Acceptance rate: 1.0
# Iter 2161 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.94059455
# Iter 2171 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.9941839
# Iter 2181 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.85814893
# Iter 2191 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.8130552
# Iter 2201 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.8218315
# Iter 2211 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.8479535
# Iter 2221 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.6754018
# Iter 2231 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.7951609
# Iter 2241 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.7436858
# Iter 2251 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.8983528
# Iter 2261 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.8886663
# Iter 2271 / 5000 Remaining minutes: 1.4 Acceptance rate: 1.0
# Iter 2281 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.8352035
# Iter 2291 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.9
# Iter 2301 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.7832822
# Iter 2311 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.8925117
# Iter 2321 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.835162
# Iter 2331 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.97653997
# Iter 2341 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.97659457
# Iter 2351 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.9070538
# Iter 2361 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.741216
# Iter 2371 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.8946843
# Iter 2381 / 5000 Remaining minutes: 1.4 Acceptance rate: 1.0
# Iter 2391 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.8044813
# Iter 2401 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.99613315
# Iter 2411 / 5000 Remaining minutes: 1.3 Acceptance rate: 1.0
# Iter 2421 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.8998786
# Iter 2431 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.88708335
# Iter 2441 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.89998436
# Iter 2451 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.85161626
# Iter 2461 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.5964579
# Iter 2471 / 5000 Remaining minutes: 2.9 Acceptance rate: 0.85857296
# Iter 2481 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.9640255
# Iter 2491 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.86160374
# Iter 2501 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.82335377
# Iter 2511 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.9913246
# Iter 2521 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.84051025
# Iter 2531 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.86209667
# Iter 2541 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.76525015
# Iter 2551 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.77478564
# Iter 2561 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.9867956
# Iter 2571 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.7081655
# Iter 2581 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.8619359
# Iter 2591 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.7949
# Iter 2601 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.8723701
# Iter 2611 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.76085204
# Iter 2621 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.8698572
# Iter 2631 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.8800789
# Iter 2641 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.8650544
# Iter 2651 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.5801536
# Iter 2661 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.91414326
# Iter 2671 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.9584651
# Iter 2681 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.86967736
# Iter 2691 / 5000 Remaining minutes: 1.2 Acceptance rate: 1.0
# Iter 2701 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.79461336
# Iter 2711 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.82873833
# Iter 2721 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.7567839
# Iter 2731 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.92391455
# Iter 2741 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.8181955
# Iter 2751 / 5000 Remaining minutes: 1.1 Acceptance rate: 1.0
# Iter 2761 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.83618295
# Iter 2771 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.7356533
# Iter 2781 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.9910596
# Iter 2791 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.9471752
# Iter 2801 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.9005598
# Iter 2811 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.89333916
# Iter 2821 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.9448856
# Iter 2831 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.8773676
# Iter 2841 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.7802818
# Iter 2851 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.7818578
# Iter 2861 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.84307843
# Iter 2871 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.8156683
# Iter 2881 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.95845234
# Iter 2891 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.8651102
# Iter 2901 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.7118612
# Iter 2911 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.8975547
# Iter 2921 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.9022083
# Iter 2931 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.92040074
# Iter 2941 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.9954135
# Iter 2951 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.9811686
# Iter 2961 / 5000 Remaining minutes: 1.0 Acceptance rate: 1.0
# Iter 2971 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.97895396
# Iter 2981 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.9152974
# Iter 2991 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.76051384
# Iter 3001 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.7916214
# Iter 3011 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.86243165
# Iter 3021 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.96209115
# Iter 3031 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.8845709
# Iter 3041 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.971988
# Iter 3051 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.6317634
# Iter 3061 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.9442867
# Iter 3071 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.7924948
# Iter 3081 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.98055106
# Iter 3091 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.9928009
# Iter 3101 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.9054705
# Iter 3111 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.9782089
# Iter 3121 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.8776115
# Iter 3131 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.8988203
# Iter 3141 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.9801877
# Iter 3151 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.9895592
# Iter 3161 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.7702469
# Iter 3171 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.9328663
# Iter 3181 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.9595677
# Iter 3191 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.764496
# Iter 3201 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.970986
# Iter 3211 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.8755363
# Iter 3221 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.9834713
# Iter 3231 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.9670172
# Iter 3241 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.83612823
# Iter 3251 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.8892304
# Iter 3261 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.889712
# Iter 3271 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.7291425
# Iter 3281 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.79087937
# Iter 3291 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.90016186
# Iter 3301 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.89646417
# Iter 3311 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.8012713
# Iter 3321 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.9318924
# Iter 3331 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.7985185
# Iter 3341 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.9997736
# Iter 3351 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.90208024
# Iter 3361 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.93817866
# Iter 3371 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.99357975
# Iter 3381 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.87631786
# Iter 3391 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.53266823
# Iter 3401 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.9000002
# Iter 3411 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.74970806
# Iter 3421 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.78783584
# Iter 3431 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.9036757
# Iter 3441 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.90018576
# Iter 3451 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.9754537
# Iter 3461 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.61955875
# Iter 3471 / 5000 Remaining minutes: 0.8 Acceptance rate: 1.0
# Iter 3481 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.74450386
# Iter 3491 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.9820328
# Iter 3501 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.880984
# Iter 3511 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.9246956
# Iter 3521 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.97336197
# Iter 3531 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.9854146
# Iter 3541 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.9000346
# Iter 3551 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.99268186
# Iter 3561 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.9190326
# Iter 3571 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.8592676
# Iter 3581 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.8916653
# Iter 3591 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.7853245
# Iter 3601 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.8221878
# Iter 3611 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.86346674
# Iter 3621 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.7256087
# Iter 3631 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.9957446
# Iter 3641 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.82083607
# Iter 3651 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.95074236
# Iter 3661 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.8641946
# Iter 3671 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.88594484
# Iter 3681 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.9592048
# Iter 3691 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.8978449
# Iter 3701 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.8074816
# Iter 3711 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.8000803
# Iter 3721 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.7802378
# Iter 3731 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.9977994
# Iter 3741 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.86704874
# Iter 3751 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.8980669
# Iter 3761 / 5000 Remaining minutes: 0.6 Acceptance rate: 1.0
# Iter 3771 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.8864263
# Iter 3781 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.85502404
# Iter 3791 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.7686731
# Iter 3801 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.8999928
# Iter 3811 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.83545077
# Iter 3821 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.8297165
# Iter 3831 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.9537317
# Iter 3841 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.76780355
# Iter 3851 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.81003875
# Iter 3861 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.95672643
# Iter 3871 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.9
# Iter 3881 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.86580354
# Iter 3891 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.9957789
# Iter 3901 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.98766536
# Iter 3911 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.7281197
# Iter 3921 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.7045776
# Iter 3931 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.9437332
# Iter 3941 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.7844055
# Iter 3951 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.9442779
# Iter 3961 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.6328569
# Iter 3971 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.9247122
# Iter 3981 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.8903826
# Iter 3991 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.7258434
# Iter 4001 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.9063282
# Iter 4011 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.88169634
# Iter 4021 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.7066401
# Iter 4031 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.59799695
# Iter 4041 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.900671
# Iter 4051 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.71474224
# Iter 4061 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.5705118
# Iter 4071 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.62335765
# Iter 4081 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.6743938
# Iter 4091 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.8455429
# Iter 4101 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.59118783
# Iter 4111 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.8886386
# Iter 4121 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.96661055
# Iter 4131 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.959661
# Iter 4141 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.83412457
# Iter 4151 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.83825856
# Iter 4161 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.98068696
# Iter 4171 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.7995964
# Iter 4181 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.7284954
# Iter 4191 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.59584904
# Iter 4201 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.71044236
# Iter 4211 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.6381777
# Iter 4221 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.532663
# Iter 4231 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.7909586
# Iter 4241 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.7030069
# Iter 4251 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.6316358
# Iter 4261 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.7508394
# Iter 4271 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.64817965
# Iter 4281 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.8695072
# Iter 4291 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8395325
# Iter 4301 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.93872434
# Iter 4311 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9789913
# Iter 4321 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.85198563
# Iter 4331 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.91679585
# Iter 4341 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7373116
# Iter 4351 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.67904395
# Iter 4361 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9915026
# Iter 4371 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.99051285
# Iter 4381 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9671686
# Iter 4391 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7760178
# Iter 4401 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.62637275
# Iter 4411 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8243939
# Iter 4421 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.6850408
# Iter 4431 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.85046864
# Iter 4441 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.906782
# Iter 4451 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.69359744
# Iter 4461 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7663914
# Iter 4471 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8996112
# Iter 4481 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7431758
# Iter 4491 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7866086
# Iter 4501 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.90354717
# Iter 4511 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.99742067
# Iter 4521 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.92927325
# Iter 4531 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9814333
# Iter 4541 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.99645644
# Iter 4551 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8611001
# Iter 4561 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9583648
# Iter 4571 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9867895
# Iter 4581 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8698664
# Iter 4591 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.987202
# Iter 4601 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8568371
# Iter 4611 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8844234
# Iter 4621 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9767271
# Iter 4631 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.97418404
# Iter 4641 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.88088894
# Iter 4651 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.97534925
# Iter 4661 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7883816
# Iter 4671 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.80859697
# Iter 4681 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.84921265
# Iter 4691 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7109321
# Iter 4701 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9014484
# Iter 4711 / 5000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 4721 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.91104716
# Iter 4731 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.88422966
# Iter 4741 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9846981
# Iter 4751 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7635447
# Iter 4761 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7534502
# Iter 4771 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.71747994
# Iter 4781 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.89010143
# Iter 4791 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.80605936
# Iter 4801 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8428011
# Iter 4811 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6779792
# Iter 4821 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.36107266
# Iter 4831 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.51870525
# Iter 4841 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.65182394
# Iter 4851 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6706554
# Iter 4861 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7480572
# Iter 4871 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9532951
# Iter 4881 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.94194144
# Iter 4891 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7899095
# Iter 4901 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7708584
# Iter 4911 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9211993
# Iter 4921 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8747778
# Iter 4931 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7795229
# Iter 4941 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9600254
# Iter 4951 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.81108475
# Iter 4961 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.66412544
# Iter 4971 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7624456
# Iter 4981 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.74702305
# Iter 4991 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.4301648
# Total time: 182.88944673538208

# %%
import rpy2
import rpy2.robjects.packages as rpackages
from rpy2.robjects import numpy2ri
numpy2ri.activate()

utils = rpackages.importr('utils')
utils.chooseCRANmirror(ind=1)
utils.install_packages('GreedyEPL')
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/GreedyEPL_1.2.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 11717 bytes (11 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 11 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The downloaded source packages are in
# 	‘/tmp/RtmpCqtPBz/downloaded_packages’
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x7ff852baf190> [RTYPES.NILSXP]

# %%
c_chain = np.vstack(allocs_out)
c_chain=c_chain+1 # con cluster 0 altrimenti da errore perchè fa un -1 dentro l'algoritmo non so perchè

GreedyEPL = rpackages.importr('GreedyEPL')
best_clust_obj=GreedyEPL.MinimiseEPL(c_chain,pars = list("B"))
best_clust=best_clust_obj[2]-1

# %%
#View the number of points inside each cluster at the best iteration
print(pd.Series(best_clust).value_counts())
x, y = np.unique(best_clust, return_counts=True)
plt.bar(x, y)
# Out:
# 1.0    571
# 0.0    429
# dtype: int64
# <BarContainer object of 2 artists>

# %%
#scatterplot of clusters from last recorded iteration
for h in range(k):
    currd = data[best_clust == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [mu[i][0] for mu in mus_out]
    second_comp = [mu[i][1] for mu in mus_out]

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__mu_x", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_mu_y", fontsize=16)

    plt.show()

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [covs[i][0,0] for covs in covs_out]
    second_comp = [covs[i][0,1] for covs in covs_out]
    third_comp = [covs[i][1,1] for covs in covs_out]

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__cov_xx", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_cov_xy", fontsize=16)
    
    axes[2].plot(np.arange(len(third_comp)), second_comp,)
    axes[2].set_title(str(i) + "_cov_yy", fontsize=16)

    plt.show()

# %%
for i in range(k):
    weights = [w[i] for w in weights_out]
    plt.plot(np.arange(len(weights)) , weights)

# %% [markdown]
# # Speed Comparison

# %%
#Slow functions

def sample_uniq_vals_fullcond_Wasserstein_NW_log_slow(clusdata, mus,covs, h,bij,cov_prop_mu,cov_prop_cov):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov = sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log_slow(clusdata,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = np.minimum(0, beta)
    accept_rate = np.exp(beta)
    
    draw = tfd.Uniform().sample()
    
    # Select the new or old values 
    if(np.log(draw) >= beta):
        return mu_old,cov_old,accept_rate

    else:
        return mu,cov,accept_rate
    
def sample_uniq_vals_prior_Wasserstein_NW_log_slow(mus,covs, h,bij,cov_prop_mu,cov_prop_cov):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov = sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log_slow(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = np.minimum(0, beta)
    accept_rate = np.exp(beta)
    
    draw = tfd.Uniform().sample()
    
    # Select the new or old values 
    if(np.log(draw) >= beta):
        return np.array(mu_old),np.array(cov_old),accept_rate

    else:
        return np.array(mu),np.array(cov),accept_rate
    

def sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov, bijector):
    """
    Sample new mean and covariance matrix through the bijection
    """
    mu = tfd.MultivariateNormalFullCovariance(mu_old, cov_prop_mu).sample()
    
    chol = np.linalg.cholesky(cov_old)
    vec = bijector.inverse(chol)
    vec_sampl = tfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample()
    cov_sampl = bijector.forward(vec_sampl)
    cov = np.matmul(cov_sampl , np.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    
    return mu,cov,log_jac

def compute_beta_NW_log_slow(clusdata,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    
    mu_0 = np.zeros(2)
    cov_0 = 10*np.eye(2)
    nu_0 = 15
    phi_0 = (nu_0 - 3)*np.eye(2)
    
    # NW distribution terms
    num_0 = evaluate_NW_log_slow(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log_slow(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = np.sum(tfd.MultivariateNormalFullCovariance(mu, cov).log_prob(clusdata))
    den_1 = np.sum(tfd.MultivariateNormalFullCovariance(mu_old, cov_old).log_prob(clusdata))
    
    # Wasserstein Distance terms
    sum_ = 0
    for j in range(k):
        if(j != h):
            mu_j = mus[j]
            cov_j = covs[j]
            sum_ = sum_ + np.log(compute_Wasserstein_slow(mu , cov , mu_j , cov_j)) - np.log(compute_Wasserstein_slow(mu_old , cov_old , mu_j, cov_j))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term

def compute_beta_NW_prior_log_slow(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = np.zeros(2)
    cov_0 = 10*np.eye(2)
    nu_0 = 15
    phi_0 = (nu_0 - 3)*np.eye(2)
    
    # NW distribution terms
    num = evaluate_NW_log_slow(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log_slow(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    sum_ = 0
    for j in range(k):
        if(j != h):
            mu_j = mus[j]
            cov_j = covs[j]
            sum_ = sum_ + np.log(compute_Wasserstein_slow(mu , cov , mu_j , cov_j)) - np.log(compute_Wasserstein_slow(mu_old , cov_old , mu_j, cov_j))

    return num  - den + sum_ + jac_term
  
def evaluate_NW_log_slow(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = np.linalg.inv(phi_n)
    chol = np.linalg.cholesky(W) 
    inv_cov = np.linalg.inv(x_cov)

    f1 = tfd.WishartTriL(df=nu_n, scale_tril=chol).log_prob(inv_cov)
    f2 = tfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

def compute_Wasserstein_slow(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = np.linalg.norm(mu_1 - mu_2, ord = 2)
    sqrt_C2 = scipy.linalg.sqrtm(cov_2)
    C1_sqrt_C2 = np.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = np.matmul(sqrt_C2,C1_sqrt_C2)
    trace = np.trace(cov_1 + cov_2 - 2 * scipy.linalg.sqrtm(sqrt_C2_C1_sqrt_C2))

    # Function g
    return g(norm+trace)

def update_weights_slow(cluster_allocs, n_clus, k, alpha):

    n_by_clus = np.array([np.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = np.ones(k) * alpha + n_by_clus
    return tfd.Dirichlet(post_params.astype(float)).sample()

def update_cluster_allocs_slow(data, weights, mus, covs):
    #print(weights)
    logprobs = tfd.MultivariateNormalFullCovariance(mus, covs).log_prob(data[:, np.newaxis])
    logprobs += np.log(weights)
    probs =  np.exp(logprobs)/(np.sum(np.exp(logprobs), axis=1))[:,None]
    return tfd.Categorical(probs=probs, validate_args=True).sample()

# %%
#Data to use for comparison
key = rng_key
jtfb = jtfp.bijectors
bij = jtfb.Chain([
        jtfb.TransformDiagonal(jtfb.Softplus()),
        jtfb.FillTriangular()])

#Starting Values
cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
weights = jnp.ones(k)/k
alpha = 0.1
lam = 0.1
mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.eye(d) ).sample(k,seed = key))
covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(d)) ).sample(k,seed = key))

#Proposal Covariances
cov_prop_cov = 0.02 * jnp.eye(3) #covariance matrix for the covariance sampling
cov_prop_mu = 0.1 * jnp.eye(2)
h = 3
clusdata = data[cluster_allocs == h]


# %timeit sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
# %timeit sample_uniq_vals_fullcond_Wasserstein_NW_log_slow(clusdata, mus,covs, h,bij,cov_prop_mu,cov_prop_cov)
# %timeit compute_Wasserstein(mus[0], covs[0], mus[3], covs[3])
# %timeit compute_Wasserstein_slow(mus[0], covs[0], mus[3], covs[3])
# %timeit sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
# %timeit sample_uniq_vals_prior_Wasserstein_NW_log_slow(mus,covs, h,bij,cov_prop_mu,cov_prop_cov)
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:3556: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# 258 µs ± 651 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 144 ms ± 7.21 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# The slowest run took 9.06 times longer than the fastest. This could mean that an intermediate result is being cached.
# 91.8 µs ± 69.1 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 424 µs ± 80.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 231 µs ± 8.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 116 ms ± 1.96 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
