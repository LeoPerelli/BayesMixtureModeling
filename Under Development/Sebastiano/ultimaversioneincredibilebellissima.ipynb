# %%
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pandas as pd
import time
import scipy

#Separate import for numpy and jax.numpy to have major felxibility
import jax.numpy as jnp
import numpy as np
from jax import jit,lax,random
from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions
from tensorflow_probability.substrates import jax as jtfp
jtfd = jtfp.distributions

np.random.seed(0)
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
sampled_perturbed = np.load('sampled_2D_two_clusters_near.npy')
data = sampled_perturbed[0 : 1000]
#DEFINING NUMBER OF CLUSTERS AND DIMENSION OF DATA
k = 10
d = 2
#Key to store for random generation
rng_key = random.PRNGKey(0)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
@jit
def g(x):
    """
    Function to modulate the Wasserstein Distance
    """
  
    
    f=(5/(1+jnp.exp(-0.6*(x-5))))-0.237

    return f

@jit
def sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    
    
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,key = sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
    
    
@jit
def sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,subk1 = sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
    

@jit
def sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov, bijector,key):
    """
    Sample new mean and covariance matrix through the bijection
    """
    key , subk1 , subk2 = random.split(key,3)

    mix = 0.1
    bimix_gauss = jtfd.MixtureSameFamily(
        
                     mixture_distribution=jtfd.Categorical(probs=[mix, 1-mix]),
                     components_distribution=jtfd.MultivariateNormalDiag(loc=[mu_old,mu_old],scale_diag=[[3,3],[0.1,0.1]])
                   )  

    mu = bimix_gauss.sample(seed = subk1)
    
    chol = jnp.linalg.cholesky(cov_old)
    vec = bijector.inverse(chol)
    vec_sampl = jtfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    
    return mu,cov,log_jac,key

@jit
def compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    cluster_allocs_expanded = jnp.expand_dims(cluster_allocs,axis = 1)
    nan_vec = jnp.repeat(jnp.array([[jnp.nan,jnp.nan]]),len(cluster_allocs),axis=0)
    clusdata = jnp.where(jnp.concatenate((cluster_allocs_expanded,cluster_allocs_expanded),axis = 1) == h,data,nan_vec)
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0-3)
    
    # NW distribution terms
    num_0 = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu, cov).log_prob(clusdata))
    den_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu_old, cov_old).log_prob(clusdata))
    
     # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term

@jit
def compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0-3)
    
    # NW distribution terms
    num = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))
    
    return num  - den + sum_ + jac_term
  
@jit
def evaluate_NW_log(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = jnp.linalg.inv(phi_n)
    chol = jnp.linalg.cholesky(W) 
    inv_cov = jnp.linalg.inv(x_cov)

    f1 = jtfd.WishartTriL(df=nu_n.astype(float), scale_tril=chol).log_prob(inv_cov)
    f2 = jtfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

@jit
def compute_Wasserstein(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = jnp.linalg.norm(mu_1 - mu_2, ord = 2)
    
    #Compute square root of cov_2
    s = jnp.sqrt(jnp.linalg.det(cov_2))
    t = jnp.sqrt(jnp.trace(cov_2) + 2*s)
    sqrt_C2 = 1/t * (cov_2 + s*jnp.eye(2))
    
    C1_sqrt_C2 = jnp.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = jnp.matmul(sqrt_C2,C1_sqrt_C2)
    
    #Compute square root of sqrt_C2_C1_sqrt_C2
    s = jnp.sqrt(jnp.linalg.det(sqrt_C2_C1_sqrt_C2))
    t = jnp.sqrt(jnp.trace(sqrt_C2_C1_sqrt_C2) + 2*s)
    mat_sqrt = 1/t * (sqrt_C2_C1_sqrt_C2 + s*jnp.eye(2))
    
    trace = jnp.trace(cov_1 + cov_2 - 2 * mat_sqrt)

    # Function g
    return g(norm+trace)

@jit
def update_weights(cluster_allocs, weights, k, alpha,key):

    key, subk = random.split(key)
    n_clus = len(weights)
    n_by_clus = jnp.array([jnp.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = jnp.ones(n_clus) * alpha + n_by_clus
    return jtfd.Dirichlet(post_params.astype(float)).sample(seed = subk),key

@jit
def update_cluster_allocs(data, weights, mus, covs,key):
    #print(weights)
    key, subk = random.split(key)
    logprobs = jtfd.MultivariateNormalFullCovariance(mus, covs).log_prob(data[:, jnp.newaxis])
    logprobs += jnp.log(weights)
    probs =  jnp.exp(logprobs)/(jnp.sum(jnp.exp(logprobs), axis=1))[:,None]
    return jtfd.Categorical(probs=probs, validate_args=True).sample(seed = subk),key

# %%
def run_one_gibbs(data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Run one gibbs sampler iteration
    Takes in input values of the previous iteration and sample the new values from sample_uniq_vals_fullcond, update_weights and update_cluster_allocs
    Returns:   
    
    -cluster_allocs: for every data point, the cluster assigned
    -uniq_vals: array of parameters of the distributions. Matrix has d rows of the type:[mu[0], var[0,0], var[0,1]]
    -weights: array with the weights of the clusters 
     """
    key, subk = random.split(key)
    n_clus = len(weights)
    for h in range(n_clus):
        
        #Extract data assigned to cluster h and sample 
        clusdata = data[cluster_allocs == h]
        if(len(clusdata) != 0):
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
        else:
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)


    weights,key = update_weights(cluster_allocs ,weights, k, alpha,key)

    cluster_allocs,key = update_cluster_allocs(data, weights, mus,covs,key)

    return cluster_allocs, mus,covs, weights, acc_rate,key

def run_mcmc(data, k, key , niter=1000, nburn=300, thin=5 ): 
    """
    Runs entire MCMC
    Takes in input data, number of clusters, number of iterations, burn-in and thin
    Returns the parameters recorded after burn-in phase
    """

    b = time.time() # only to measure time
    
    #Bijector setup
    jtfb = jtfp.bijectors
    bij = jtfb.Chain([
            jtfb.TransformDiagonal(jtfb.Softplus()),
            jtfb.FillTriangular()])

    #Starting Values
    cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
    weights = jnp.ones(k)/k
    alpha = 0.1
    lam = 0.1
    mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.linalg.inv(np.diag(np.ones(d))/lam) ).sample(k,seed = key))
    covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(2)) ).sample(k,seed = key))
    
    #Proposal Covariances
    cov_prop_cov = 0.02 * jnp.eye(3) #covariance matrix for the covariance sampling
    cov_prop_mu = jnp.eye(2)   #covariance matrix for the mean sampling
    
    #Output values
    allocs_out = []
    mus_out = []
    covs_out = []
    weights_out = []
    acc_rates = []
    
    #Useful value
    data_mean = np.mean(data, axis = 0)
    
    #Iterations
    for i in range(niter):
        cluster_allocs, mus,covs, weights, acc_rate,key = run_one_gibbs(
            data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,key)
        acc_rates.append(acc_rate)
        
        if i > nburn and i % thin == 0:
            allocs_out.append(cluster_allocs)
            mus_out.append(mus.copy())
            covs_out.append(covs.copy())
            weights_out.append(weights)
            
        if i % 10 == 0 and i > 11:
            a = time.time()
            print("\rIter {0} / {1}".format(i+1, niter) + " Remaining minutes: " + str(round((a-b)*(niter-i)/(60*10) ,1)) , flush=False, end=" ")
            b = time.time()
            print("Acceptance rate: " + str(np.mean(acc_rates[-10:])))
            
    return allocs_out, mus_out,covs_out, weights_out,acc_rates

# %%
#RUNNING THE MCMC
start = time.time()
allocs_out, mus_out,covs_out, weights_out,accept_rate_out = run_mcmc(data, k,rng_key , niter = 5000,nburn = 1000,thin = 5)
end = time.time()
print("Total time: " + str(end-start))
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:3556: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# skip assert _assert_compare_to_zero
# skip assert _assert_near
# Iter 21 / 5000 Remaining minutes: 254.5 Acceptance rate: 0.6125957
# Iter 31 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8540718
# Iter 41 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.74440277
# Iter 51 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.63813984
# Iter 61 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.60970837
# Iter 71 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.567639
# Iter 81 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.6595684
# Iter 91 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.6179322
# Iter 101 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7013028
# Iter 111 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.82106334
# Iter 121 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.74202996
# Iter 131 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.71757305
# Iter 141 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.74243695
# Iter 151 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.7773532
# Iter 161 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.8797701
# Iter 171 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.98760146
# Iter 181 / 5000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 191 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.81120807
# Iter 201 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.87714815
# Iter 211 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.90086377
# Iter 221 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.87596875
# Iter 231 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.92029226
# Iter 241 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7508171
# Iter 251 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7639243
# Iter 261 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8641831
# Iter 271 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8949073
# Iter 281 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.75971717
# Iter 291 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.96572673
# Iter 301 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7006994
# Iter 311 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.98797005
# Iter 321 / 5000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 331 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8849611
# Iter 341 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.79001296
# Iter 351 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.96752167
# Iter 361 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.900877
# Iter 371 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.945209
# Iter 381 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9542095
# Iter 391 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.77953684
# Iter 401 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.90350646
# Iter 411 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7977082
# Iter 421 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.6825194
# Iter 431 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7784105
# Iter 441 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9478051
# Iter 451 / 5000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 461 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.85762674
# Iter 471 / 5000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 481 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.97979975
# Iter 491 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.85227144
# Iter 501 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.94852126
# Iter 511 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8626151
# Iter 521 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8198339
# Iter 531 / 5000 Remaining minutes: 0.4 Acceptance rate: 1.0
# Iter 541 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8548252
# Iter 551 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9434088
# Iter 561 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8003241
# Iter 571 / 5000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 581 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.96937764
# Iter 591 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.91647303
# Iter 601 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9210601
# Iter 611 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7874195
# Iter 621 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.98870623
# Iter 631 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9680007
# Iter 641 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8858317
# Iter 651 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8793329
# Iter 661 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9000003
# Iter 671 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.94273424
# Iter 681 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.88679874
# Iter 691 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7768386
# Iter 701 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8999957
# Iter 711 / 5000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 721 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8417207
# Iter 731 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8070232
# Iter 741 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.99306095
# Iter 751 / 5000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 761 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9005109
# Iter 771 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9151313
# Iter 781 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9642805
# Iter 791 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.80000055
# Iter 801 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.88900167
# Iter 811 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9
# Iter 821 / 5000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 831 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.99196166
# Iter 841 / 5000 Remaining minutes: 0.3 Acceptance rate: 1.0
# Iter 851 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.97534055
# Iter 861 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8988308
# Iter 871 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.86887246
# Iter 881 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9773
# Iter 891 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9873061
# Iter 901 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.98416746
# Iter 911 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7491859
# Iter 921 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8176696
# Iter 931 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8225886
# Iter 941 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7939359
# Iter 951 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8751546
# Iter 961 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8392019
# Iter 971 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.70310295
# Iter 981 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.90996933
# Iter 991 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.97852135
# Iter 1001 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7985759
# Iter 1011 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.5742222
# Iter 1021 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.96290934
# Iter 1031 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8911971
# Iter 1041 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9726011
# Iter 1051 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9604003
# Iter 1061 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.97567844
# Iter 1071 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9729311
# Iter 1081 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.86720145
# Iter 1091 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9797165
# Iter 1101 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.89765835
# Iter 1111 / 5000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1121 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.99893695
# Iter 1131 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.93588364
# Iter 1141 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.90801907
# Iter 1151 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9010798
# Iter 1161 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.9090799
# Iter 1171 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8288584
# Iter 1181 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8707162
# Iter 1191 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.94489765
# Iter 1201 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.79410285
# Iter 1211 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.88074553
# Iter 1221 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8898047
# Iter 1231 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8982313
# Iter 1241 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.81789505
# Iter 1251 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.92925644
# Iter 1261 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.80241215
# Iter 1271 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9
# Iter 1281 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8993081
# Iter 1291 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.80869514
# Iter 1301 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9415926
# Iter 1311 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8842905
# Iter 1321 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9928648
# Iter 1331 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.79776514
# Iter 1341 / 5000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1351 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.95101434
# Iter 1361 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9
# Iter 1371 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.89464027
# Iter 1381 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.98248065
# Iter 1391 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.926787
# Iter 1401 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7209938
# Iter 1411 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9667775
# Iter 1421 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8827467
# Iter 1431 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.986066
# Iter 1441 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.88184375
# Iter 1451 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8926407
# Iter 1461 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.6876966
# Iter 1471 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.94300383
# Iter 1481 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7995356
# Iter 1491 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9584567
# Iter 1501 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.971666
# Iter 1511 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9926028
# Iter 1521 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.93950635
# Iter 1531 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.71042204
# Iter 1541 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8707573
# Iter 1551 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.96848357
# Iter 1561 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9719515
# Iter 1571 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.89657325
# Iter 1581 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8068347
# Iter 1591 / 5000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1601 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.98321265
# Iter 1611 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9216388
# Iter 1621 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8419979
# Iter 1631 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.90110934
# Iter 1641 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.95433867
# Iter 1651 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9211316
# Iter 1661 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7429846
# Iter 1671 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.6993725
# Iter 1681 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.6056829
# Iter 1691 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.5474479
# Iter 1701 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.6485126
# Iter 1711 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7875417
# Iter 1721 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8436636
# Iter 1731 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7015041
# Iter 1741 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9985987
# Iter 1751 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8472306
# Iter 1761 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.675893
# Iter 1771 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.65516937
# Iter 1781 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.80151445
# Iter 1791 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.6616725
# Iter 1801 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9129475
# Iter 1811 / 5000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 1821 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9975481
# Iter 1831 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.91753733
# Iter 1841 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.95482177
# Iter 1851 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.94075596
# Iter 1861 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9021689
# Iter 1871 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9
# Iter 1881 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8222264
# Iter 1891 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8055692
# Iter 1901 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.83919257
# Iter 1911 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.86890495
# Iter 1921 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.88680995
# Iter 1931 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.68673277
# Iter 1941 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8733923
# Iter 1951 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9340661
# Iter 1961 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8543914
# Iter 1971 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7335892
# Iter 1981 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.85968935
# Iter 1991 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8632167
# Iter 2001 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.81808245
# Iter 2011 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8574111
# Iter 2021 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8714303
# Iter 2031 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.82899225
# Iter 2041 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9044709
# Iter 2051 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8504206
# Iter 2061 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.683722
# Iter 2071 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8062091
# Iter 2081 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8970833
# Iter 2091 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.95529044
# Iter 2101 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.96916616
# Iter 2111 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.70947933
# Iter 2121 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8894392
# Iter 2131 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.78101647
# Iter 2141 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8617819
# Iter 2151 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8911909
# Iter 2161 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9877709
# Iter 2171 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.6511321
# Iter 2181 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8846966
# Iter 2191 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.933169
# Iter 2201 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.76925653
# Iter 2211 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9827574
# Iter 2221 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.82749337
# Iter 2231 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.93744147
# Iter 2241 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.897941
# Iter 2251 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8650467
# Iter 2261 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7823284
# Iter 2271 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.97760427
# Iter 2281 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9816375
# Iter 2291 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8
# Iter 2301 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.89902675
# Iter 2311 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.999197
# Iter 2321 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9204157
# Iter 2331 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8659986
# Iter 2341 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.82987213
# Iter 2351 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9740246
# Iter 2361 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9428369
# Iter 2371 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.90062845
# Iter 2381 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.97110254
# Iter 2391 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8588848
# Iter 2401 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8851183
# Iter 2411 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8539936
# Iter 2421 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9701115
# Iter 2431 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9899616
# Iter 2441 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9810085
# Iter 2451 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7985488
# Iter 2461 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8400825
# Iter 2471 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.86649686
# Iter 2481 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8471573
# Iter 2491 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9606694
# Iter 2501 / 5000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 2511 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.79600376
# Iter 2521 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9307203
# Iter 2531 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.91670716
# Iter 2541 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9984783
# Iter 2551 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.96419305
# Iter 2561 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9023237
# Iter 2571 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.82608396
# Iter 2581 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.6855053
# Iter 2591 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9813158
# Iter 2601 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9107677
# Iter 2611 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9642232
# Iter 2621 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9514023
# Iter 2631 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.70135134
# Iter 2641 / 5000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 2651 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.85944045
# Iter 2661 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9000009
# Iter 2671 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8655052
# Iter 2681 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.68833375
# Iter 2691 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8288701
# Iter 2701 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8266357
# Iter 2711 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7554601
# Iter 2721 / 5000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 2731 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.90006125
# Iter 2741 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9771959
# Iter 2751 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8542732
# Iter 2761 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8675047
# Iter 2771 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9044383
# Iter 2781 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.5998142
# Iter 2791 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.78911716
# Iter 2801 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.79573786
# Iter 2811 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.84399986
# Iter 2821 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9
# Iter 2831 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.88983595
# Iter 2841 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6865932
# Iter 2851 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.81845635
# Iter 2861 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6406593
# Iter 2871 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.85813636
# Iter 2881 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9155078
# Iter 2891 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8076728
# Iter 2901 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7879853
# Iter 2911 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.956967
# Iter 2921 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.5503186
# Iter 2931 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6813837
# Iter 2941 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.60438687
# Iter 2951 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.52064574
# Iter 2961 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7105235
# Iter 2971 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7375218
# Iter 2981 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.87774485
# Iter 2991 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.88869894
# Iter 3001 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8097968
# Iter 3011 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.78914744
# Iter 3021 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7687947
# Iter 3031 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.5072182
# Iter 3041 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9483302
# Iter 3051 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9495565
# Iter 3061 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.97964174
# Iter 3071 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9651926
# Iter 3081 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.96034825
# Iter 3091 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9826158
# Iter 3101 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9926466
# Iter 3111 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9147865
# Iter 3121 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.50771487
# Iter 3131 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7112458
# Iter 3141 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.68722504
# Iter 3151 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7568151
# Iter 3161 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7304246
# Iter 3171 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7236603
# Iter 3181 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8310391
# Iter 3191 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.43005928
# Iter 3201 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.5701045
# Iter 3211 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8374737
# Iter 3221 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.69769406
# Iter 3231 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6171764
# Iter 3241 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6109285
# Iter 3251 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.62752116
# Iter 3261 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7286455
# Iter 3271 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9517568
# Iter 3281 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8690715
# Iter 3291 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.785292
# Iter 3301 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.663872
# Iter 3311 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.4208838
# Iter 3321 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.46539897
# Iter 3331 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8503281
# Iter 3341 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7633614
# Iter 3351 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.82940847
# Iter 3361 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8022107
# Iter 3371 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.55641407
# Iter 3381 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.39858177
# Iter 3391 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.5377683
# Iter 3401 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.555916
# Iter 3411 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.684425
# Iter 3421 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.74717903
# Iter 3431 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.870302
# Iter 3441 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7873495
# Iter 3451 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7516623
# Iter 3461 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8872019
# Iter 3471 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9133601
# Iter 3481 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9443129
# Iter 3491 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9950816
# Iter 3501 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.80007267
# Iter 3511 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.76005685
# Iter 3521 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7385204
# Iter 3531 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8699784
# Iter 3541 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6681342
# Iter 3551 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.85032177
# Iter 3561 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.84617233
# Iter 3571 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.88656455
# Iter 3581 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8205881
# Iter 3591 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8349746
# Iter 3601 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8774673
# Iter 3611 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.90665036
# Iter 3621 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.72412264
# Iter 3631 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.5843275
# Iter 3641 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.61446875
# Iter 3651 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7387445
# Iter 3661 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7345333
# Iter 3671 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.81952703
# Iter 3681 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7802085
# Iter 3691 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.70489395
# Iter 3701 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.5158795
# Iter 3711 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.36146036
# Iter 3721 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.43758923
# Iter 3731 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.4559341
# Iter 3741 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.2235044
# Iter 3751 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.4768588
# Iter 3761 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.52449787
# Iter 3771 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6133083
# Iter 3781 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6429653
# Iter 3791 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.5219673
# Iter 3801 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.55017155
# Iter 3811 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8213245
# Iter 3821 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.47692505
# Iter 3831 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.69489676
# Iter 3841 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7778322
# Iter 3851 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7739884
# Iter 3861 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6905526
# Iter 3871 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.69048154
# Iter 3881 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7105211
# Iter 3891 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.5429432
# Iter 3901 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.4133033
# Iter 3911 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.5767923
# Iter 3921 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6336435
# Iter 3931 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.5535256
# Iter 3941 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.4773101
# Iter 3951 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.68140584
# Iter 3961 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.95096433
# Iter 3971 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.692232
# Iter 3981 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.94538087
# Iter 3991 / 5000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 4001 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9018256
# Iter 4011 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8463646
# Iter 4021 / 5000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 4031 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8233181
# Iter 4041 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.897328
# Iter 4051 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.91369027
# Iter 4061 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.82932293
# Iter 4071 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.87390345
# Iter 4081 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8901106
# Iter 4091 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8898342
# Iter 4101 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7941048
# Iter 4111 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.89342344
# Iter 4121 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.84378844
# Iter 4131 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.70008326
# Iter 4141 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.93541926
# Iter 4151 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.61547375
# Iter 4161 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.68707275
# Iter 4171 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.6008825
# Iter 4181 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.905945
# Iter 4191 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.96599925
# Iter 4201 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.76220495
# Iter 4211 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8631398
# Iter 4221 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.56472373
# Iter 4231 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.6449381
# Iter 4241 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.82253325
# Iter 4251 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7140051
# Iter 4261 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.846677
# Iter 4271 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.5034219
# Iter 4281 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8507657
# Iter 4291 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8788756
# Iter 4301 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9154474
# Iter 4311 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7805013
# Iter 4321 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8517033
# Iter 4331 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.6618861
# Iter 4341 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7520155
# Iter 4351 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9698208
# Iter 4361 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.99167603
# Iter 4371 / 5000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 4381 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.78381413
# Iter 4391 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.6737212
# Iter 4401 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.6118176
# Iter 4411 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8316766
# Iter 4421 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8961692
# Iter 4431 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9
# Iter 4441 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.89811534
# Iter 4451 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.890621
# Iter 4461 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8276762
# Iter 4471 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9218372
# Iter 4481 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9751711
# Iter 4491 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8953972
# Iter 4501 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9
# Iter 4511 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9920351
# Iter 4521 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9898378
# Iter 4531 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.900115
# Iter 4541 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.99658805
# Iter 4551 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8931176
# Iter 4561 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8000042
# Iter 4571 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9993774
# Iter 4581 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7894773
# Iter 4591 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9
# Iter 4601 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.91065073
# Iter 4611 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7398864
# Iter 4621 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.89145565
# Iter 4631 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.81984746
# Iter 4641 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.6969476
# Iter 4651 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.99288
# Iter 4661 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7922738
# Iter 4671 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9619156
# Iter 4681 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.80724984
# Iter 4691 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.90225375
# Iter 4701 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9347409
# Iter 4711 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9442915
# Iter 4721 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.744459
# Iter 4731 / 5000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 4741 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9
# Iter 4751 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9000006
# Iter 4761 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.90000755
# Iter 4771 / 5000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 4781 / 5000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 4791 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.88695306
# Iter 4801 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8884174
# Iter 4811 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9064361
# Iter 4821 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9
# Iter 4831 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.73742616
# Iter 4841 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.88693416
# Iter 4851 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.76197004
# Iter 4861 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9944684
# Iter 4871 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9726052
# Iter 4881 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.99546355
# Iter 4891 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9998268
# Iter 4901 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.78413296
# Iter 4911 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8738902
# Iter 4921 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8401104
# Iter 4931 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8000008
# Iter 4941 / 5000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Iter 4951 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9
# Iter 4961 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9000155
# Iter 4971 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9203596
# Iter 4981 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9998894
# Iter 4991 / 5000 Remaining minutes: 0.0 Acceptance rate: 1.0
# Total time: 49.3827702999115

# %%
import rpy2
import rpy2.robjects.packages as rpackages
from rpy2.robjects import numpy2ri
numpy2ri.activate()

utils = rpackages.importr('utils')
utils.chooseCRANmirror(ind=1)
utils.install_packages('GreedyEPL')
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cloud.r-project.org/bin/macosx/contrib/4.0/GreedyEPL_1.2.tgz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 729715 bytes (712 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 712 KB
# The downloaded binary packages are in
# 	/var/folders/92/n6f3gbh54m30s9rvslvx5k0h0000gn/T//RtmpcCeIYd/downloaded_packages
# <rpy2.rinterface_lib.sexp.NULLType object at 0x7f812addd448> [RTYPES.NILSXP]

# %%
c_chain = np.vstack(allocs_out)
c_chain=c_chain+1 # con cluster 0 altrimenti da errore perchè fa un -1 dentro l'algoritmo non so perchè

GreedyEPL = rpackages.importr('GreedyEPL')
best_clust_obj=GreedyEPL.MinimiseEPL(c_chain,pars = list("B"))
best_clust=best_clust_obj[2]-1
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in p__CollapseLabelsCpp(as.numeric(decision) - 1) :
#   function 'Rcpp_precious_remove' not provided by package 'Rcpp'
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-7-2b81841a5a29> in <module>
#       3
#       4 GreedyEPL = rpackages.importr('GreedyEPL')
# ----> 5 best_clust_obj=GreedyEPL.MinimiseEPL(c_chain,pars = list("B"))
#       6 best_clust=best_clust_obj[2]-1
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     197                 kwargs[r_k] = v
#     198         return (super(SignatureTranslatedFunction, self)
# --> 199                 .__call__(*args, **kwargs))
#     200
#     201
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     123             else:
#     124                 new_kwargs[k] = conversion.py2rpy(v)
# --> 125         res = super(Function, self).__call__(*new_args, **new_kwargs)
#     126         res = conversion.rpy2py(res)
#     127         return res
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/conversion.py in _(*args, **kwargs)
#      43 def _cdata_res_to_rinterface(function):
#      44     def _(*args, **kwargs):
# ---> 45         cdata = function(*args, **kwargs)
#      46         # TODO: test cdata is of the expected CType
#      47         return _cdata_to_rinterface(cdata)
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/rinterface.py in __call__(self, *args, **kwargs)
#     678             )
#     679             if error_occured[0]:
# --> 680                 raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     681         return res
#     682
#
# RRuntimeError: Error in p__CollapseLabelsCpp(as.numeric(decision) - 1) :
#   function 'Rcpp_precious_remove' not provided by package 'Rcpp'

# %%
#View the number of points inside each cluster at the best iteration
print(pd.Series(best_clust).value_counts())
x, y = np.unique(best_clust, return_counts=True)
plt.bar(x, y)

# %%
#scatterplot of clusters from last recorded iteration
for h in range(k):
    currd = data[best_clust == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [mu[i][0] for mu in mus_out]
    second_comp = [mu[i][1] for mu in mus_out]

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__mu_x", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_mu_y", fontsize=16)

    plt.show()

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [covs[i][0,0] for covs in covs_out]
    second_comp = [covs[i][0,1] for covs in covs_out]
    third_comp = [covs[i][1,1] for covs in covs_out]

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__cov_xx", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_cov_xy", fontsize=16)
    
    axes[2].plot(np.arange(len(third_comp)), second_comp,)
    axes[2].set_title(str(i) + "_cov_yy", fontsize=16)

    plt.show()

# %%
for i in range(k):
    weights = [w[i] for w in weights_out]
    plt.plot(np.arange(len(weights)) , weights)

# %% [markdown]
# # Speed Comparison

# %%
#Slow functions

def sample_uniq_vals_fullcond_Wasserstein_NW_log_slow(clusdata, mus,covs, h,bij,cov_prop_mu,cov_prop_cov):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov = sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log_slow(clusdata,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = np.minimum(0, beta)
    accept_rate = np.exp(beta)
    
    draw = tfd.Uniform().sample()
    
    # Select the new or old values 
    if(np.log(draw) >= beta):
        return mu_old,cov_old,accept_rate

    else:
        return mu,cov,accept_rate
    
def sample_uniq_vals_prior_Wasserstein_NW_log_slow(mus,covs, h,bij,cov_prop_mu,cov_prop_cov):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov = sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log_slow(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = np.minimum(0, beta)
    accept_rate = np.exp(beta)
    
    draw = tfd.Uniform().sample()
    
    # Select the new or old values 
    if(np.log(draw) >= beta):
        return np.array(mu_old),np.array(cov_old),accept_rate

    else:
        return np.array(mu),np.array(cov),accept_rate
    

def sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov, bijector):
    """
    Sample new mean and covariance matrix through the bijection
    """
    mu = tfd.MultivariateNormalFullCovariance(mu_old, cov_prop_mu).sample()
    
    chol = np.linalg.cholesky(cov_old)
    vec = bijector.inverse(chol)
    vec_sampl = tfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample()
    cov_sampl = bijector.forward(vec_sampl)
    cov = np.matmul(cov_sampl , np.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    
    return mu,cov,log_jac

def compute_beta_NW_log_slow(clusdata,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    
    mu_0 = np.zeros(2)
    cov_0 = 10*np.eye(2)
    nu_0 = 15
    phi_0 = (nu_0 - 3)*np.eye(2)
    
    # NW distribution terms
    num_0 = evaluate_NW_log_slow(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log_slow(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = np.sum(tfd.MultivariateNormalFullCovariance(mu, cov).log_prob(clusdata))
    den_1 = np.sum(tfd.MultivariateNormalFullCovariance(mu_old, cov_old).log_prob(clusdata))
    
    # Wasserstein Distance terms
    sum_ = 0
    for j in range(k):
        if(j != h):
            mu_j = mus[j]
            cov_j = covs[j]
            sum_ = sum_ + np.log(compute_Wasserstein_slow(mu , cov , mu_j , cov_j)) - np.log(compute_Wasserstein_slow(mu_old , cov_old , mu_j, cov_j))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term

def compute_beta_NW_prior_log_slow(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = np.zeros(2)
    cov_0 = 10*np.eye(2)
    nu_0 = 15
    phi_0 = (nu_0 - 3)*np.eye(2)
    
    # NW distribution terms
    num = evaluate_NW_log_slow(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log_slow(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    sum_ = 0
    for j in range(k):
        if(j != h):
            mu_j = mus[j]
            cov_j = covs[j]
            sum_ = sum_ + np.log(compute_Wasserstein_slow(mu , cov , mu_j , cov_j)) - np.log(compute_Wasserstein_slow(mu_old , cov_old , mu_j, cov_j))

    return num  - den + sum_ + jac_term
  
def evaluate_NW_log_slow(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = np.linalg.inv(phi_n)
    chol = np.linalg.cholesky(W) 
    inv_cov = np.linalg.inv(x_cov)

    f1 = tfd.WishartTriL(df=nu_n, scale_tril=chol).log_prob(inv_cov)
    f2 = tfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

def compute_Wasserstein_slow(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = np.linalg.norm(mu_1 - mu_2, ord = 2)
    sqrt_C2 = scipy.linalg.sqrtm(cov_2)
    C1_sqrt_C2 = np.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = np.matmul(sqrt_C2,C1_sqrt_C2)
    trace = np.trace(cov_1 + cov_2 - 2 * scipy.linalg.sqrtm(sqrt_C2_C1_sqrt_C2))

    # Function g
    return g(norm+trace)

def update_weights_slow(cluster_allocs, n_clus, k, alpha):

    n_by_clus = np.array([np.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = np.ones(k) * alpha + n_by_clus
    return tfd.Dirichlet(post_params.astype(float)).sample()

def update_cluster_allocs_slow(data, weights, mus, covs):
    #print(weights)
    logprobs = tfd.MultivariateNormalFullCovariance(mus, covs).log_prob(data[:, np.newaxis])
    logprobs += np.log(weights)
    probs =  np.exp(logprobs)/(np.sum(np.exp(logprobs), axis=1))[:,None]
    return tfd.Categorical(probs=probs, validate_args=True).sample()

# %%
#Data to use for comparison
key = rng_key
jtfb = jtfp.bijectors
bij = jtfb.Chain([
        jtfb.TransformDiagonal(jtfb.Softplus()),
        jtfb.FillTriangular()])

#Starting Values
cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
weights = jnp.ones(k)/k
alpha = 0.1
lam = 0.1
mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.eye(d) ).sample(k,seed = key))
covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(d)) ).sample(k,seed = key))

#Proposal Covariances
cov_prop_cov = 0.02 * jnp.eye(3) #covariance matrix for the covariance sampling
cov_prop_mu = 0.1 * jnp.eye(2)
h = 3
clusdata = data[cluster_allocs == h]


# %timeit sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
# %timeit sample_uniq_vals_fullcond_Wasserstein_NW_log_slow(clusdata, mus,covs, h,bij,cov_prop_mu,cov_prop_cov)
# %timeit compute_Wasserstein(mus[0], covs[0], mus[3], covs[3])
# %timeit compute_Wasserstein_slow(mus[0], covs[0], mus[3], covs[3])
# %timeit sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
# %timeit sample_uniq_vals_prior_Wasserstein_NW_log_slow(mus,covs, h,bij,cov_prop_mu,cov_prop_cov)
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:3556: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# 258 µs ± 651 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 144 ms ± 7.21 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# The slowest run took 9.06 times longer than the fastest. This could mean that an intermediate result is being cached.
# 91.8 µs ± 69.1 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 424 µs ± 80.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 231 µs ± 8.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 116 ms ± 1.96 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
