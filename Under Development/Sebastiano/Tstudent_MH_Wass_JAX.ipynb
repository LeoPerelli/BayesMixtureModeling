# %%
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pandas as pd
import time
import scipy

#Separate import for numpy and jax.numpy to have major felxibility
import jax.numpy as jnp
import numpy as np
from jax import jit,lax,random
from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions
from tensorflow_probability.substrates import jax as jtfp
jtfd = jtfp.distributions

np.random.seed(0)

# %%
sampled_perturbed = np.load('sampled_2D_two_clusters_near.npy')
data = sampled_perturbed[0 : 1000]
#DEFINING NUMBER OF CLUSTERS AND DIMENSION OF DATA
k = 10
d = 2
df=3
#Key to store for random generation
rng_key = random.PRNGKey(0)

# %%
@jit
def g(x):
    """
    Function to modulate the Wasserstein Distance
    """
  
    
    f=(5/(1+jnp.exp(-0.6*(x-5))))-0.237

    return f

@jit
def sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    
    
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,key = sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
    
    
@jit
def sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,subk1 = sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
    

@jit
def sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov, bijector,key):
    """
    Sample new mean and covariance matrix through the bijection
    """
    key , subk1 , subk2 = random.split(key,3)

    mix = 0.1
    bimix_gauss = jtfd.MixtureSameFamily(
        
                     mixture_distribution=jtfd.Categorical(probs=[mix, 1-mix]),
                     components_distribution=jtfd.MultivariateNormalDiag(loc=[mu_old,mu_old],scale_diag=[[3,3],[0.1,0.1]])
                   )  

    mu = bimix_gauss.sample(seed = subk1)
    
    chol = jnp.linalg.cholesky(cov_old)
    vec = bijector.inverse(chol)
    vec_sampl = jtfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    
    return mu,cov,log_jac,key

@jit
def compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    cluster_allocs_expanded = jnp.expand_dims(cluster_allocs,axis = 1)
    nan_vec = jnp.repeat(jnp.array([[jnp.nan,jnp.nan]]),len(cluster_allocs),axis=0)
    clusdata = jnp.where(jnp.concatenate((cluster_allocs_expanded,cluster_allocs_expanded),axis = 1) == h,data,nan_vec)
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0-3)
    
    # NW distribution terms
    num_0 = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = jnp.nansum(jtfd.StudentT(df, mu, cov).log_prob(clusdata))
    den_1 = jnp.nansum(jtfd.StudentT(df, mu_old, cov_old).log_prob(clusdata))
    
     # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term

@jit
def compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0-3)
    
    # NW distribution terms
    num = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))
    
    return num  - den + sum_ + jac_term
  
@jit
def evaluate_NW_log(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = jnp.linalg.inv(phi_n)
    chol = jnp.linalg.cholesky(W) 
    inv_cov = jnp.linalg.inv(x_cov)

    f1 = jtfd.WishartTriL(df=nu_n.astype(float), scale_tril=chol).log_prob(inv_cov)
    f2 = jtfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

@jit
def compute_Wasserstein(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = jnp.linalg.norm(mu_1 - mu_2, ord = 2)
    
    #Compute square root of cov_2
    s = jnp.sqrt(jnp.linalg.det(cov_2))
    t = jnp.sqrt(jnp.trace(cov_2) + 2*s)
    sqrt_C2 = 1/t * (cov_2 + s*jnp.eye(2))
    
    C1_sqrt_C2 = jnp.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = jnp.matmul(sqrt_C2,C1_sqrt_C2)
    
    #Compute square root of sqrt_C2_C1_sqrt_C2
    s = jnp.sqrt(jnp.linalg.det(sqrt_C2_C1_sqrt_C2))
    t = jnp.sqrt(jnp.trace(sqrt_C2_C1_sqrt_C2) + 2*s)
    mat_sqrt = 1/t * (sqrt_C2_C1_sqrt_C2 + s*jnp.eye(2))
    
    trace = jnp.trace(cov_1 + cov_2 - 2 * mat_sqrt)

    # Function g
    return g(norm+trace)

@jit
def update_weights(cluster_allocs, weights, k, alpha,key):

    key, subk = random.split(key)
    n_clus = len(weights)
    n_by_clus = jnp.array([jnp.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = jnp.ones(n_clus) * alpha + n_by_clus
    return jtfd.Dirichlet(post_params.astype(float)).sample(seed = subk),key

@jit
def update_cluster_allocs(data, weights, mus, covs,key):
    #print(weights)
    key, subk = random.split(key)
    logprobs = jtfd.StudentT(df, mus, covs).log_prob(data[:, jnp.newaxis])
    logprobs += jnp.log(weights)
    probs =  jnp.exp(logprobs)/(jnp.sum(jnp.exp(logprobs), axis=1))[:,None]
    return jtfd.Categorical(probs=probs, validate_args=True).sample(seed = subk),key

# %%
def run_one_gibbs(data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Run one gibbs sampler iteration
    Takes in input values of the previous iteration and sample the new values from sample_uniq_vals_fullcond, update_weights and update_cluster_allocs
    Returns:   
    
    -cluster_allocs: for every data point, the cluster assigned
    -uniq_vals: array of parameters of the distributions. Matrix has d rows of the type:[mu[0], var[0,0], var[0,1]]
    -weights: array with the weights of the clusters 
     """
    key, subk = random.split(key)
    n_clus = len(weights)
    for h in range(n_clus):
        
        #Extract data assigned to cluster h and sample 
        clusdata = data[cluster_allocs == h]
        if(len(clusdata) != 0):
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
        else:
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)


    weights,key = update_weights(cluster_allocs ,weights, k, alpha,key)

    cluster_allocs,key = update_cluster_allocs(data, weights, mus,covs,key)

    return cluster_allocs, mus,covs, weights, acc_rate,key

def run_mcmc(data, k, key , niter=1000, nburn=300, thin=5 ): 
    """
    Runs entire MCMC
    Takes in input data, number of clusters, number of iterations, burn-in and thin
    Returns the parameters recorded after burn-in phase
    """

    b = time.time() # only to measure time
    
    #Bijector setup
    jtfb = jtfp.bijectors
    bij = jtfb.Chain([
            jtfb.TransformDiagonal(jtfb.Softplus()),
            jtfb.FillTriangular()])

    #Starting Values
    cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
    weights = jnp.ones(k)/k
    alpha = 0.1
    lam = 0.1
    mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.linalg.inv(np.diag(np.ones(d))/lam) ).sample(k,seed = key))
    covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(2)) ).sample(k,seed = key))
    
    #Proposal Covariances
    cov_prop_cov = 0.02 * jnp.eye(3) #covariance matrix for the covariance sampling
    cov_prop_mu = jnp.eye(2)   #covariance matrix for the mean sampling
    
    #Output values
    allocs_out = []
    mus_out = []
    covs_out = []
    weights_out = []
    acc_rates = []
    
    #Useful value
    data_mean = np.mean(data, axis = 0)
    
    #Iterations
    for i in range(niter):
        cluster_allocs, mus,covs, weights, acc_rate,key = run_one_gibbs(
            data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,key)
        acc_rates.append(acc_rate)
        
        if i > nburn and i % thin == 0:
            allocs_out.append(cluster_allocs)
            mus_out.append(mus.copy())
            covs_out.append(covs.copy())
            weights_out.append(weights)
            
        if i % 10 == 0 and i > 11:
            a = time.time()
            print("\rIter {0} / {1}".format(i+1, niter) + " Remaining minutes: " + str(round((a-b)*(niter-i)/(60*10) ,1)) , flush=False, end=" ")
            b = time.time()
            print("Acceptance rate: " + str(np.mean(acc_rates[-10:])))
            
    return allocs_out, mus_out,covs_out, weights_out,acc_rates

# %%
#RUNNING THE MCMC
start = time.time()
allocs_out, mus_out,covs_out, weights_out,accept_rate_out = run_mcmc(data, k,rng_key , niter = 5000,nburn = 1000,thin = 5)
end = time.time()
print("Total time: " + str(end-start))
# Out:
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:6493: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:6493: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:3552: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# skip assert _assert_compare_to_zero
# skip assert _assert_near
# Iter 21 / 5000 Remaining minutes: 253.1 Acceptance rate: 0.5317226
# Iter 31 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.6135559
# Iter 41 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.7266233
# Iter 51 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.2853246
# Iter 61 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.4100229
# Iter 71 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.13392265
# Iter 81 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.24252574
# Iter 91 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.18366131
# Iter 101 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.21425024
# Iter 111 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.20706184
# Iter 121 / 5000 Remaining minutes: 2.5 Acceptance rate: 0.16459027
# Iter 131 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.3117066
# Iter 141 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.19697846
# Iter 151 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.21476462
# Iter 161 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.2792923
# Iter 171 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.12624627
# Iter 181 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.29388326
# Iter 191 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.28286093
# Iter 201 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.29844224
# Iter 211 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.3176492
# Iter 221 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.121186875
# Iter 231 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.23760045
# Iter 241 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.28708237
# Iter 251 / 5000 Remaining minutes: 2.7 Acceptance rate: 0.1064236
# Iter 261 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.07569033
# Iter 271 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.065993786
# Iter 281 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.1095358
# Iter 291 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.26045248
# Iter 301 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.10647353
# Iter 311 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.011865616
# Iter 321 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.041217607
# Iter 331 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.029263202
# Iter 341 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.011399703
# Iter 351 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.1814684
# Iter 361 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.11650516
# Iter 371 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.12912117
# Iter 381 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.2925968
# Iter 391 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.1224008
# Iter 401 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.065059274
# Iter 411 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.090821125
# Iter 421 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.38709757
# Iter 431 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.21151856
# Iter 441 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.14464119
# Iter 451 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.23325872
# Iter 461 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.23496485
# Iter 471 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.02940182
# Iter 481 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.23614192
# Iter 491 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.015555786
# Iter 501 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.069642894
# Iter 511 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.0572971
# Iter 521 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.050786544
# Iter 531 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.1720703
# Iter 541 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.07455472
# Iter 551 / 5000 Remaining minutes: 2.4 Acceptance rate: 0.081480354
# Iter 561 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.3615315
# Iter 571 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.12927696
# Iter 581 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.036989387
# Iter 591 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.0870534
# Iter 601 / 5000 Remaining minutes: 2.3 Acceptance rate: 0.1033354
# Iter 611 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.15605791
# Iter 621 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.15315205
# Iter 631 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.22068293
# Iter 641 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.04540389
# Iter 651 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.21721677
# Iter 661 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.11215627
# Iter 671 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.10055157
# Iter 681 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.00088513584
# Iter 691 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.1368102
# Iter 701 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.21632877
# Iter 711 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.24231935
# Iter 721 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.11452234
# Iter 731 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.021054521
# Iter 741 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.119219795
# Iter 751 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.022294873
# Iter 761 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.19307275
# Iter 771 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.0928978
# Iter 781 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.16307732
# Iter 791 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.123213604
# Iter 801 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.081247695
# Iter 811 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.20385265
# Iter 821 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.025306055
# Iter 831 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.03871831
# Iter 841 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.17112495
# Iter 851 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.06447442
# Iter 861 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.022170942
# Iter 871 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.102960564
# Iter 881 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.043888263
# Iter 891 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.10331516
# Iter 901 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.024652712
# Iter 911 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.10642705
# Iter 921 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.14533648
# Iter 931 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.019191612
# Iter 941 / 5000 Remaining minutes: 2.2 Acceptance rate: 0.036342427
# Iter 951 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.3150298
# Iter 961 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.23202288
# Iter 971 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.24667144
# Iter 981 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.11838756
# Iter 991 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.07152542
# Iter 1001 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.011034494
# Iter 1011 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.18255456
# Iter 1021 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.30277887
# Iter 1031 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.3138142
# Iter 1041 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.0051111844
# Iter 1051 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.021976195
# Iter 1061 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.029039796
# Iter 1071 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.10165175
# Iter 1081 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.019626794
# Iter 1091 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.20665345
# Iter 1101 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.04375759
# Iter 1111 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.12891056
# Iter 1121 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.029666403
# Iter 1131 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.036498014
# Iter 1141 / 5000 Remaining minutes: 2.1 Acceptance rate: 0.13972673
# Iter 1151 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.26372212
# Iter 1161 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.0076488615
# Iter 1171 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.23152752
# Iter 1181 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.12127583
# Iter 1191 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.07265146
# Iter 1201 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.015726287
# Iter 1211 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.013149959
# Iter 1221 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.13330314
# Iter 1231 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.103398085
# Iter 1241 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.31575066
# Iter 1251 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.072880074
# Iter 1261 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.12731259
# Iter 1271 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.28184542
# Iter 1281 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.16038801
# Iter 1291 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.1046298
# Iter 1301 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.11125419
# Iter 1311 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.14172825
# Iter 1321 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.0051137935
# Iter 1331 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.01015902
# Iter 1341 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.11936961
# Iter 1351 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.16040628
# Iter 1361 / 5000 Remaining minutes: 2.0 Acceptance rate: 0.036732443
# Iter 1371 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.0076617664
# Iter 1381 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.04999514
# Iter 1391 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.004864857
# Iter 1401 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.009241777
# Iter 1411 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.2119424
# Iter 1421 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.14471343
# Iter 1431 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.012025992
# Iter 1441 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.14250329
# Iter 1451 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.061335552
# Iter 1461 / 5000 Remaining minutes: 1.9 Acceptance rate: 0.13326868
# Iter 1471 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.24690613
# Iter 1481 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.0030306382
# Iter 1491 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.12364533
# Iter 1501 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.0848748
# Iter 1511 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.29321796
# Iter 1521 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.42976952
# Iter 1531 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.08789202
# Iter 1541 / 5000 Remaining minutes: 2.7 Acceptance rate: 0.011069879
# Iter 1551 / 5000 Remaining minutes: 3.7 Acceptance rate: 0.045602337
# Iter 1561 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.009549811
# Iter 1571 / 5000 Remaining minutes: 4.7 Acceptance rate: 0.038045123
# Iter 1581 / 5000 Remaining minutes: 1.8 Acceptance rate: 0.16626732
# Iter 1591 / 5000 Remaining minutes: 3.3 Acceptance rate: 0.12455829
# Iter 1601 / 5000 Remaining minutes: 2.9 Acceptance rate: 0.24131945
# Iter 1611 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.06748541
# Iter 1621 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.16081265
# Iter 1631 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.3022722
# Iter 1641 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.21435097
# Iter 1651 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.14737737
# Iter 1661 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.19959648
# Iter 1671 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.14092202
# Iter 1681 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.12385093
# Iter 1691 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.3031326
# Iter 1701 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.06048601
# Iter 1711 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.19908643
# Iter 1721 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.13427089
# Iter 1731 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.02945901
# Iter 1741 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.16635661
# Iter 1751 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.10397692
# Iter 1761 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.035238795
# Iter 1771 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.14371045
# Iter 1781 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.104443416
# Iter 1791 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.12521291
# Iter 1801 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.2664186
# Iter 1811 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.055874683
# Iter 1821 / 5000 Remaining minutes: 1.7 Acceptance rate: 0.012002452
# Iter 1831 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.3118611
# Iter 1841 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.19675286
# Iter 1851 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.14136867
# Iter 1861 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.12610048
# Iter 1871 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.13450761
# Iter 1881 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.0514737
# Iter 1891 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.10678653
# Iter 1901 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.011768153
# Iter 1911 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.16233611
# Iter 1921 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.0060445247
# Iter 1931 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.28584918
# Iter 1941 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.055374462
# Iter 1951 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.002412867
# Iter 1961 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.18342237
# Iter 1971 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.047200304
# Iter 1981 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.11679983
# Iter 1991 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.138237
# Iter 2001 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.0015966188
# Iter 2011 / 5000 Remaining minutes: 2.7 Acceptance rate: 0.048560005
# Iter 2021 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.049618803
# Iter 2031 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.23526108
# Iter 2041 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.0074952594
# Iter 2051 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.20273969
# Iter 2061 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.015621389
# Iter 2071 / 5000 Remaining minutes: 1.6 Acceptance rate: 0.020377293
# Iter 2081 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.129832
# Iter 2091 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.12024572
# Iter 2101 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.11174009
# Iter 2111 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.0023596245
# Iter 2121 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.18678927
# Iter 2131 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.10417454
# Iter 2141 / 5000 Remaining minutes: 1.5 Acceptance rate: 0.14241752
# Iter 2151 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.10014305
# Iter 2161 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.102237605
# Iter 2171 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.1282948
# Iter 2181 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.100957826
# Iter 2191 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.12742913
# Iter 2201 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.19868144
# Iter 2211 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.3054304
# Iter 2221 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.074991256
# Iter 2231 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.20255885
# Iter 2241 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.05729357
# Iter 2251 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.118520215
# Iter 2261 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.14688516
# Iter 2271 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.10472429
# Iter 2281 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.08048311
# Iter 2291 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.025201663
# Iter 2301 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.10271577
# Iter 2311 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.15668705
# Iter 2321 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.0010355869
# Iter 2331 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.070198275
# Iter 2341 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.21347818
# Iter 2351 / 5000 Remaining minutes: 1.4 Acceptance rate: 0.081202075
# Iter 2361 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.05392518
# Iter 2371 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.024516078
# Iter 2381 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.00995574
# Iter 2391 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.21636423
# Iter 2401 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.20145026
# Iter 2411 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.028136725
# Iter 2421 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.061839543
# Iter 2431 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.10987276
# Iter 2441 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.1084733
# Iter 2451 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.043039523
# Iter 2461 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.10522284
# Iter 2471 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.012373278
# Iter 2481 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.121460125
# Iter 2491 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.002344875
# Iter 2501 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.017600246
# Iter 2511 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.097296596
# Iter 2521 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.017617583
# Iter 2531 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.07355131
# Iter 2541 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.030441443
# Iter 2551 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.05680449
# Iter 2561 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.05712946
# Iter 2571 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.11640984
# Iter 2581 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.09704468
# Iter 2591 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.05302137
# Iter 2601 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.10258243
# Iter 2611 / 5000 Remaining minutes: 1.3 Acceptance rate: 0.037477992
# Iter 2621 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.013081878
# Iter 2631 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.30067122
# Iter 2641 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.20127296
# Iter 2651 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.004081239
# Iter 2661 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.105978906
# Iter 2671 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.21283145
# Iter 2681 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.115063265
# Iter 2691 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.09689062
# Iter 2701 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.106804155
# Iter 2711 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.07627638
# Iter 2721 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.017609159
# Iter 2731 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.0014380692
# Iter 2741 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.03699332
# Iter 2751 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.25624922
# Iter 2761 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.13810241
# Iter 2771 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.030976843
# Iter 2781 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.1611077
# Iter 2791 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.103916906
# Iter 2801 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.016994718
# Iter 2811 / 5000 Remaining minutes: 1.2 Acceptance rate: 0.019006591
# Iter 2821 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.20381144
# Iter 2831 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.011810995
# Iter 2841 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.023783203
# Iter 2851 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.06828574
# Iter 2861 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.07539023
# Iter 2871 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.10623713
# Iter 2881 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.05138297
# Iter 2891 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.30004653
# Iter 2901 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.26515427
# Iter 2911 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.12197437
# Iter 2921 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.0024274988
# Iter 2931 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.16374072
# Iter 2941 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.10134064
# Iter 2951 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.0018938475
# Iter 2961 / 5000 Remaining minutes: 1.0 Acceptance rate: 4.2400683e-05
# Iter 2971 / 5000 Remaining minutes: 1.1 Acceptance rate: 0.15472518
# Iter 2981 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.107285
# Iter 2991 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.10349673
# Iter 3001 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.09524114
# Iter 3011 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.1437681
# Iter 3021 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.23785773
# Iter 3031 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.24316187
# Iter 3041 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.101232685
# Iter 3051 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.012131246
# Iter 3061 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.014524227
# Iter 3071 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.16851619
# Iter 3081 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.10093355
# Iter 3091 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.10044549
# Iter 3101 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.20144212
# Iter 3111 / 5000 Remaining minutes: 1.0 Acceptance rate: 0.3509193
# Iter 3121 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.027209397
# Iter 3131 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.20582065
# Iter 3141 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.17397578
# Iter 3151 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.10565909
# Iter 3161 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.16278018
# Iter 3171 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.10710527
# Iter 3181 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.11476854
# Iter 3191 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.02692404
# Iter 3201 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.025544431
# Iter 3211 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.04914433
# Iter 3221 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.19389601
# Iter 3231 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.039144494
# Iter 3241 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.3449625
# Iter 3251 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.021430768
# Iter 3261 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.0011330624
# Iter 3271 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.013035695
# Iter 3281 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.13080189
# Iter 3291 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.04978128
# Iter 3301 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.12032688
# Iter 3311 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.00049871777
# Iter 3321 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.013786947
# Iter 3331 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.00974161
# Iter 3341 / 5000 Remaining minutes: 0.9 Acceptance rate: 0.20720346
# Iter 3351 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.13818721
# Iter 3361 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.0023706346
# Iter 3371 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.0822564
# Iter 3381 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.27857968
# Iter 3391 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.021739444
# Iter 3401 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.097279124
# Iter 3411 / 5000 Remaining minutes: 0.8 Acceptance rate: 8.7916356e-05
# Iter 3421 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.22080743
# Iter 3431 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.02646793
# Iter 3441 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.07719123
# Iter 3451 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.10688368
# Iter 3461 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.009539116
# Iter 3471 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.09511502
# Iter 3481 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.07802021
# Iter 3491 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.040705156
# Iter 3501 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.20763214
# Iter 3511 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.00973109
# Iter 3521 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.20019794
# Iter 3531 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.33794796
# Iter 3541 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.062519595
# Iter 3551 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.017046683
# Iter 3561 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.21019629
# Iter 3571 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.10525552
# Iter 3581 / 5000 Remaining minutes: 0.8 Acceptance rate: 0.00038820662
# Iter 3591 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.20219581
# Iter 3601 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.0548547
# Iter 3611 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.014786119
# Iter 3621 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.29363483
# Iter 3631 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.10227525
# Iter 3641 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.004236601
# Iter 3651 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.07720669
# Iter 3661 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.08978583
# Iter 3671 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.315819
# Iter 3681 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.10811772
# Iter 3691 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.0831953
# Iter 3701 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.18819013
# Iter 3711 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.0039216364
# Iter 3721 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.009825584
# Iter 3731 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.04646648
# Iter 3741 / 5000 Remaining minutes: 0.7 Acceptance rate: 0.0019363876
# Iter 3751 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.015130957
# Iter 3761 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.1387913
# Iter 3771 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.15399158
# Iter 3781 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.01379326
# Iter 3791 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.0028825714
# Iter 3801 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.11392561
# Iter 3811 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.0038659102
# Iter 3821 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.22250447
# Iter 3831 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.0064254897
# Iter 3841 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.05050101
# Iter 3851 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.123487934
# Iter 3861 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.07190722
# Iter 3871 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.13688977
# Iter 3881 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.12339665
# Iter 3891 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.30012354
# Iter 3901 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.11293848
# Iter 3911 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.010598435
# Iter 3921 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.011621847
# Iter 3931 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.0041526663
# Iter 3941 / 5000 Remaining minutes: 0.6 Acceptance rate: 0.29277903
# Iter 3951 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.007274133
# Iter 3961 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.019362265
# Iter 3971 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.1354067
# Iter 3981 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.01102533
# Iter 3991 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.12635744
# Iter 4001 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.011606126
# Iter 4011 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.040528495
# Iter 4021 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.09369675
# Iter 4031 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.25439715
# Iter 4041 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.1539623
# Iter 4051 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.16361168
# Iter 4061 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.10888231
# Iter 4071 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.100600086
# Iter 4081 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.009996088
# Iter 4091 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.0074869962
# Iter 4101 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.0200642
# Iter 4111 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.047563247
# Iter 4121 / 5000 Remaining minutes: 0.5 Acceptance rate: 0.1567836
# Iter 4131 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.08882499
# Iter 4141 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.21481279
# Iter 4151 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.07536416
# Iter 4161 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.03231342
# Iter 4171 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.0721627
# Iter 4181 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.14903031
# Iter 4191 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.10682593
# Iter 4201 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.10201603
# Iter 4211 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.106232956
# Iter 4221 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.057582997
# Iter 4231 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.2023449
# Iter 4241 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.07260008
# Iter 4251 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.14637157
# Iter 4261 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.016912399
# Iter 4271 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.12026222
# Iter 4281 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.10307892
# Iter 4291 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.09618209
# Iter 4301 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.20482533
# Iter 4311 / 5000 Remaining minutes: 0.4 Acceptance rate: 0.30368266
# Iter 4321 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.142126
# Iter 4331 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.3290903
# Iter 4341 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.0032006702
# Iter 4351 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.06957649
# Iter 4361 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.0020742752
# Iter 4371 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.0031614571
# Iter 4381 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.17312877
# Iter 4391 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.12613206
# Iter 4401 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.04477729
# Iter 4411 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.13478914
# Iter 4421 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.21971598
# Iter 4431 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.16533992
# Iter 4441 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.008751872
# Iter 4451 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.011371011
# Iter 4461 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.090233274
# Iter 4471 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.07109196
# Iter 4481 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.0021652319
# Iter 4491 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.0031389284
# Iter 4501 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.015753154
# Iter 4511 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.18871768
# Iter 4521 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.20326369
# Iter 4531 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.12877008
# Iter 4541 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.013546325
# Iter 4551 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.22064035
# Iter 4561 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.021607924
# Iter 4571 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.10447935
# Iter 4581 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.039460126
# Iter 4591 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.04110021
# Iter 4601 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.100615345
# Iter 4611 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.18205741
# Iter 4621 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.0005559645
# Iter 4631 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.10802104
# Iter 4641 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.13512145
# Iter 4651 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.00054988585
# Iter 4661 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.009934769
# Iter 4671 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.03742539
# Iter 4681 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.04303011
# Iter 4691 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.042630367
# Iter 4701 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.08242549
# Iter 4711 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.23216632
# Iter 4721 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.12772866
# Iter 4731 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.113226816
# Iter 4741 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.1346608
# Iter 4751 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.0133204805
# Iter 4761 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.21584003
# Iter 4771 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.14331093
# Iter 4781 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.10056563
# Iter 4791 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.09096266
# Iter 4801 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.105845645
# Iter 4811 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.076078765
# Iter 4821 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.15702641
# Iter 4831 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.23491248
# Iter 4841 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.013319725
# Iter 4851 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.31445378
# Iter 4861 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.21062681
# Iter 4871 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.108893275
# Iter 4881 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.16087288
# Iter 4891 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.13602035
# Iter 4901 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.01097215
# Iter 4911 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.0045779096
# Iter 4921 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.01688059
# Iter 4931 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.10117972
# Iter 4941 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.0018180453
# Iter 4951 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.035421748
# Iter 4961 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.014187254
# Iter 4971 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.18023363
# Iter 4981 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.014575904
# Iter 4991 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.0004375106
# Total time: 184.37482285499573

# %%
import rpy2
import rpy2.robjects.packages as rpackages
from rpy2.robjects import numpy2ri
numpy2ri.activate()

utils = rpackages.importr('utils')
utils.chooseCRANmirror(ind=1)
utils.install_packages('GreedyEPL')
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: also installing the dependency ‘RcppArmadillo’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/RcppArmadillo_0.10.7.5.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 1362368 bytes (1.3 MB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 1.3 MB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/GreedyEPL_1.2.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 11717 bytes (11 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 11 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The downloaded source packages are in
# 	‘/tmp/RtmpNjCKyJ/downloaded_packages’
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x7ff4b2b7b780> [RTYPES.NILSXP]

# %%
c_chain = np.vstack(allocs_out)
c_chain=c_chain+1 # con cluster 0 altrimenti da errore perchè fa un -1 dentro l'algoritmo non so perchè

GreedyEPL = rpackages.importr('GreedyEPL')
best_clust_obj=GreedyEPL.MinimiseEPL(c_chain,pars = list("B"))
best_clust=best_clust_obj[2]-1

# %%
#View the number of points inside each cluster at the best iteration
print(pd.Series(best_clust).value_counts())
x, y = np.unique(best_clust, return_counts=True)
plt.bar(x, y)
# Out:
# 0.0    429
# 2.0    368
# 1.0    202
# 3.0      1
# dtype: int64
# <BarContainer object of 4 artists>

# %%
#scatterplot of clusters from last recorded iteration
for h in range(k):
    currd = data[best_clust == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [mu[i][0] for mu in mus_out]
    second_comp = [mu[i][1] for mu in mus_out]

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__mu_x", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_mu_y", fontsize=16)

    plt.show()

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [covs[i][0,0] for covs in covs_out]
    second_comp = [covs[i][0,1] for covs in covs_out]
    third_comp = [covs[i][1,1] for covs in covs_out]

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__cov_xx", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_cov_xy", fontsize=16)
    
    axes[2].plot(np.arange(len(third_comp)), third_comp,)
    axes[2].set_title(str(i) + "_cov_yy", fontsize=16)

    plt.show()

# %%
for i in range(k):
    weights = [w[i] for w in weights_out]
    plt.plot(np.arange(len(weights)) , weights)

# %% [markdown]
# # Speed Comparison

# %%
#Slow functions

def sample_uniq_vals_fullcond_Wasserstein_NW_log_slow(clusdata, mus,covs, h,bij,cov_prop_mu,cov_prop_cov):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov = sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log_slow(clusdata,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = np.minimum(0, beta)
    accept_rate = np.exp(beta)
    
    draw = tfd.Uniform().sample()
    
    # Select the new or old values 
    if(np.log(draw) >= beta):
        return mu_old,cov_old,accept_rate

    else:
        return mu,cov,accept_rate
    
def sample_uniq_vals_prior_Wasserstein_NW_log_slow(mus,covs, h,bij,cov_prop_mu,cov_prop_cov):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov = sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log_slow(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = np.minimum(0, beta)
    accept_rate = np.exp(beta)
    
    draw = tfd.Uniform().sample()
    
    # Select the new or old values 
    if(np.log(draw) >= beta):
        return np.array(mu_old),np.array(cov_old),accept_rate

    else:
        return np.array(mu),np.array(cov),accept_rate
    

def sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov, bijector):
    """
    Sample new mean and covariance matrix through the bijection
    """
    mu = tfd.MultivariateNormalFullCovariance(mu_old, cov_prop_mu).sample()
    
    chol = np.linalg.cholesky(cov_old)
    vec = bijector.inverse(chol)
    vec_sampl = tfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample()
    cov_sampl = bijector.forward(vec_sampl)
    cov = np.matmul(cov_sampl , np.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    
    return mu,cov,log_jac

def compute_beta_NW_log_slow(clusdata,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    
    mu_0 = np.zeros(2)
    cov_0 = 10*np.eye(2)
    nu_0 = 15
    phi_0 = (nu_0 - 3)*np.eye(2)
    
    # NW distribution terms
    num_0 = evaluate_NW_log_slow(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log_slow(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = np.sum(tfd.MultivariateNormalFullCovariance(mu, cov).log_prob(clusdata))
    den_1 = np.sum(tfd.MultivariateNormalFullCovariance(mu_old, cov_old).log_prob(clusdata))
    
    # Wasserstein Distance terms
    sum_ = 0
    for j in range(k):
        if(j != h):
            mu_j = mus[j]
            cov_j = covs[j]
            sum_ = sum_ + np.log(compute_Wasserstein_slow(mu , cov , mu_j , cov_j)) - np.log(compute_Wasserstein_slow(mu_old , cov_old , mu_j, cov_j))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term

def compute_beta_NW_prior_log_slow(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = np.zeros(2)
    cov_0 = 10*np.eye(2)
    nu_0 = 15
    phi_0 = (nu_0 - 3)*np.eye(2)
    
    # NW distribution terms
    num = evaluate_NW_log_slow(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log_slow(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    sum_ = 0
    for j in range(k):
        if(j != h):
            mu_j = mus[j]
            cov_j = covs[j]
            sum_ = sum_ + np.log(compute_Wasserstein_slow(mu , cov , mu_j , cov_j)) - np.log(compute_Wasserstein_slow(mu_old , cov_old , mu_j, cov_j))

    return num  - den + sum_ + jac_term
  
def evaluate_NW_log_slow(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = np.linalg.inv(phi_n)
    chol = np.linalg.cholesky(W) 
    inv_cov = np.linalg.inv(x_cov)

    f1 = tfd.WishartTriL(df=nu_n, scale_tril=chol).log_prob(inv_cov)
    f2 = tfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

def compute_Wasserstein_slow(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = np.linalg.norm(mu_1 - mu_2, ord = 2)
    sqrt_C2 = scipy.linalg.sqrtm(cov_2)
    C1_sqrt_C2 = np.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = np.matmul(sqrt_C2,C1_sqrt_C2)
    trace = np.trace(cov_1 + cov_2 - 2 * scipy.linalg.sqrtm(sqrt_C2_C1_sqrt_C2))

    # Function g
    return g(norm+trace)

def update_weights_slow(cluster_allocs, n_clus, k, alpha):

    n_by_clus = np.array([np.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = np.ones(k) * alpha + n_by_clus
    return tfd.Dirichlet(post_params.astype(float)).sample()

def update_cluster_allocs_slow(data, weights, mus, covs):
    #print(weights)
    logprobs = tfd.MultivariateNormalFullCovariance(mus, covs).log_prob(data[:, np.newaxis])
    logprobs += np.log(weights)
    probs =  np.exp(logprobs)/(np.sum(np.exp(logprobs), axis=1))[:,None]
    return tfd.Categorical(probs=probs, validate_args=True).sample()

# %%
#Data to use for comparison
key = rng_key
jtfb = jtfp.bijectors
bij = jtfb.Chain([
        jtfb.TransformDiagonal(jtfb.Softplus()),
        jtfb.FillTriangular()])

#Starting Values
cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
weights = jnp.ones(k)/k
alpha = 0.1
lam = 0.1
mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.eye(d) ).sample(k,seed = key))
covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(d)) ).sample(k,seed = key))

#Proposal Covariances
cov_prop_cov = 0.02 * jnp.eye(3) #covariance matrix for the covariance sampling
cov_prop_mu = 0.1 * jnp.eye(2)
h = 3
clusdata = data[cluster_allocs == h]


# %timeit sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
# %timeit sample_uniq_vals_fullcond_Wasserstein_NW_log_slow(clusdata, mus,covs, h,bij,cov_prop_mu,cov_prop_cov)
# %timeit compute_Wasserstein(mus[0], covs[0], mus[3], covs[3])
# %timeit compute_Wasserstein_slow(mus[0], covs[0], mus[3], covs[3])
# %timeit sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
# %timeit sample_uniq_vals_prior_Wasserstein_NW_log_slow(mus,covs, h,bij,cov_prop_mu,cov_prop_cov)
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:3556: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# 258 µs ± 651 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 144 ms ± 7.21 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# The slowest run took 9.06 times longer than the fastest. This could mean that an intermediate result is being cached.
# 91.8 µs ± 69.1 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 424 µs ± 80.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 231 µs ± 8.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 116 ms ± 1.96 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
