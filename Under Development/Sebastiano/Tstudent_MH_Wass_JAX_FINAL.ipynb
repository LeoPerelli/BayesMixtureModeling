# %%
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pandas as pd
import time
import scipy

#Separate import for numpy and jax.numpy to have major felxibility
import jax.numpy as jnp
import numpy as np
from jax import jit,lax,random
from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions
from tensorflow_probability.substrates import jax as jtfp
jtfd = jtfp.distributions
import jax.scipy as js

np.random.seed(0)

# %%
sampled_perturbed = np.load('test4.npy')
#sampled_perturbed=np.genfromtxt('faithful.csv', delimiter=',')
data = sampled_perturbed[0 : 1000]
#DEFINING NUMBER OF CLUSTERS AND DIMENSION OF DATA
k = 10
d = 2
df=10
df_cost=df/(df-2)
#Key to store for random generation
rng_key = random.PRNGKey(0)

# %%
plt.scatter(data[:,0],data[:,1])

# %%
from IPython.core.pylabtools import select_figure_formats
@jit
def g(x):
    """
    Function to modulate the Wasserstein Distance
    """
  
    
    f=(5/(1+jnp.exp(-0.6*(x-5))))-0.237

    return f

@jit
def sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    
    
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,key = sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
    
    
@jit
def sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,subk1 = sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
    

@jit
def sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov, bijector,key):
    """
    Sample new mean and covariance matrix through the bijection
    """
    key , subk1 , subk2 = random.split(key,3)

    mix = 0.1
    bimix_gauss = jtfd.MixtureSameFamily(
        
                     mixture_distribution=jtfd.Categorical(probs=[mix, 1-mix]),
                     components_distribution=jtfd.MultivariateNormalDiag(loc=[mu_old,mu_old],scale_diag=[[3,3],[0.1,0.1]])
                   )  

    mu = bimix_gauss.sample(seed = subk1)
    
    chol = jnp.linalg.cholesky(cov_old)
    vec = bijector.inverse(chol)
    vec_sampl = jtfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    
    return mu,cov,log_jac,key

@jit
def compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    nan_vec = jnp.repeat(jnp.array([jnp.nan]),len(cluster_allocs))
    
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0-3)
    
    # NW distribution terms
    num_0 = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    
    eval_vec=evaluate_student_T(data,mu,cov,df)
    eval_vec_old=evaluate_student_T(data,mu_old,cov_old,df)
    
    num_1 = jnp.nansum( jnp.where(cluster_allocs == h,eval_vec,nan_vec))
    den_1 = jnp.nansum( jnp.where(cluster_allocs == h,eval_vec_old,nan_vec))


    
     # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term

@jit
def compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 5
    phi_0 = jnp.eye(2)*(nu_0-3)
    
    # NW distribution terms
    num = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))
    
    return num  - den + sum_ + jac_term
  
@jit
def evaluate_NW_log(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = jnp.linalg.inv(phi_n)
    chol = jnp.linalg.cholesky(W) 
    inv_cov = jnp.linalg.inv(x_cov)

    f1 = jtfd.WishartTriL(df=nu_n.astype(float), scale_tril=chol).log_prob(inv_cov)
    f2 = jtfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

@jit
def compute_Wasserstein(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = jnp.linalg.norm(mu_1 - mu_2, ord = 2)
    
    #Compute square root of cov_2
    s = jnp.sqrt(jnp.linalg.det(cov_2))
    t = jnp.sqrt(jnp.trace(cov_2) + 2*s)
    sqrt_C2 = 1/t * (cov_2 + s*jnp.eye(2))
    
    C1_sqrt_C2 = jnp.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = jnp.matmul(sqrt_C2,C1_sqrt_C2)
    
    #Compute square root of sqrt_C2_C1_sqrt_C2
    s = jnp.sqrt(jnp.linalg.det(sqrt_C2_C1_sqrt_C2))
    t = jnp.sqrt(jnp.trace(sqrt_C2_C1_sqrt_C2) + 2*s)
    mat_sqrt = 1/t * (sqrt_C2_C1_sqrt_C2 + s*jnp.eye(2))
    
    trace = jnp.trace(cov_1 + cov_2 - 2 * mat_sqrt)

    # Function g
    return g(norm+trace)

@jit
def update_weights(cluster_allocs, weights, k, alpha,key):

    key, subk = random.split(key)
    n_clus = len(weights)
    n_by_clus = jnp.array([jnp.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = jnp.ones(n_clus) * alpha + n_by_clus
    return jtfd.Dirichlet(post_params.astype(float)).sample(seed = subk),key


#def update_cluster_allocs(data, weights, mus, covs,key):
    #print(weights)
    #key, subk = random.split(key)


    #logprobs = jtfd.MultivariateStudentTLinearOperator(df, mus.astype('float32'), tf.linalg.LinearOperatorLowerTriangular(scales)).log_prob(data[:, jnp.newaxis])
    #logprobs += jnp.log(weights)
    #probs =  jnp.exp(logprobs)/(jnp.sum(jnp.exp(logprobs), axis=1))[:,None]
    #return jtfd.Categorical(probs=probs, validate_args=True).sample(seed = subk),key

# %%
@jit
def evaluate_student_T(data,mu,cov,df):
  
  scale=cov*(df-2)/df
  inv_scale=jnp.linalg.inv(scale)
  det_scale=jnp.linalg.det(scale)
  p=2
  
  def inner_f (x):
    eval_vec=js.special.gammaln((df+p)/2)-js.special.gammaln(df/2)-0.5*jnp.log(jnp.power(df,p)*jnp.power(jnp.pi,p)*det_scale)-((df+p)/2)*jnp.log(1+(1/df)*(jnp.dot((x-mu).T ,jnp.dot(inv_scale, x-mu))))
    return eval_vec
  ris=jnp.apply_along_axis(inner_f,1,data)
  
  return ris
 
def update_cluster_allocs(data, weights, mus, covs,key):
    key, subk = random.split(key)
    logprobs=[]
    for h in range(k):
      v=evaluate_student_T(data,mus[h],covs[h],df)
      #print(v[1:5])
      v=np.expand_dims(v,axis=1)
      if (h==0):
        logprobs=v
      else:
        logprobs=np.concatenate((logprobs,v),axis=1)
    #print(logprobs[1:5],)
    logprobs += jnp.log(weights)
    probs =  jnp.exp(logprobs)/(jnp.sum(jnp.exp(logprobs), axis=1))[:,None]
    #print(probs)
    return jtfd.Categorical(probs=probs, validate_args=True).sample(seed = subk),key

# %%
def run_one_gibbs(data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Run one gibbs sampler iteration
    Takes in input values of the previous iteration and sample the new values from sample_uniq_vals_fullcond, update_weights and update_cluster_allocs
    Returns:   
    
    -cluster_allocs: for every data point, the cluster assigned
    -uniq_vals: array of parameters of the distributions. Matrix has d rows of the type:[mu[0], var[0,0], var[0,1]]
    -weights: array with the weights of the clusters 
     """
    key, subk = random.split(key)
    n_clus = len(weights)
    for h in range(n_clus):
        
        #Extract data assigned to cluster h and sample 
        clusdata = data[cluster_allocs == h]
        if(len(clusdata) != 0):
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
        else:
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)


    weights,key = update_weights(cluster_allocs ,weights, k, alpha,key)

    cluster_allocs,key = update_cluster_allocs(data, weights, mus,covs,key)

    return cluster_allocs, mus,covs, weights, acc_rate,key

def run_mcmc(data, k, key , niter=1000, nburn=300, thin=5 ): 
    """
    Runs entire MCMC
    Takes in input data, number of clusters, number of iterations, burn-in and thin
    Returns the parameters recorded after burn-in phase
    """

    b = time.time() # only to measure time
    
    #Bijector setup
    jtfb = jtfp.bijectors
    bij = jtfb.Chain([
            jtfb.TransformDiagonal(jtfb.Softplus()),
            jtfb.FillTriangular()])

    #Starting Values
    cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
    weights = jnp.ones(k)/k
    alpha = 0.1
    lam = 0.1
    mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.linalg.inv(np.diag(np.ones(d))/lam) ).sample(k,seed = key))
    covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(2)) ).sample(k,seed = key))
    
    #Proposal Covariances
    cov_prop_cov = 0.02 * jnp.eye(3) #covariance matrix for the covariance sampling
    cov_prop_mu = jnp.eye(2)   #covariance matrix for the mean sampling
    
    #Output values
    allocs_out = []
    mus_out = []
    covs_out = []
    weights_out = []
    acc_rates = []
    
    #Useful value
    data_mean = np.mean(data, axis = 0)
    
    #Iterations
    for i in range(niter):
        cluster_allocs, mus,covs, weights, acc_rate,key = run_one_gibbs(
            data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,key)
        acc_rates.append(acc_rate)
        
        if i > nburn and i % thin == 0:
            allocs_out.append(cluster_allocs)
            mus_out.append(mus.copy())
            covs_out.append(covs.copy())
            weights_out.append(weights)
            
        if i % 10 == 0 and i > 11:
            a = time.time()
            print("\rIter {0} / {1}".format(i+1, niter) + " Remaining minutes: " + str(round((a-b)*(niter-i)/(60*10) ,1)) , flush=False, end=" ")
            b = time.time()
            print("Acceptance rate: " + str(np.mean(acc_rates[-10:])))
            
    return allocs_out, mus_out,covs_out, weights_out,acc_rates

# %%
#RUNNING THE MCMC
start = time.time()
allocs_out, mus_out,covs_out, weights_out,accept_rate_out = run_mcmc(data, k,rng_key , niter = 2500,nburn = 500,thin = 5)
end = time.time()
print("Total time: " + str(end-start))
# Out:
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:6493: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:6493: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:3552: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# Iter 21 / 2500 Remaining minutes: 43.9 Acceptance rate: 0.5676478
# Iter 31 / 2500 Remaining minutes: 1.4 Acceptance rate: 0.71344364
# Iter 41 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.7999714
# Iter 51 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.99460566
# Iter 61 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.9913219
# Iter 71 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.93832415
# Iter 81 / 2500 Remaining minutes: 1.4 Acceptance rate: 0.5832373
# Iter 91 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.5523718
# Iter 101 / 2500 Remaining minutes: 1.4 Acceptance rate: 0.44701347
# Iter 111 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.4492612
# Iter 121 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.10923554
# Iter 131 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.38287875
# Iter 141 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.1348265
# Iter 151 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.0679087
# Iter 161 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.14097781
# Iter 171 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.2570485
# Iter 181 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.10896965
# Iter 191 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.17125306
# Iter 201 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.20713155
# Iter 211 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.03367085
# Iter 221 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.11155603
# Iter 231 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.024244497
# Iter 241 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.018790228
# Iter 251 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.20401327
# Iter 261 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.07068058
# Iter 271 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.17559786
# Iter 281 / 2500 Remaining minutes: 1.3 Acceptance rate: 0.025021031
# Iter 291 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.050278943
# Iter 301 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.11579553
# Iter 311 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.033632055
# Iter 321 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.034271818
# Iter 331 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.023568546
# Iter 341 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.038808238
# Iter 351 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.008172548
# Iter 361 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.0037395507
# Iter 371 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.010120755
# Iter 381 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.101357795
# Iter 391 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.004999904
# Iter 401 / 2500 Remaining minutes: 1.2 Acceptance rate: 0.031811193
# Iter 411 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.07414871
# Iter 421 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.032497793
# Iter 431 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.24421623
# Iter 441 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.0028965727
# Iter 451 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.022388915
# Iter 461 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.013469299
# Iter 471 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.012555731
# Iter 481 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.00034940834
# Iter 491 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.04152056
# Iter 501 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.109804414
# Iter 511 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.068386
# Iter 521 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.11225927
# Iter 531 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.112427734
# Iter 541 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.118185304
# Iter 551 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.022490332
# Iter 561 / 2500 Remaining minutes: 1.1 Acceptance rate: 0.049680818
# Iter 571 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.10747012
# Iter 581 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.11044459
# Iter 591 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.027243573
# Iter 601 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.046625145
# Iter 611 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.08936511
# Iter 621 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.055113308
# Iter 631 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.03566136
# Iter 641 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.1217374
# Iter 651 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.014769273
# Iter 661 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.03380619
# Iter 671 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.024663327
# Iter 681 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.22445428
# Iter 691 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.11132443
# Iter 701 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.11873416
# Iter 711 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.055152893
# Iter 721 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.0220451
# Iter 731 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.04292102
# Iter 741 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.07495458
# Iter 751 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.08793386
# Iter 761 / 2500 Remaining minutes: 1.0 Acceptance rate: 0.23372862
# Iter 771 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.006288612
# Iter 781 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.13707896
# Iter 791 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.30396703
# Iter 801 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.16163489
# Iter 811 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.016305652
# Iter 821 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.023792552
# Iter 831 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.08469429
# Iter 841 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.20697136
# Iter 851 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.08231887
# Iter 861 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.12874648
# Iter 871 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.10591161
# Iter 881 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.20714644
# Iter 891 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.080511086
# Iter 901 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.012775302
# Iter 911 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.022992756
# Iter 921 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.024175946
# Iter 931 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.18223986
# Iter 941 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.014630509
# Iter 951 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.111207984
# Iter 961 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.017588105
# Iter 971 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.030302757
# Iter 981 / 2500 Remaining minutes: 0.9 Acceptance rate: 0.1215996
# Iter 991 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.052561454
# Iter 1001 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.04901334
# Iter 1011 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.005203943
# Iter 1021 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.19866076
# Iter 1031 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.031002557
# Iter 1041 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.0044903248
# Iter 1051 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.06745689
# Iter 1061 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.116790876
# Iter 1071 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.018493515
# Iter 1081 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.04278744
# Iter 1091 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.0008960913
# Iter 1101 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.020155044
# Iter 1111 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.05987993
# Iter 1121 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.057227165
# Iter 1131 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.012490776
# Iter 1141 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.0022140485
# Iter 1151 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.053334247
# Iter 1161 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.015573521
# Iter 1171 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.012009211
# Iter 1181 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.03898769
# Iter 1191 / 2500 Remaining minutes: 0.8 Acceptance rate: 0.06767254
# Iter 1201 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.11029197
# Iter 1211 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.02732257
# Iter 1221 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.056142606
# Iter 1231 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.057551682
# Iter 1241 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.08127567
# Iter 1251 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.056157432
# Iter 1261 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.0026781575
# Iter 1271 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.11045368
# Iter 1281 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.015104237
# Iter 1291 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.04343582
# Iter 1301 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.021207392
# Iter 1311 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.033079013
# Iter 1321 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.014669947
# Iter 1331 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.0019167745
# Iter 1341 / 2500 Remaining minutes: 0.7 Acceptance rate: 0.02590333
# Iter 1351 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.043814503
# Iter 1361 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.009162293
# Iter 1371 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.03664273
# Iter 1381 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.063051775
# Iter 1391 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.08087318
# Iter 1401 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.059619747
# Iter 1411 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.0121394545
# Iter 1421 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.07391881
# Iter 1431 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.05978932
# Iter 1441 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.10555055
# Iter 1451 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.011900011
# Iter 1461 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.09373753
# Iter 1471 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.09701337
# Iter 1481 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.19338945
# Iter 1491 / 2500 Remaining minutes: 0.6 Acceptance rate: 0.007368834
# Iter 1501 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.060799517
# Iter 1511 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.043941908
# Iter 1521 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.020719431
# Iter 1531 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.027736336
# Iter 1541 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.010938136
# Iter 1551 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.024463346
# Iter 1561 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.0115408655
# Iter 1571 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.04398609
# Iter 1581 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.017013136
# Iter 1591 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.05016284
# Iter 1601 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.032654684
# Iter 1611 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.0024805856
# Iter 1621 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.025346464
# Iter 1631 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.10838051
# Iter 1641 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.028963199
# Iter 1651 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.0007867155
# Iter 1661 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.013059298
# Iter 1671 / 2500 Remaining minutes: 0.5 Acceptance rate: 0.0113091385
# Iter 1681 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.0007309244
# Iter 1691 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.10040422
# Iter 1701 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.0028579393
# Iter 1711 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.0055209724
# Iter 1721 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.038251586
# Iter 1731 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.13968089
# Iter 1741 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.044247504
# Iter 1751 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.01917116
# Iter 1761 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.019121174
# Iter 1771 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.009797956
# Iter 1781 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.0046279905
# Iter 1791 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.017346282
# Iter 1801 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.11902912
# Iter 1811 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.007605405
# Iter 1821 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.018248413
# Iter 1831 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.0117429495
# Iter 1841 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.05773438
# Iter 1851 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.056372352
# Iter 1861 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.015930643
# Iter 1871 / 2500 Remaining minutes: 0.4 Acceptance rate: 0.1607492
# Iter 1881 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.019265203
# Iter 1891 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.05288465
# Iter 1901 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.14912291
# Iter 1911 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.04169674
# Iter 1921 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.0058350237
# Iter 1931 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.05814932
# Iter 1941 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.017781492
# Iter 1951 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.12592293
# Iter 1961 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.010547873
# Iter 1971 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.086478986
# Iter 1981 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.0025323294
# Iter 1991 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.0046250555
# Iter 2001 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.00024063129
# Iter 2011 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.016505798
# Iter 2021 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.00657357
# Iter 2031 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.052099634
# Iter 2041 / 2500 Remaining minutes: 0.3 Acceptance rate: 0.026145598
# Iter 2051 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.013284753
# Iter 2061 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.022396673
# Iter 2071 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.08012753
# Iter 2081 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.0043999287
# Iter 2091 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.09095381
# Iter 2101 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.02089708
# Iter 2111 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.07293023
# Iter 2121 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.07997159
# Iter 2131 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.010146184
# Iter 2141 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.23810157
# Iter 2151 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.015117168
# Iter 2161 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.104832605
# Iter 2171 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.074655145
# Iter 2181 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.1464028
# Iter 2191 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.08454273
# Iter 2201 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.008988699
# Iter 2211 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.18432775
# Iter 2221 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.06715173
# Iter 2231 / 2500 Remaining minutes: 0.2 Acceptance rate: 0.109322906
# Iter 2241 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.012400721
# Iter 2251 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.10292528
# Iter 2261 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.041314118
# Iter 2271 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.19832817
# Iter 2281 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.13000938
# Iter 2291 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.023669122
# Iter 2301 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.10133699
# Iter 2311 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.0043546706
# Iter 2321 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.128132
# Iter 2331 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.02534459
# Iter 2341 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.13068402
# Iter 2351 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.115860224
# Iter 2361 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.05482449
# Iter 2371 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.16191769
# Iter 2381 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.25858706
# Iter 2391 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.22170572
# Iter 2401 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.023593454
# Iter 2411 / 2500 Remaining minutes: 0.1 Acceptance rate: 0.045372143
# Iter 2421 / 2500 Remaining minutes: 0.0 Acceptance rate: 0.00273806
# Iter 2431 / 2500 Remaining minutes: 0.0 Acceptance rate: 0.11940102
# Iter 2441 / 2500 Remaining minutes: 0.0 Acceptance rate: 0.15222254
# Iter 2451 / 2500 Remaining minutes: 0.0 Acceptance rate: 0.15835838
# Iter 2461 / 2500 Remaining minutes: 0.0 Acceptance rate: 0.12558529
# Iter 2471 / 2500 Remaining minutes: 0.0 Acceptance rate: 0.031375304
# Iter 2481 / 2500 Remaining minutes: 0.0 Acceptance rate: 0.0048204786
# Iter 2491 / 2500 Remaining minutes: 0.0 Acceptance rate: 0.103401445
# Total time: 92.19962811470032

# %%
import rpy2
import rpy2.robjects.packages as rpackages
from rpy2.robjects import numpy2ri
numpy2ri.activate()

utils = rpackages.importr('utils')
utils.chooseCRANmirror(ind=1)
utils.install_packages('GreedyEPL')
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: also installing the dependency ‘RcppArmadillo’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/RcppArmadillo_0.10.8.1.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 1364404 bytes (1.3 MB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 1.3 MB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/GreedyEPL_1.2.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 11717 bytes (11 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 11 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The downloaded source packages are in
# 	‘/tmp/RtmpEHtTiW/downloaded_packages’
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x7f362783a550> [RTYPES.NILSXP]

# %%
c_chain = np.vstack(allocs_out)
c_chain=c_chain+1 # con cluster 0 altrimenti da errore perchè fa un -1 dentro l'algoritmo non so perchè

GreedyEPL = rpackages.importr('GreedyEPL')
best_clust_obj=GreedyEPL.MinimiseEPL(c_chain,pars = list("B"))
best_clust=best_clust_obj[2]-1

# %%
c_chain
# Out:
# array([[7, 7, 1, ..., 7, 7, 3],
#        [7, 7, 1, ..., 7, 3, 3],
#        [3, 7, 3, ..., 7, 3, 3],
#        ...,
#        [7, 7, 3, ..., 7, 9, 3],
#        [7, 7, 3, ..., 7, 9, 3],
#        [7, 7, 3, ..., 7, 7, 3]], dtype=int32)

# %%
#View the number of points inside each cluster at the best iteration
print(pd.Series(best_clust).value_counts())
x, y = np.unique(best_clust, return_counts=True)
plt.bar(x, y)
# Out:
# 2.0    330
# 0.0    222
# 3.0    135
# 4.0    126
# 1.0    120
# 5.0     67
# dtype: int64
# <BarContainer object of 6 artists>

# %%
#scatterplot of clusters from last recorded iteration
for h in range(k):
    currd = data[best_clust == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [mu[i][0] for mu in mus_out]
    second_comp = [mu[i][1] for mu in mus_out]

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__mu_x", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_mu_y", fontsize=16)

    plt.show()

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [covs[i][0,0] for covs in covs_out]
    second_comp = [covs[i][0,1] for covs in covs_out]
    third_comp = [covs[i][1,1] for covs in covs_out]

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__cov_xx", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_cov_xy", fontsize=16)
    
    axes[2].plot(np.arange(len(third_comp)), third_comp,)
    axes[2].set_title(str(i) + "_cov_yy", fontsize=16)

    plt.show()

# %%
for i in range(k):
    weights = [w[i] for w in weights_out]
    plt.plot(np.arange(len(weights)) , weights)

# %% [markdown]
# # Speed Comparison

# %%
#Slow functions

def sample_uniq_vals_fullcond_Wasserstein_NW_log_slow(clusdata, mus,covs, h,bij,cov_prop_mu,cov_prop_cov):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov = sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log_slow(clusdata,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = np.minimum(0, beta)
    accept_rate = np.exp(beta)
    
    draw = tfd.Uniform().sample()
    
    # Select the new or old values 
    if(np.log(draw) >= beta):
        return mu_old,cov_old,accept_rate

    else:
        return mu,cov,accept_rate
    
def sample_uniq_vals_prior_Wasserstein_NW_log_slow(mus,covs, h,bij,cov_prop_mu,cov_prop_cov):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov = sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log_slow(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = np.minimum(0, beta)
    accept_rate = np.exp(beta)
    
    draw = tfd.Uniform().sample()
    
    # Select the new or old values 
    if(np.log(draw) >= beta):
        return np.array(mu_old),np.array(cov_old),accept_rate

    else:
        return np.array(mu),np.array(cov),accept_rate
    

def sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov, bijector):
    """
    Sample new mean and covariance matrix through the bijection
    """
    mu = tfd.MultivariateNormalFullCovariance(mu_old, cov_prop_mu).sample()
    
    chol = np.linalg.cholesky(cov_old)
    vec = bijector.inverse(chol)
    vec_sampl = tfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample()
    cov_sampl = bijector.forward(vec_sampl)
    cov = np.matmul(cov_sampl , np.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    
    return mu,cov,log_jac

def compute_beta_NW_log_slow(clusdata,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    
    mu_0 = np.zeros(2)
    cov_0 = 10*np.eye(2)
    nu_0 = 15
    phi_0 = (nu_0 - 3)*np.eye(2)
    
    # NW distribution terms
    num_0 = evaluate_NW_log_slow(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log_slow(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = np.sum(tfd.MultivariateNormalFullCovariance(mu, cov).log_prob(clusdata))
    den_1 = np.sum(tfd.MultivariateNormalFullCovariance(mu_old, cov_old).log_prob(clusdata))
    
    # Wasserstein Distance terms
    sum_ = 0
    for j in range(k):
        if(j != h):
            mu_j = mus[j]
            cov_j = covs[j]
            sum_ = sum_ + np.log(compute_Wasserstein_slow(mu , cov , mu_j , cov_j)) - np.log(compute_Wasserstein_slow(mu_old , cov_old , mu_j, cov_j))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term

def compute_beta_NW_prior_log_slow(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = np.zeros(2)
    cov_0 = 10*np.eye(2)
    nu_0 = 15
    phi_0 = (nu_0 - 3)*np.eye(2)
    
    # NW distribution terms
    num = evaluate_NW_log_slow(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log_slow(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    sum_ = 0
    for j in range(k):
        if(j != h):
            mu_j = mus[j]
            cov_j = covs[j]
            sum_ = sum_ + np.log(compute_Wasserstein_slow(mu , cov , mu_j , cov_j)) - np.log(compute_Wasserstein_slow(mu_old , cov_old , mu_j, cov_j))

    return num  - den + sum_ + jac_term
  
def evaluate_NW_log_slow(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = np.linalg.inv(phi_n)
    chol = np.linalg.cholesky(W) 
    inv_cov = np.linalg.inv(x_cov)

    f1 = tfd.WishartTriL(df=nu_n, scale_tril=chol).log_prob(inv_cov)
    f2 = tfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

def compute_Wasserstein_slow(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = np.linalg.norm(mu_1 - mu_2, ord = 2)
    sqrt_C2 = scipy.linalg.sqrtm(cov_2)
    C1_sqrt_C2 = np.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = np.matmul(sqrt_C2,C1_sqrt_C2)
    trace = np.trace(cov_1 + cov_2 - 2 * scipy.linalg.sqrtm(sqrt_C2_C1_sqrt_C2))

    # Function g
    return g(norm+trace)

def update_weights_slow(cluster_allocs, n_clus, k, alpha):

    n_by_clus = np.array([np.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = np.ones(k) * alpha + n_by_clus
    return tfd.Dirichlet(post_params.astype(float)).sample()

def update_cluster_allocs_slow(data, weights, mus, covs):
    #print(weights)
    logprobs = tfd.MultivariateNormalFullCovariance(mus, covs).log_prob(data[:, np.newaxis])
    logprobs += np.log(weights)
    probs =  np.exp(logprobs)/(np.sum(np.exp(logprobs), axis=1))[:,None]
    return tfd.Categorical(probs=probs, validate_args=True).sample()

# %%
#Data to use for comparison
key = rng_key
jtfb = jtfp.bijectors
bij = jtfb.Chain([
        jtfb.TransformDiagonal(jtfb.Softplus()),
        jtfb.FillTriangular()])

#Starting Values
cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
weights = jnp.ones(k)/k
alpha = 0.1
lam = 0.1
mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.eye(d) ).sample(k,seed = key))
covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(d)) ).sample(k,seed = key))

#Proposal Covariances
cov_prop_cov = 0.02 * jnp.eye(3) #covariance matrix for the covariance sampling
cov_prop_mu = 0.1 * jnp.eye(2)
h = 3
clusdata = data[cluster_allocs == h]


# %timeit sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
# %timeit sample_uniq_vals_fullcond_Wasserstein_NW_log_slow(clusdata, mus,covs, h,bij,cov_prop_mu,cov_prop_cov)
# %timeit compute_Wasserstein(mus[0], covs[0], mus[3], covs[3])
# %timeit compute_Wasserstein_slow(mus[0], covs[0], mus[3], covs[3])
# %timeit sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
# %timeit sample_uniq_vals_prior_Wasserstein_NW_log_slow(mus,covs, h,bij,cov_prop_mu,cov_prop_cov)
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:3556: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# 258 µs ± 651 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 144 ms ± 7.21 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# The slowest run took 9.06 times longer than the fastest. This could mean that an intermediate result is being cached.
# 91.8 µs ± 69.1 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 424 µs ± 80.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 231 µs ± 8.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 116 ms ± 1.96 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
