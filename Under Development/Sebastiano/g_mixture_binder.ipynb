# %%
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pandas as pd
import time
import scipy

#Separate import for numpy and jax.numpy to have major felxibility
import jax.numpy as jnp
import numpy as np
from jax import jit,lax,random
from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions
from tensorflow_probability.substrates import jax as jtfp
jtfd = jtfp.distributions

np.random.seed(0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7d1a6ba4b2b3> in <module>
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 3 import tensorflow as tf
#       4 import pandas as pd
#       5 import time
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
sampled_perturbed = np.load('sampled_2D_two_clusters_near.npy')
data = sampled_perturbed[0 : 1000]
#DEFINING NUMBER OF CLUSTERS AND DIMENSION OF DATA
k = 10
d = 2
#Key to store for random generation
rng_key = random.PRNGKey(0)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
@jit
def g(x):
    """
    Function to modulate the Wasserstein Distance
    """
    #Shape parameters
    a = 0.5

    return jnp.tanh(x*a)

@jit
def sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    
    
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,key = sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
    
    
@jit
def sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov,subk1 = sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij,key)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = jnp.minimum(0, beta)
    accept_rate = jnp.exp(beta)
    
    key,subk = random.split(key)
    draw = jtfd.Uniform().sample(seed = subk)
    
    # Select the new or old values 
    logic = jnp.log(draw) >= beta
    ret_mu = logic * jnp.array(mu_old) + (1 - logic)*jnp.array(mu)
    ret_cov = logic * jnp.array(cov_old) + (1 - logic)*jnp.array(cov)

    return ret_mu,ret_cov,accept_rate,key
    

@jit
def sample_from_bijector(mu_old, cov_prop_mu, cov_old, cov_prop_cov, bijector,key):
    """
    Sample new mean and covariance matrix through the bijection
    """
    key , subk1 , subk2 = random.split(key,3)

    mix = 0.1
    bimix_gauss = jtfd.MixtureSameFamily(
        
                     mixture_distribution=jtfd.Categorical(probs=[mix, 1-mix]),
                     components_distribution=jtfd.MultivariateNormalDiag(loc=[mu_old,mu_old],scale_diag=[[3,3],[0.1,0.1]])
                   )  

    mu = bimix_gauss.sample(seed = subk1)
    
    chol = jnp.linalg.cholesky(cov_old)
    vec = bijector.inverse(chol)
    vec_sampl = jtfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample(seed = subk2)
    cov_sampl = bijector.forward(vec_sampl)
    cov = jnp.matmul(cov_sampl , jnp.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    
    return mu,cov,log_jac,key

@jit
def compute_beta_NW_log(data,cluster_allocs,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    cluster_allocs_expanded = jnp.expand_dims(cluster_allocs,axis = 1)
    nan_vec = jnp.repeat(jnp.array([[jnp.nan,jnp.nan]]),len(cluster_allocs),axis=0)
    clusdata = jnp.where(jnp.concatenate((cluster_allocs_expanded,cluster_allocs_expanded),axis = 1) == h,data,nan_vec)
       
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 3
    phi_0 = jnp.eye(2)*nu_0
    
    # NW distribution terms
    num_0 = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu, cov).log_prob(clusdata))
    den_1 = jnp.nansum(jtfd.MultivariateNormalFullCovariance(mu_old, cov_old).log_prob(clusdata))
    
     # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term

@jit
def compute_beta_NW_prior_log(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = jnp.zeros(2)
    cov_0 = jnp.eye(2)
    nu_0 = 3
    phi_0 = jnp.eye(2)*nu_0
    
    # NW distribution terms
    num = evaluate_NW_log(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    wass_arr = jnp.array([jnp.log(compute_Wasserstein(mu , cov , mus[j] , covs[j])) - jnp.log(compute_Wasserstein(mu_old , cov_old , mus[j], covs[j])) for j in range(k)])
    cond_arr = jnp.arange(k)
    nan_arr = jnp.repeat(jnp.nan,k)
    sum_ = jnp.nansum(jnp.where(cond_arr != h,wass_arr,nan_arr))
    
    return num  - den + sum_ + jac_term
  
@jit
def evaluate_NW_log(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = jnp.linalg.inv(phi_n)
    chol = jnp.linalg.cholesky(W) 
    inv_cov = jnp.linalg.inv(x_cov)

    f1 = jtfd.WishartTriL(df=nu_n.astype(float), scale_tril=chol).log_prob(inv_cov)
    f2 = jtfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

@jit
def compute_Wasserstein(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = jnp.linalg.norm(mu_1 - mu_2, ord = 2)
    
    #Compute square root of cov_2
    s = jnp.sqrt(jnp.linalg.det(cov_2))
    t = jnp.sqrt(jnp.trace(cov_2) + 2*s)
    sqrt_C2 = 1/t * (cov_2 + s*jnp.eye(2))
    
    C1_sqrt_C2 = jnp.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = jnp.matmul(sqrt_C2,C1_sqrt_C2)
    
    #Compute square root of sqrt_C2_C1_sqrt_C2
    s = jnp.sqrt(jnp.linalg.det(sqrt_C2_C1_sqrt_C2))
    t = jnp.sqrt(jnp.trace(sqrt_C2_C1_sqrt_C2) + 2*s)
    mat_sqrt = 1/t * (sqrt_C2_C1_sqrt_C2 + s*jnp.eye(2))
    
    trace = jnp.trace(cov_1 + cov_2 - 2 * mat_sqrt)

    # Function g
    return g(norm+trace)

@jit
def update_weights(cluster_allocs, weights, k, alpha,key):

    key, subk = random.split(key)
    n_clus = len(weights)
    n_by_clus = jnp.array([jnp.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = jnp.ones(n_clus) * alpha + n_by_clus
    return jtfd.Dirichlet(post_params.astype(float)).sample(seed = subk),key

@jit
def update_cluster_allocs(data, weights, mus, covs,key):
    #print(weights)
    key, subk = random.split(key)
    logprobs = jtfd.MultivariateNormalFullCovariance(mus, covs).log_prob(data[:, jnp.newaxis])
    logprobs += jnp.log(weights)
    probs =  jnp.exp(logprobs)/(jnp.sum(jnp.exp(logprobs), axis=1))[:,None]
    return jtfd.Categorical(probs=probs, validate_args=True).sample(seed = subk),key

# %%
def run_one_gibbs(data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,key):
    """
    Run one gibbs sampler iteration
    Takes in input values of the previous iteration and sample the new values from sample_uniq_vals_fullcond, update_weights and update_cluster_allocs
    Returns:   
    
    -cluster_allocs: for every data point, the cluster assigned
    -uniq_vals: array of parameters of the distributions. Matrix has d rows of the type:[mu[0], var[0,0], var[0,1]]
    -weights: array with the weights of the clusters 
     """
    key, subk = random.split(key)
    n_clus = len(weights)
    for h in range(n_clus):
        
        #Extract data assigned to cluster h and sample 
        clusdata = data[cluster_allocs == h]
        if(len(clusdata) != 0):
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
        else:
            mus[h],covs[h], acc_rate,key = sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)


    weights,key = update_weights(cluster_allocs ,weights, k, alpha,key)

    cluster_allocs,key = update_cluster_allocs(data, weights, mus,covs,key)

    return cluster_allocs, mus,covs, weights, acc_rate,key

def run_mcmc(data, k, key , niter=1000, nburn=300, thin=5 ): 
    """
    Runs entire MCMC
    Takes in input data, number of clusters, number of iterations, burn-in and thin
    Returns the parameters recorded after burn-in phase
    """

    b = time.time() # only to measure time
    
    #Bijector setup
    jtfb = jtfp.bijectors
    bij = jtfb.Chain([
            jtfb.TransformDiagonal(jtfb.Softplus()),
            jtfb.FillTriangular()])

    #Starting Values
    cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
    weights = jnp.ones(k)/k
    alpha = 0.1
    lam = 0.1
    mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.linalg.inv(np.diag(np.ones(d))/lam) ).sample(k,seed = key))
    covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(2)) ).sample(k,seed = key))
    
    #Proposal Covariances
    cov_prop_cov = 0.02 * jnp.eye(3) #covariance matrix for the covariance sampling
    cov_prop_mu = jnp.eye(2)   #covariance matrix for the mean sampling
    
    #Output values
    allocs_out = []
    mus_out = []
    covs_out = []
    weights_out = []
    acc_rates = []
    
    #Useful value
    data_mean = np.mean(data, axis = 0)
    
    #Iterations
    for i in range(niter):
        cluster_allocs, mus,covs, weights, acc_rate,key = run_one_gibbs(
            data, cluster_allocs, mus,covs, weights, alpha,bij,cov_prop_mu,cov_prop_cov,key)
        acc_rates.append(acc_rate)
        
        if i > nburn and i % thin == 0:
            allocs_out.append(cluster_allocs)
            mus_out.append(mus.copy())
            covs_out.append(covs.copy())
            weights_out.append(weights)
            
        if i % 10 == 0 and i > 11:
            a = time.time()
            print("\rIter {0} / {1}".format(i+1, niter) + " Remaining minutes: " + str(round((a-b)*(niter-i)/(60*10) ,1)) , flush=False, end=" ")
            b = time.time()
            print("Acceptance rate: " + str(np.mean(acc_rates[-10:])))
            
    return allocs_out, mus_out,covs_out, weights_out,acc_rates

# %%
#RUNNING THE MCMC
start = time.time()
allocs_out, mus_out,covs_out, weights_out,accept_rate_out = run_mcmc(data, k,rng_key , niter = 5000,nburn = 1000,thin = 5)
end = time.time()
print("Total time: " + str(end-start))
# Out:
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:6493: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:6493: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:3552: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# skip assert _assert_compare_to_zero
# skip assert _assert_near
# Iter 21 / 5000 Remaining minutes: 181.5 Acceptance rate: 0.7587995
# Iter 31 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.37443343
# Iter 41 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8237456
# Iter 51 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.87699634
# Iter 61 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7700584
# Iter 71 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8619827
# Iter 81 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8519577
# Iter 91 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.93630314
# Iter 101 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.86246824
# Iter 111 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8161252
# Iter 121 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.89178294
# Iter 131 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.80387
# Iter 141 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.88821536
# Iter 151 / 5000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 161 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8051748
# Iter 171 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8474096
# Iter 181 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.87623423
# Iter 191 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9507529
# Iter 201 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.88719624
# Iter 211 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.84991395
# Iter 221 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.95314485
# Iter 231 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.98271763
# Iter 241 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.98173904
# Iter 251 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.95197666
# Iter 261 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9874733
# Iter 271 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.98069745
# Iter 281 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.80449486
# Iter 291 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9271986
# Iter 301 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9967022
# Iter 311 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.90297985
# Iter 321 / 5000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 331 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8801346
# Iter 341 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.70341563
# Iter 351 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8606633
# Iter 361 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.82168806
# Iter 371 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.97243375
# Iter 381 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8184187
# Iter 391 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7669074
# Iter 401 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9285327
# Iter 411 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.7912227
# Iter 421 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.75863427
# Iter 431 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9206646
# Iter 441 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.94236946
# Iter 451 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.96690977
# Iter 461 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.97374886
# Iter 471 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9642722
# Iter 481 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8932927
# Iter 491 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.97281617
# Iter 501 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.77256763
# Iter 511 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8717046
# Iter 521 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9072833
# Iter 531 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.83594865
# Iter 541 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8782517
# Iter 551 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.84833604
# Iter 561 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.99743336
# Iter 571 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.87256753
# Iter 581 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7584408
# Iter 591 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.8486884
# Iter 601 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8456524
# Iter 611 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8651825
# Iter 621 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7676511
# Iter 631 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8751976
# Iter 641 / 5000 Remaining minutes: 0.3 Acceptance rate: 0.94925135
# Iter 651 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.6465229
# Iter 661 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.89272845
# Iter 671 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8860264
# Iter 681 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9967831
# Iter 691 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.805662
# Iter 701 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9003151
# Iter 711 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9919149
# Iter 721 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9614889
# Iter 731 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8320676
# Iter 741 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7817497
# Iter 751 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7891009
# Iter 761 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9215369
# Iter 771 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9788825
# Iter 781 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.97986853
# Iter 791 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.87571794
# Iter 801 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.69752884
# Iter 811 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9592121
# Iter 821 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9488986
# Iter 831 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8858431
# Iter 841 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.891939
# Iter 851 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8864077
# Iter 861 / 5000 Remaining minutes: 0.2 Acceptance rate: 1.0
# Iter 871 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9000103
# Iter 881 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7968489
# Iter 891 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7640827
# Iter 901 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.996055
# Iter 911 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7783454
# Iter 921 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8884676
# Iter 931 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9808636
# Iter 941 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.90738344
# Iter 951 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9765089
# Iter 961 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.81374156
# Iter 971 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.77954936
# Iter 981 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.86290246
# Iter 991 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.89446926
# Iter 1001 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9529511
# Iter 1011 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9863294
# Iter 1021 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.69811505
# Iter 1031 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.74138296
# Iter 1041 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8363632
# Iter 1051 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8031352
# Iter 1061 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.94549274
# Iter 1071 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.888581
# Iter 1081 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.93244535
# Iter 1091 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.6347804
# Iter 1101 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9360102
# Iter 1111 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.87967616
# Iter 1121 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.6471324
# Iter 1131 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9131028
# Iter 1141 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.935222
# Iter 1151 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.76697177
# Iter 1161 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9885565
# Iter 1171 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7793122
# Iter 1181 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.85413456
# Iter 1191 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9954201
# Iter 1201 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.84263456
# Iter 1211 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7996241
# Iter 1221 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.78783286
# Iter 1231 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.91448575
# Iter 1241 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9794973
# Iter 1251 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.919292
# Iter 1261 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.6265458
# Iter 1271 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9342227
# Iter 1281 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.86718196
# Iter 1291 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7070657
# Iter 1301 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.93066704
# Iter 1311 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9735773
# Iter 1321 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8388718
# Iter 1331 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.59246194
# Iter 1341 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7283268
# Iter 1351 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.87177306
# Iter 1361 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7727824
# Iter 1371 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7053257
# Iter 1381 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.77008617
# Iter 1391 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.82454646
# Iter 1401 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.75347245
# Iter 1411 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9750422
# Iter 1421 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8470982
# Iter 1431 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.88206065
# Iter 1441 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.89818037
# Iter 1451 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9873918
# Iter 1461 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.85645056
# Iter 1471 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.69677997
# Iter 1481 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8952013
# Iter 1491 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9148962
# Iter 1501 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.68187845
# Iter 1511 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9
# Iter 1521 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.86852854
# Iter 1531 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8938755
# Iter 1541 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.97841966
# Iter 1551 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9981966
# Iter 1561 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7892494
# Iter 1571 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8687128
# Iter 1581 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9236692
# Iter 1591 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8608211
# Iter 1601 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9657998
# Iter 1611 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7907423
# Iter 1621 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9138101
# Iter 1631 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.94915694
# Iter 1641 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8479048
# Iter 1651 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8157929
# Iter 1661 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8662182
# Iter 1671 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.93190795
# Iter 1681 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.97500306
# Iter 1691 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8490602
# Iter 1701 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.86722106
# Iter 1711 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.923192
# Iter 1721 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.936722
# Iter 1731 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.92387676
# Iter 1741 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8600941
# Iter 1751 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.869559
# Iter 1761 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.86753607
# Iter 1771 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.87067586
# Iter 1781 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.73537195
# Iter 1791 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.91923237
# Iter 1801 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9670027
# Iter 1811 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.89847964
# Iter 1821 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.96456397
# Iter 1831 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9309801
# Iter 1841 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.99098176
# Iter 1851 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.938488
# Iter 1861 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8773071
# Iter 1871 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8167254
# Iter 1881 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7697936
# Iter 1891 / 5000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 1901 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9246315
# Iter 1911 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6999184
# Iter 1921 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8463615
# Iter 1931 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.99430066
# Iter 1941 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.89509976
# Iter 1951 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.834643
# Iter 1961 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8886607
# Iter 1971 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8086357
# Iter 1981 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9153551
# Iter 1991 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7569425
# Iter 2001 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9097211
# Iter 2011 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.967628
# Iter 2021 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.86807716
# Iter 2031 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.85624534
# Iter 2041 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.88955325
# Iter 2051 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.8790263
# Iter 2061 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.89557475
# Iter 2071 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.879161
# Iter 2081 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.95342875
# Iter 2091 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.98098963
# Iter 2101 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7926196
# Iter 2111 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.682569
# Iter 2121 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.85990304
# Iter 2131 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.99018824
# Iter 2141 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.85957366
# Iter 2151 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9728302
# Iter 2161 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.85854834
# Iter 2171 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7816517
# Iter 2181 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7741727
# Iter 2191 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.7714538
# Iter 2201 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.74925697
# Iter 2211 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6971528
# Iter 2221 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7704538
# Iter 2231 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6833468
# Iter 2241 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7338696
# Iter 2251 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.5388573
# Iter 2261 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.79883283
# Iter 2271 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.76228374
# Iter 2281 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9703768
# Iter 2291 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8863903
# Iter 2301 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8412598
# Iter 2311 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8237605
# Iter 2321 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6976848
# Iter 2331 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7572044
# Iter 2341 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.98497725
# Iter 2351 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8318001
# Iter 2361 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.867843
# Iter 2371 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8261441
# Iter 2381 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7826187
# Iter 2391 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.87787867
# Iter 2401 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9789316
# Iter 2411 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9589736
# Iter 2421 / 5000 Remaining minutes: 0.2 Acceptance rate: 0.9262106
# Iter 2431 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.78411525
# Iter 2441 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.81663066
# Iter 2451 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6386727
# Iter 2461 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.965381
# Iter 2471 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.89975643
# Iter 2481 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8042242
# Iter 2491 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.88764924
# Iter 2501 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8000226
# Iter 2511 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.79244936
# Iter 2521 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8862009
# Iter 2531 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.96446097
# Iter 2541 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.87390435
# Iter 2551 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.96463096
# Iter 2561 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9709617
# Iter 2571 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7924916
# Iter 2581 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.78709215
# Iter 2591 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.87273884
# Iter 2601 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9437629
# Iter 2611 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.79816276
# Iter 2621 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8710419
# Iter 2631 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8285228
# Iter 2641 / 5000 Remaining minutes: 0.1 Acceptance rate: 1.0
# Iter 2651 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9952795
# Iter 2661 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9967011
# Iter 2671 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.859903
# Iter 2681 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8764183
# Iter 2691 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.97789955
# Iter 2701 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9
# Iter 2711 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.97864354
# Iter 2721 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.811108
# Iter 2731 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9752601
# Iter 2741 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8161353
# Iter 2751 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.97689295
# Iter 2761 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9623892
# Iter 2771 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8373784
# Iter 2781 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.91717565
# Iter 2791 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.89281005
# Iter 2801 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.89682233
# Iter 2811 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9812484
# Iter 2821 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.76183116
# Iter 2831 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9128288
# Iter 2841 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.872215
# Iter 2851 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.89403135
# Iter 2861 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9834585
# Iter 2871 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8770588
# Iter 2881 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.77544516
# Iter 2891 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.83524674
# Iter 2901 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.86183417
# Iter 2911 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.894796
# Iter 2921 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.86966884
# Iter 2931 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.98743486
# Iter 2941 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.66411465
# Iter 2951 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9726925
# Iter 2961 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.88151217
# Iter 2971 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9864197
# Iter 2981 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8894647
# Iter 2991 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.77784574
# Iter 3001 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.88103545
# Iter 3011 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.89649713
# Iter 3021 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.80017626
# Iter 3031 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9313857
# Iter 3041 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.88948756
# Iter 3051 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9000001
# Iter 3061 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.995443
# Iter 3071 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9383066
# Iter 3081 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9000389
# Iter 3091 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9003873
# Iter 3101 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7069164
# Iter 3111 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.98087996
# Iter 3121 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9847191
# Iter 3131 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.96692955
# Iter 3141 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8506025
# Iter 3151 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.779354
# Iter 3161 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9502613
# Iter 3171 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8714708
# Iter 3181 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8540288
# Iter 3191 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.85146314
# Iter 3201 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8734438
# Iter 3211 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8408171
# Iter 3221 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9031132
# Iter 3231 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.883659
# Iter 3241 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.6236088
# Iter 3251 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.67048824
# Iter 3261 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.834314
# Iter 3271 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.722726
# Iter 3281 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.97481346
# Iter 3291 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9281828
# Iter 3301 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7197886
# Iter 3311 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8532896
# Iter 3321 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.87283325
# Iter 3331 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7934352
# Iter 3341 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9625929
# Iter 3351 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.92112684
# Iter 3361 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.85377693
# Iter 3371 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.844952
# Iter 3381 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8491472
# Iter 3391 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9121062
# Iter 3401 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.86021215
# Iter 3411 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.94022715
# Iter 3421 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7624591
# Iter 3431 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.93818104
# Iter 3441 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8909381
# Iter 3451 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9695222
# Iter 3461 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9456051
# Iter 3471 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8587469
# Iter 3481 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.86970234
# Iter 3491 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.83622915
# Iter 3501 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.86473644
# Iter 3511 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8498042
# Iter 3521 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9091362
# Iter 3531 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9852482
# Iter 3541 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8859987
# Iter 3551 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8057461
# Iter 3561 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9387161
# Iter 3571 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8473972
# Iter 3581 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8592518
# Iter 3591 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8622451
# Iter 3601 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7407681
# Iter 3611 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8887784
# Iter 3621 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.88807994
# Iter 3631 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9704231
# Iter 3641 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8663368
# Iter 3651 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.97318745
# Iter 3661 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9757139
# Iter 3671 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.79833496
# Iter 3681 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9811233
# Iter 3691 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.95807827
# Iter 3701 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.85784066
# Iter 3711 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9810316
# Iter 3721 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.81820124
# Iter 3731 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.93711483
# Iter 3741 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.951783
# Iter 3751 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.97084343
# Iter 3761 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.7909979
# Iter 3771 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.81005573
# Iter 3781 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.82838285
# Iter 3791 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9354132
# Iter 3801 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.872839
# Iter 3811 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9588558
# Iter 3821 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9936129
# Iter 3831 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9326037
# Iter 3841 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.95154303
# Iter 3851 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9451687
# Iter 3861 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9290349
# Iter 3871 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.92909276
# Iter 3881 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.68665016
# Iter 3891 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8995803
# Iter 3901 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8843001
# Iter 3911 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8984184
# Iter 3921 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.72128725
# Iter 3931 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.93591005
# Iter 3941 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9843627
# Iter 3951 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8536924
# Iter 3961 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8612183
# Iter 3971 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.8904907
# Iter 3981 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.873133
# Iter 3991 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.98254746
# Iter 4001 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9930006
# Iter 4011 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8979232
# Iter 4021 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.69720095
# Iter 4031 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.982971
# Iter 4041 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.85672486
# Iter 4051 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9582046
# Iter 4061 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8885271
# Iter 4071 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.97901934
# Iter 4081 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9866209
# Iter 4091 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.75283474
# Iter 4101 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.9622442
# Iter 4111 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.85964423
# Iter 4121 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.874191
# Iter 4131 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7795372
# Iter 4141 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8988447
# Iter 4151 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7540617
# Iter 4161 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.96343726
# Iter 4171 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.74930084
# Iter 4181 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.85442674
# Iter 4191 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.97766054
# Iter 4201 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9680153
# Iter 4211 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.97504294
# Iter 4221 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.76222825
# Iter 4231 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.85465926
# Iter 4241 / 5000 Remaining minutes: 0.1 Acceptance rate: 0.85652083
# Iter 4251 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7732361
# Iter 4261 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9594046
# Iter 4271 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8600748
# Iter 4281 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.80665433
# Iter 4291 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.773557
# Iter 4301 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7614479
# Iter 4311 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.94576913
# Iter 4321 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.76809174
# Iter 4331 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8094467
# Iter 4341 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.82450086
# Iter 4351 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8658956
# Iter 4361 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.6593818
# Iter 4371 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9184084
# Iter 4381 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.95302975
# Iter 4391 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.870344
# Iter 4401 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.94083786
# Iter 4411 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.61021906
# Iter 4421 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.78440607
# Iter 4431 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.881083
# Iter 4441 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8882591
# Iter 4451 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9816332
# Iter 4461 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9971377
# Iter 4471 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.98734045
# Iter 4481 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9029762
# Iter 4491 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.87476283
# Iter 4501 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9220308
# Iter 4511 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.67817736
# Iter 4521 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9453786
# Iter 4531 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7497973
# Iter 4541 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9450123
# Iter 4551 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.68316436
# Iter 4561 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7717916
# Iter 4571 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.85383415
# Iter 4581 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.92892486
# Iter 4591 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.89854413
# Iter 4601 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8913504
# Iter 4611 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.66939586
# Iter 4621 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.92689687
# Iter 4631 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.92356426
# Iter 4641 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8553856
# Iter 4651 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.88518935
# Iter 4661 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.95411855
# Iter 4671 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7000239
# Iter 4681 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.67201227
# Iter 4691 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.866865
# Iter 4701 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.771022
# Iter 4711 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.753932
# Iter 4721 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9718111
# Iter 4731 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.872184
# Iter 4741 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7990428
# Iter 4751 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.87291086
# Iter 4761 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.88092244
# Iter 4771 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8853943
# Iter 4781 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9837516
# Iter 4791 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8999221
# Iter 4801 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.97024375
# Iter 4811 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.95177877
# Iter 4821 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7835903
# Iter 4831 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.96552724
# Iter 4841 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8965151
# Iter 4851 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8105172
# Iter 4861 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.88862437
# Iter 4871 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8740698
# Iter 4881 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.78994
# Iter 4891 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9691103
# Iter 4901 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9449004
# Iter 4911 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7331033
# Iter 4921 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.7656218
# Iter 4931 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.85389745
# Iter 4941 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.83900154
# Iter 4951 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8913002
# Iter 4961 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.9141331
# Iter 4971 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.94312
# Iter 4981 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.8766098
# Iter 4991 / 5000 Remaining minutes: 0.0 Acceptance rate: 0.99043226
# Total time: 36.594176054000854

# %%
import rpy2
import rpy2.robjects.packages as rpackages
from rpy2.robjects import numpy2ri
numpy2ri.activate()

#utils = rpackages.importr('utils')
#utils.chooseCRANmirror(ind=1)
#utils.install_packages('GreedyEPL')

# %%
allocs_out
c_chain = np.vstack(allocs_out)
c_chain=c_chain+1

GreedyEPL = rpackages.importr('GreedyEPL')
best_clust_obj=GreedyEPL.MinimiseEPL(c_chain,pars = list("B"))
best_clust=best_clust_obj[2]-1

# %%
#View the number of points inside each cluster at the final iteration
print(pd.Series(best_clust).value_counts())
x, y = np.unique(best_clust, return_counts=True)
plt.bar(x, y)
# Out:
# 1.0    572
# 0.0    428
# dtype: int64
# <BarContainer object of 2 artists>

# %%
#scatterplot of clusters from last recorded iteration
for h in range(k):
    currd = data[best_clust == h]
    sns.scatterplot(x=[elem[0] for elem in currd], y=[elem[1] for elem in currd])

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [mu[i][0] for mu in mus_out]
    second_comp = [mu[i][1] for mu in mus_out]

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__mu_x", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_mu_y", fontsize=16)

    plt.show()

# %%
for i in range(k):
    
    #Get mean of the first gaussian component
    first_comp = [covs[i][0,0] for covs in covs_out]
    second_comp = [covs[i][0,1] for covs in covs_out]
    third_comp = [covs[i][1,1] for covs in covs_out]

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10, 5))

    axes[0].plot(np.arange(len(first_comp)), first_comp)
    axes[0].set_title(str(i) + "__cov_xx", fontsize=16)

    axes[1].plot(np.arange(len(second_comp)), second_comp,)
    axes[1].set_title(str(i) + "_cov_xy", fontsize=16)
    
    axes[2].plot(np.arange(len(third_comp)), second_comp,)
    axes[2].set_title(str(i) + "_cov_yy", fontsize=16)

    plt.show()

# %%
for i in range(k):
    weights = [w[i] for w in weights_out]
    plt.plot(np.arange(len(weights)) , weights)

# %% [markdown]
# # Speed Comparison

# %%
#Slow functions

def sample_uniq_vals_fullcond_Wasserstein_NW_log_slow(clusdata, mus,covs, h,bij,cov_prop_mu,cov_prop_cov):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    #Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov = sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_log_slow(clusdata,mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = np.minimum(0, beta)
    accept_rate = np.exp(beta)
    
    draw = tfd.Uniform().sample()
    
    # Select the new or old values 
    if(np.log(draw) >= beta):
        return mu_old,cov_old,accept_rate

    else:
        return mu,cov,accept_rate
    
def sample_uniq_vals_prior_Wasserstein_NW_log_slow(mus,covs, h,bij,cov_prop_mu,cov_prop_cov):
    """
    Perform one step of the Metropolis Hastings to sample a couple (mu,cov) from N*IW*Wasserstein
    """
    # Starting point of MH
    mu_old = mus[h]
    cov_old = covs[h]
    log_jac_cov_old = abs(bij.forward_log_det_jacobian( bij.inverse(cov_old) ) )
    
    # Sample the proposal using Bijector and compute jacobian term of transformation
    mu, cov, log_jac_cov = sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov,bij)
    jac_term = log_jac_cov - log_jac_cov_old
    
    # Compute acceptance rate(and return it for tuning)
    beta = compute_beta_NW_prior_log_slow(mus,covs, h, mu, cov,mu_old, cov_old,jac_term)
    beta = np.minimum(0, beta)
    accept_rate = np.exp(beta)
    
    draw = tfd.Uniform().sample()
    
    # Select the new or old values 
    if(np.log(draw) >= beta):
        return np.array(mu_old),np.array(cov_old),accept_rate

    else:
        return np.array(mu),np.array(cov),accept_rate
    

def sample_from_bijector_slow(mu_old, cov_prop_mu, cov_old, cov_prop_cov, bijector):
    """
    Sample new mean and covariance matrix through the bijection
    """
    mu = tfd.MultivariateNormalFullCovariance(mu_old, cov_prop_mu).sample()
    
    chol = np.linalg.cholesky(cov_old)
    vec = bijector.inverse(chol)
    vec_sampl = tfd.MultivariateNormalFullCovariance(vec,cov_prop_cov).sample()
    cov_sampl = bijector.forward(vec_sampl)
    cov = np.matmul(cov_sampl , np.transpose(cov_sampl))
    log_jac = abs(bijector.forward_log_det_jacobian(vec_sampl))
    
    return mu,cov,log_jac

def compute_beta_NW_log_slow(clusdata,mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_n
    """
    
    mu_0 = np.zeros(2)
    cov_0 = 10*np.eye(2)
    nu_0 = 15
    phi_0 = (nu_0 - 3)*np.eye(2)
    
    # NW distribution terms
    num_0 = evaluate_NW_log_slow(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den_0 = evaluate_NW_log_slow(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Data distribution terms
    num_1 = np.sum(tfd.MultivariateNormalFullCovariance(mu, cov).log_prob(clusdata))
    den_1 = np.sum(tfd.MultivariateNormalFullCovariance(mu_old, cov_old).log_prob(clusdata))
    
    # Wasserstein Distance terms
    sum_ = 0
    for j in range(k):
        if(j != h):
            mu_j = mus[j]
            cov_j = covs[j]
            sum_ = sum_ + np.log(compute_Wasserstein_slow(mu , cov , mu_j , cov_j)) - np.log(compute_Wasserstein_slow(mu_old , cov_old , mu_j, cov_j))

    return num_0 + num_1  - den_0 - den_1 + sum_ + jac_term

def compute_beta_NW_prior_log_slow(mus,covs, h, mu, cov,mu_old, cov_old,jac_term):
    """
    Compute Metropolis Hastings term, knowing the proposal is symmetric
    The target is the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nus the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_s the Normal Inverse Wishart with parameters mu_n, lam_n, phi_n, nu_"n
    """
    
    mu_0 = np.zeros(2)
    cov_0 = 10*np.eye(2)
    nu_0 = 15
    phi_0 = (nu_0 - 3)*np.eye(2)
    
    # NW distribution terms
    num = evaluate_NW_log_slow(mu, cov, mu_0, cov_0, phi_0, nu_0)
    den = evaluate_NW_log_slow(mu_old, cov_old , mu_0, cov_0, phi_0, nu_0)
    
    # Wasserstein Distance terms
    sum_ = 0
    for j in range(k):
        if(j != h):
            mu_j = mus[j]
            cov_j = covs[j]
            sum_ = sum_ + np.log(compute_Wasserstein_slow(mu , cov , mu_j , cov_j)) - np.log(compute_Wasserstein_slow(mu_old , cov_old , mu_j, cov_j))

    return num  - den + sum_ + jac_term
  
def evaluate_NW_log_slow(x_mu, x_cov, mu_n, cov_n, phi_n, nu_n):
    """
    Evaluate the likelihood: L[ (x_mu, x_cov) | ( mu_n, cov_n, phi_n, nu_n ) ]
    L = Normal x Inverse Wishart
    """
    W = np.linalg.inv(phi_n)
    chol = np.linalg.cholesky(W) 
    inv_cov = np.linalg.inv(x_cov)

    f1 = tfd.WishartTriL(df=nu_n, scale_tril=chol).log_prob(inv_cov)
    f2 = tfd.MultivariateNormalFullCovariance(mu_n, cov_n).log_prob(x_mu)
    
    return f1 + f2

def compute_Wasserstein_slow(mu_1, cov_1, mu_2, cov_2):
    """
    Wasserstein distance for the Gaussian Case, already taking consideration of g() to bound Wasserstein term
    """
    norm = np.linalg.norm(mu_1 - mu_2, ord = 2)
    sqrt_C2 = scipy.linalg.sqrtm(cov_2)
    C1_sqrt_C2 = np.matmul(cov_1,sqrt_C2)
    sqrt_C2_C1_sqrt_C2 = np.matmul(sqrt_C2,C1_sqrt_C2)
    trace = np.trace(cov_1 + cov_2 - 2 * scipy.linalg.sqrtm(sqrt_C2_C1_sqrt_C2))

    # Function g
    return g(norm+trace)

def update_weights_slow(cluster_allocs, n_clus, k, alpha):

    n_by_clus = np.array([np.sum(cluster_allocs == h) for h in range(n_clus)])
    post_params = np.ones(k) * alpha + n_by_clus
    return tfd.Dirichlet(post_params.astype(float)).sample()

def update_cluster_allocs_slow(data, weights, mus, covs):
    #print(weights)
    logprobs = tfd.MultivariateNormalFullCovariance(mus, covs).log_prob(data[:, np.newaxis])
    logprobs += np.log(weights)
    probs =  np.exp(logprobs)/(np.sum(np.exp(logprobs), axis=1))[:,None]
    return tfd.Categorical(probs=probs, validate_args=True).sample()

# %%
#Data to use for comparison
key = rng_key
jtfb = jtfp.bijectors
bij = jtfb.Chain([
        jtfb.TransformDiagonal(jtfb.Softplus()),
        jtfb.FillTriangular()])

#Starting Values
cluster_allocs = tfd.Categorical(probs=np.ones(k) / k).sample(len(data))
weights = jnp.ones(k)/k
alpha = 0.1
lam = 0.1
mus = np.array(jtfd.MultivariateNormalFullCovariance(np.mean(np.array(data), axis=0), np.eye(d) ).sample(k,seed = key))
covs = np.array(jtfd.WishartTriL(df=d, scale_tril=tf.linalg.cholesky(np.eye(d)) ).sample(k,seed = key))

#Proposal Covariances
cov_prop_cov = 0.02 * jnp.eye(3) #covariance matrix for the covariance sampling
cov_prop_mu = 0.1 * jnp.eye(2)
h = 3
clusdata = data[cluster_allocs == h]


# %timeit sample_uniq_vals_fullcond_Wasserstein_NW_log(data,cluster_allocs, mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
# %timeit sample_uniq_vals_fullcond_Wasserstein_NW_log_slow(clusdata, mus,covs, h,bij,cov_prop_mu,cov_prop_cov)
# %timeit compute_Wasserstein(mus[0], covs[0], mus[3], covs[3])
# %timeit compute_Wasserstein_slow(mus[0], covs[0], mus[3], covs[3])
# %timeit sample_uniq_vals_prior_Wasserstein_NW_log(mus,covs, h,bij,cov_prop_mu,cov_prop_cov,key)
# %timeit sample_uniq_vals_prior_Wasserstein_NW_log_slow(mus,covs, h,bij,cov_prop_mu,cov_prop_cov)
# Out:
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:6497: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "astype")
# /Users/leopere/anaconda3/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:3556: UserWarning: Explicitly requested dtype <class 'numpy.float64'> requested in array is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# 258 µs ± 651 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 144 ms ± 7.21 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# The slowest run took 9.06 times longer than the fastest. This could mean that an intermediate result is being cached.
# 91.8 µs ± 69.1 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 424 µs ± 80.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 231 µs ± 8.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 116 ms ± 1.96 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
